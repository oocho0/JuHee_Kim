# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt #서브 패키지 pyplot 사용
# %matplotlib inline
from sklearn.cluster import KMeans

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
else:
    print('Unknown system...  sorry~~~')

# %%
data=pd.read_csv('project_all.csv')
hh=pd.read_csv('../total_household/total_household_2020.csv')
hh.set_index('sigungu', inplace=True)
hh.sort_index(inplace=True)

# %%
data.set_index('시군구', inplace=True)
data['총가구수']=hh['2020']
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 88 entries, 강원도 고성군 to 충청북도 제천시
# Data columns (total 30 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SIG_CD       88 non-null     int64
#  1   SIG_KOR_NM   88 non-null     object
#  2   인구수          88 non-null     float64
#  3   사망률          88 non-null     float64
#  4   고령화비율        88 non-null     float64
#  5   전체 가구수       88 non-null     int64
#  6   산림면적(ha)     88 non-null     int64
#  7   고용률          88 non-null     float64
#  8   경제활동인구       88 non-null     float64
#  9   유소년비율        88 non-null     float64
#  10  조출생률         88 non-null     float64
#  11  1인 가구비율      88 non-null     float64
#  12  터널수          88 non-null     int64
#  13  만명당 매장 수     88 non-null     float64
#  14  만명 당 의료기관 수  88 non-null     float64
#  15  만명당 3차병원수    88 non-null     float64
#  16  만명당 2차병원 수   88 non-null     float64
#  17  만명당 1차병원 수   88 non-null     float64
#  18  만명당 요양병원 수   88 non-null     float64
#  19  만먕당 한의원 수    88 non-null     float64
#  20  1차산업비율       88 non-null     float64
#  21  2차산업비율       88 non-null     float64
#  22  3차산업비율       88 non-null     float64
#  23  ktx거리        88 non-null     float64
#  24  빈집비율         88 non-null     float64
#  25  산지면적/도시면적    88 non-null     float64
#  26  재정자립도        88 non-null     float64
#  27  연평균인구증감률     88 non-null     float64
#  28  시도           88 non-null     object
#  29  총가구수         88 non-null     int64
# dtypes: float64(23), int64(5), object(2)
# memory usage: 21.3+ KB

# %%
cluster_1=pd.read_csv('cluster.csv')
cluster_1.set_index('sigungu',inplace=True)
cluster_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 88 entries, 강원도 고성군 to 충청북도 제천시
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cluster  88 non-null     int64
# dtypes: int64(1)
# memory usage: 1.4+ KB

# %%
data['cluster']=cluster_1['cluster']
data
# Out:
#           SIG_CD SIG_KOR_NM       인구수     사망률      고령화비율  전체 가구수  산림면적(ha)  \
# 시군구
# 강원도 고성군    42820        고성군   26791.5  1228.0  28.942015   12096     54827
# 강원도 삼척시    42230        삼척시   65623.0   964.6  24.495985   31016    104323
# 강원도 양구군    42800        양구군   22379.0   862.4  20.362840    8606     52993
# 강원도 양양군    42830        양양군   27627.5  1104.0  29.253461   12445     52485
# 강원도 영월군    42750        영월군   38345.0  1053.6  28.819924   17175     95389
# ...          ...        ...       ...     ...        ...     ...       ...
# 충청북도 단양군   43800        단양군   29143.0  1132.3  30.027794   12845     64227
# 충청북도 보은군   43720        보은군   32402.5  1638.8  33.843068   14464     39807
# 충청북도 영동군   43740        영동군   47736.5  1432.9  30.806615   21303     65745
# 충청북도 옥천군   43730        옥천군   50381.0  1206.8  29.195530   20937    349001
# 충청북도 제천시   43150        제천시  132882.5   852.6  21.257126   60173     64042
#
#            고용률  경제활동인구      유소년비율  ...  2차산업비율  3차산업비율    ktx거리  빈집비율  \
# 시군구                                ...
# 강원도 고성군   70.1    34.2   7.629285  ...   12.13   64.20  78.2998  15.6
# 강원도 삼척시   61.0    70.0   9.679533  ...   16.64   74.38   6.5740  17.2
# 강원도 양구군   71.2    23.4  11.836990  ...    7.83   63.48  69.6764   7.8
# 강원도 양양군   71.5    33.9   7.984798  ...   12.57   62.28  42.4503  23.7
# 강원도 영월군   65.8    43.4   7.560308  ...   12.82   61.07  23.6510  11.3
# ...        ...     ...        ...  ...     ...     ...      ...   ...
# 충청북도 단양군  66.1    32.6   7.480355  ...   16.35   58.18   2.3648  15.2
# 충청북도 보은군  69.1    39.3   7.693851  ...   16.92   41.28  31.8634  15.6
# 충청북도 영동군  63.0    53.4   8.341625  ...   12.52   44.02  35.8983  13.1
# 충청북도 옥천군  63.2    56.4   9.037137  ...   19.86   50.54  12.7339  11.7
# 충청북도 제천시  60.1   144.9  10.929204  ...   23.31   63.34   1.2238  11.6
#
#            산지면적/도시면적  재정자립도  연평균인구증감률    시도   총가구수  cluster
# 시군구
# 강원도 고성군    44.137726    8.6   -2.9116   강원도  12096        3
# 강원도 삼척시    13.059622   13.5   -1.6028   강원도  31016        0
# 강원도 양구군   142.838275    8.1   -1.8544   강원도   8606        3
# 강원도 양양군    44.811864   14.1    0.6621   강원도  12445        3
# 강원도 영월군    36.154246   15.2   -0.8921   강원도  17175        0
# ...              ...    ...       ...   ...    ...      ...
# 충청북도 단양군   18.018566   11.6   -1.1236  충청북도  12845        0
# 충청북도 보은군   22.443296    9.5   -1.3486  충청북도  14464        1
# 충청북도 영동군   21.135318    8.1   -1.5577  충청북도  21303        1
# 충청북도 옥천군   63.384428   11.4   -0.8429  충청북도  20937        0
# 충청북도 제천시   11.109511   15.3   -0.6470  충청북도  60173        2
#
# [88 rows x 31 columns]

# %%
df = data[data['cluster'].isin([0])]
df
# Out:
#            SIG_CD SIG_KOR_NM       인구수     사망률      고령화비율  전체 가구수  산림면적(ha)  \
# 시군구
# 강원도 삼척시     42230        삼척시   65623.0   964.6  24.495985   31016    104323
# 강원도 영월군     42750        영월군   38345.0  1053.6  28.819924   17175     95389
# 강원도 정선군     42770        정선군   36313.0  1027.2  26.847135   16375    104220
# 강원도 태백시     42190        태백시   42288.0   848.9  23.725407   18688     26855
# 강원도 홍천군     42720        홍천군   68652.0  1091.0  25.489425   29533    151734
# 강원도 횡성군     42730        횡성군   46150.0  1118.1  28.667389   19775     76193
# 경기도 가평군     41820        가평군   61675.0  1060.4  25.363600   26056     69030
# 경기도 연천군     41800        연천군   43104.5  1090.4  25.628415   18368     41162
# 전라남도 영암군    2.190799   13.0   -1.4998   전라남도  25307        0
# 전라남도 장성군    2.922111   11.8   -0.9014   전라남도  17583        0
# 전라북도 남원시   15.320989    9.1   -1.0639   전라북도  34331        0
# 전라북도 정읍시    6.760534    9.5   -1.4792   전라북도  46850        0
# 충청남도 공주시    9.992681   12.5   -1.2480   충청남도  46981        0
# 충청남도 금산군   13.692277   12.6   -1.4977   충청남도  24102        0
# 충청남도 논산시    4.662331   11.4   -1.3538   충청남도  51800        0
# 충청남도 보령시   10.879052   13.6   -0.8888   충청남도  43181        0
# 충청남도 예산군    6.656996   12.7   -1.0158   충청남도  34488        0
# 충청북도 단양군   18.018566   11.6   -1.1236   충청북도  12845        0
# 충청북도 옥천군   63.384428   11.4   -0.8429   충청북도  20937        0
#
# [30 rows x 31 columns]

# %%
df.to_csv('cluster_0s.csv')

# %%
cluster=pd.read_csv('project_result_0.csv')
cluster.set_index('시군구',inplace=True)

# %%
df['cluster']=cluster[['cluster']]
df
# Out:
#            SIG_CD SIG_KOR_NM       인구수     사망률      고령화비율  전체 가구수  산림면적(ha)  \
# 시군구
# 강원도 삼척시     42230        삼척시   65623.0   964.6  24.495985   31016    104323
# 강원도 영월군     42750        영월군   38345.0  1053.6  28.819924   17175     95389
# 강원도 정선군     42770        정선군   36313.0  1027.2  26.847135   16375    104220
# 강원도 태백시     42190        태백시   42288.0   848.9  23.725407   18688     26855
# 강원도 홍천군     42720        홍천군   68652.0  1091.0  25.489425   29533    151734
# 강원도 횡성군     42730        횡성군   46150.0  1118.1  28.667389   19775     76193
# 경기도 가평군     41820        가평군   61675.0  1060.4  25.363600   26056     69030
# 경기도 연천군     41800        연천군   43104.5  1090.4  25.628415   18368     41162
# 경상남도 거창군    48880        거창군   61478.0  1159.8  27.196721   26054     60250
# 경상남도 밀양시    48270        밀양시  104300.5  1131.3  27.733328   46860     51798
# 경상남도 함안군    48730        함안군   64502.0  1003.1  24.196149   27594     20927
# 경상북도 고령군    47830        고령군   31646.5  1317.7  30.790135   13917     24367
# 경상북도 문경시    47280        문경시   71266.5  1202.5  29.558067   30839     70256
# 경상북도 안동시    47170        안동시  158634.0   980.2  24.142996   71424    106975
# 경상북도 영주시    47210        영주시  103452.0  1023.7  26.624908   45970     41154
# 경상북도 영천시    47230        영천시  101506.0  1183.2  27.617087   45647     62185
# 경상북도 울진군    47930        울진군   48710.0  1190.7  27.556970   22006     84811
# 인천광역시 강화군   28710        강화군   68662.0  1316.6  32.371617   28145     17682
# 전라남도 영광군    46870        영광군   52970.0  1238.4  28.686049   22102     20632
# 전라남도 영암군    46830        영암군   53651.0  1137.0  26.241822   25307     22487
# 전라남도 장성군    46880        장성군   44714.5  1183.1  29.314875   17583     31745
# 전라북도 남원시    45190        남원시   80653.5  1232.4  27.616904   34331     46955
# 전라북도 정읍시    45180        정읍시  108474.0  1178.2  27.179785   46850     32338
# 충청남도 보령시   63.6   111.7  10.322225  ...   19.47   59.69  43.3527  12.7
# 충청남도 예산군   67.7    93.4   8.210422  ...   18.65   42.86  26.3595  15.1
# 충청북도 단양군   66.1    32.6   7.480355  ...   16.35   58.18   2.3648  15.2
# 충청북도 옥천군   63.2    56.4   9.037137  ...   19.86   50.54  12.7339  11.7
#
#            산지면적/도시면적  재정자립도  연평균인구증감률     시도   총가구수  cluster
# 시군구
# 강원도 삼척시    13.059622   13.5   -1.6028    강원도  31016        0
# 강원도 영월군    36.154246   15.2   -0.8921    강원도  17175        2
# 강원도 정선군    24.497452   21.5   -1.2152    강원도  16375        2
# 강원도 태백시     4.035657   18.5   -2.3956    강원도  18688        2
# 강원도 홍천군    49.400297   12.1   -0.2989    강원도  29533        1
# 강원도 횡성군    76.815978   11.4    0.2604    강원도  19775        1
# 경기도 가평군     8.429662   18.0   -0.0284    경기도  26056        2
# 경기도 연천군    13.520074   18.3   -1.3283    경기도  18368        2
# 경상남도 거창군   18.883300    8.9   -0.7209   경상남도  26054        2
# 경상남도 밀양시    8.430431   13.7   -0.8229   경상남도  46860        0
# 경상남도 함안군    5.339079   16.8   -1.7709   경상남도  27594        0
# 경상북도 고령군    7.503611   11.7   -2.1839   경상북도  13917        2
# 경상북도 문경시   18.536812   11.3   -1.1218   경상북도  30839        2
# 경상북도 안동시   13.536444   10.6   -1.4983   경상북도  71424        0
# 경상북도 영주시    8.218751   11.5   -1.4328   경상북도  45970        0
# 경상북도 영천시   10.910319   15.4    0.3695   경상북도  45647        2
# 경상북도 울진군   17.698308   10.7   -1.4934   경상북도  22006        2
# 인천광역시 강화군  10.216911   14.5    0.4357  인천광역시  28145        2
# 전라남도 영광군    4.388256   10.5   -1.1520   전라남도  22102        2
# 전라남도 영암군    2.190799   13.0   -1.4998   전라남도  25307        2
# 전라남도 장성군    2.922111   11.8   -0.9014   전라남도  17583        0
# 전라북도 남원시   15.320989    9.1   -1.0639   전라북도  34331        0
# 전라북도 정읍시    6.760534    9.5   -1.4792   전라북도  46850        0
# 충청남도 공주시    9.992681   12.5   -1.2480   충청남도  46981        0
# 충청남도 금산군   13.692277   12.6   -1.4977   충청남도  24102        2
# 충청남도 논산시    4.662331   11.4   -1.3538   충청남도  51800        0
# 충청남도 보령시   10.879052   13.6   -0.8888   충청남도  43181        2
# 충청남도 예산군    6.656996   12.7   -1.0158   충청남도  34488        2
# 충청북도 단양군   18.018566   11.6   -1.1236   충청북도  12845        0
# 충청북도 옥천군   63.384428   11.4   -0.8429   충청북도  20937        1
#
# [30 rows x 31 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

sns.scatterplot(x='산림면적(ha)', y='터널수', hue='cluster', style='cluster', s=60,data=df)

#df.reset_index(inplace=True)
#for i in range(len(df)):
#    row=df.iloc[i]
#    name=row['시군구']
#    x = row['산림면적(ha)']
#    y = row['터널수']
#    plt.text(x-0.5, y, name, fontsize=8)
#df.set_index('시군구', inplace=True)

plt.title('인구감소지역 산림면적 당 터널 수_3군집')
plt.xlabel('산림면적(ha)')
plt.ylabel('터널 수')
plt.legend(fontsize=6)
plt.savefig('output/oph_total_0.png', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

sns.scatterplot(x='산림면적(ha)', y='터널수',s=60,data=df)

df.reset_index(inplace=True)
for i in range(len(df)):
    row=df.iloc[i]
    name=row['시군구']
    x = row['산림면적(ha)']
    y = row['터널수']
    plt.text(x-0.5, y, name, fontsize=8)
df.set_index('시군구', inplace=True)

plt.title('인구감소지역 산림면적 당 터널 수_3군집')
plt.xlabel('산림면적(ha)')
plt.ylabel('터널 수')
plt.legend(fontsize=6)
plt.savefig('output/oph_total_0.png', bbox_inches='tight')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

sns.scatterplot(x='총가구수', y='1인 가구비율',s=60,data=df)

df.reset_index(inplace=True)
for i in range(len(df)):
    row=df.iloc[i]
    name=row['시군구']
    x = row['총가구수']
    y = row['1인 가구비율']
    plt.text(x-0.5, y, name, fontsize=8)
df.set_index('시군구', inplace=True)

plt.title('인구감소지역 1인 가구 비율_3군집')
plt.xlabel('총 가구수')
plt.ylabel('1인 가구 비율')
plt.legend(fontsize=6)
plt.savefig('output/oph_total_0.png', bbox_inches='tight')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

sns.scatterplot(x='인구수', y='만명 당 의료기관 수',s=60,data=df)

df.reset_index(inplace=True)
for i in range(len(df)):
    row=df.iloc[i]
    name=row['시군구']
    x = row['인구수']
    y = row['만명 당 의료기관 수']
    plt.text(x-0.5, y-0.5, name, fontsize=8)
df.set_index('시군구', inplace=True)

plt.title('인구감소지역 전체 병원/인구수 비율, 1 만명 당_3군집')
plt.xlabel('인구수')
plt.ylabel('전체 병원/인구수 비율')
plt.legend(fontsize=6)
plt.savefig('output/hs_total_0.png', bbox_inches='tight')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

sns.scatterplot(x='경제활동인구', y='고용률',s=60,data=df)

df.reset_index(inplace=True)
for i in range(len(df)):
    row=df.iloc[i]
    name=row['시군구']
    x = row['경제활동인구']
    y = row['고용률']
    plt.text(x-0.5, y-0.5, name, fontsize=8)
df.set_index('시군구', inplace=True)

plt.title('인구감소지역 고용률_3군집')
plt.xlabel('경제활동인구')
plt.ylabel('고용률')
plt.legend(fontsize=6)
plt.savefig('output/emp_rate_0.png', bbox_inches='tight')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

sns.scatterplot(x='인구수', y='사망률',s=60,data=df)

df.reset_index(inplace=True)
for i in range(len(df)):
    row=df.iloc[i]
    name=row['시군구']
    x = row['인구수']
    y = row['사망률']
    plt.text(x-0.5, y-0.5, name, fontsize=8)
df.set_index('시군구', inplace=True)

plt.title('인구감소지역 사망률_3군집')
plt.xlabel('인구수')
plt.ylabel('사망률')
plt.legend(fontsize=6)
plt.savefig('output/death_rate_0.png', bbox_inches='tight')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

sns.scatterplot(x='인구수', y='조출생률',s=60,data=df)

df.reset_index(inplace=True)
for i in range(len(df)):
    row=df.iloc[i]
    name=row['시군구']
    x = row['인구수']
    y = row['조출생률']
    plt.text(x-0.5, y-0.5, name, fontsize=8)
df.set_index('시군구', inplace=True)

plt.title('인구감소지역 조출산률_3군집')
plt.xlabel('인구수')
plt.ylabel('조출산률')
plt.legend(fontsize=6)
plt.savefig('output/birth_rate_0.png', bbox_inches='tight')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

sns.scatterplot(x='인구수', y='고령화비율',s=60,data=df)

df.reset_index(inplace=True)
for i in range(len(df)):
    row=df.iloc[i]
    name=row['시군구']
    x = row['인구수']
    y = row['고령화비율']
    plt.text(x-0.5, y-0.5, name, fontsize=8)
df.set_index('시군구', inplace=True)

plt.title('인구감소지역 고령화비율_3군집')
plt.xlabel('인구수')
plt.ylabel('고령화비율')
plt.legend(fontsize=6)
plt.savefig('output/aging_rate_0.png', bbox_inches='tight')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

sns.scatterplot(x='인구수', y='만명당 매장 수',s=60,data=df)

df.reset_index(inplace=True)
for i in range(len(df)):
    row=df.iloc[i]
    name=row['시군구']
    x = row['인구수']
    y = row['만명당 매장 수']
    plt.text(x-0.5, y, name, fontsize=8)
df.set_index('시군구', inplace=True)

plt.title('인구감소지역 뚜레쥬르-파리바게트 매장 비율, 1만명 당_3군집')
plt.xlabel('인구수')
plt.ylabel('매장 수/인구수')
plt.legend(fontsize=6)
plt.savefig('output/bakery_0.png', bbox_inches='tight')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
