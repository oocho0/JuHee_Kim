# %% [markdown]
# ## 유소년비율
# - 자료출처
# <br>통계청,「인구동향조사」, 2021, 2022.12.20, 시군구/성/연령(5세)별 주민등록연앙인구

# %%
import pandas as pd

under14_pop=pd.read_csv('./under14_pop.csv')
total_pop=pd.read_csv('../total_pop/total_pop.csv')
pop_89 = pd.read_csv('../total_pop/pop_89.csv')
sig_cd = pd.read_csv('../total_pop/sig_cd.csv')
under14_pop
# Out:
#      행정구역(시군구)별  youth_2016  youth_2017  youth_2018  youth_2019  youth_2020
# 0      부산광역시 중구      3322.0        3068        2774        2510        2284
# 1      부산광역시 서구      9918.0        9489        9354        9189        8989
# 2      부산광역시 동구      7188.5        6813        6506        6332        6338
# 3     부산광역시 영도구     11269.0       10652       10053        9433        8825
# 4    부산광역시 부산진구     39603.5       38069       36385       34654       33445
# ..          ...         ...         ...         ...         ...         ...
# 217    경상남도 하동군      4271.5        4028        3843        3643        3361
# 218    경상남도 산청군      2983.0        2897        2806        2645        2436
# 219    경상남도 함양군      3955.0        3747        3601        3443        3272
# 220    경상남도 거창군      7268.5        7098        6931        6741        6468
# 221    경상남도 합천군      3614.0        3348        3137        2972        2812
#
# [222 rows x 6 columns]

# %%
total_pop
# Out:
#      행정구역(시군구)별  total_2016  total_2017  total_2018  total_2019  total_2020
# 0      부산광역시 중구     44191.5     43386.0     42206.5     41066.5     40445.5
# 1      부산광역시 서구    112041.5    109135.5    107981.5    107094.5    105948.0
# 2      부산광역시 동구     89046.5     87490.5     86074.5     85757.0     86801.0
# 3     부산광역시 영도구    125772.5    122860.5    119749.5    116364.5    113042.5
# 4    부산광역시 부산진구    373849.5    368927.5    361954.5    355134.5    354107.5
# ..          ...         ...         ...         ...         ...         ...
# 217    경상남도 하동군     49639.5     48933.0     47890.0     46756.0     45389.5
# 218    경상남도 산청군     35772.0     35918.5     35853.0     35389.5     34845.0
# 219    경상남도 함양군     39952.0     39870.0     39778.0     39519.0     39045.0
# 220    경상남도 거창군     62894.5     62656.5     62244.5     61957.5     61478.0
# 221    경상남도 합천군     48109.0     47048.5     46005.5     45111.5     44159.5
#
# [222 rows x 6 columns]

# %%
under14_pop.rename(columns={'행정구역(시군구)별':'sigungu'}, inplace=True)
under14_pop.set_index('sigungu', inplace=True)
under14_pop.sort_index(inplace=True)
under14_pop
# Out:
#           youth_2016  youth_2017  youth_2018  youth_2019  youth_2020
# sigungu
# 강원도 강릉시      25745.0       24831       23960       23182       22556
# 강원도 고성군       2539.0        2451        2282        2125        2044
# 강원도 동해시      12714.0       12285       11833       11317       10933
# 강원도 삼척시       7363.0        7028        6784        6618        6352
# 강원도 속초시      10482.0       10047        9709        9443        9318
# ...              ...         ...         ...         ...         ...
# 충청북도 증평군      5703.5        5713        5585        5381        5128
# 충청북도 진천군      9873.5       10246       10946       11547       11836
# 충청북도 청원구     31746.5       32657       32684       32202       31054
# 충청북도 충주시     25960.5       25244       24855       24541       24001
# 충청북도 흥덕구     39249.5       38106       37161       37036       37304
#
# [222 rows x 5 columns]

# %%
under14_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 222 entries, 강원도 강릉시 to 충청북도 흥덕구
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   youth_2016  222 non-null    float64
#  1   youth_2017  222 non-null    int64
#  2   youth_2018  222 non-null    int64
#  3   youth_2019  222 non-null    int64
#  4   youth_2020  222 non-null    int64
# dtypes: float64(1), int64(4)
# memory usage: 10.4+ KB

# %%
total_pop.rename(columns={'행정구역(시군구)별':'sigungu'}, inplace=True)
total_pop.set_index('sigungu', inplace=True)
total_pop.sort_index(inplace=True)
total_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 222 entries, 강원도 강릉시 to 충청북도 흥덕구
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_2016  222 non-null    float64
#  1   total_2017  222 non-null    float64
#  2   total_2018  222 non-null    float64
#  3   total_2019  222 non-null    float64
#  4   total_2020  222 non-null    float64
# dtypes: float64(5)
# memory usage: 10.4+ KB

# %%
total_pop
# Out:
#           total_2016  total_2017  total_2018  total_2019  total_2020
# sigungu
# 강원도 강릉시     212434.0    212129.0    211716.0    211445.5    211643.0
# 강원도 고성군      29867.0     29855.0     28873.0     27484.0     26791.5
# 강원도 동해시      92854.5     92327.0     91313.5     90147.0     89814.0
# 강원도 삼척시      69481.5     68371.0     67786.5     67156.5     65623.0
# 강원도 속초시      81180.0     81307.5     81248.5     80999.0     81496.5
# ...              ...         ...         ...         ...         ...
# 충청북도 증평군     36808.5     37357.5     37353.5     37148.5     36893.0
# 충청북도 진천군     68446.5     71295.0     75445.5     79174.5     81957.5
# 충청북도 청원구    185558.5    191438.5    194656.0    195690.0    194256.0
# 충청북도 충주시    206784.5    206912.0    207998.5    209230.5    209083.5
# 충청북도 흥덕구    252102.0    252342.0    252741.5    256841.5    262632.0
#
# [222 rows x 5 columns]

# %%
under14_5y_rate=pd.DataFrame({'2016':under14_pop['youth_2016']/total_pop['total_2016']*100})
under14_5y_rate['2017']=under14_pop['youth_2017']/total_pop['total_2017']*100
under14_5y_rate['2018']=under14_pop['youth_2018']/total_pop['total_2018']*100
under14_5y_rate['2019']=under14_pop['youth_2019']/total_pop['total_2019']*100
under14_5y_rate['2020']=under14_pop['youth_2020']/total_pop['total_2020']*100
under14_5y_rate
# Out:
#                2016       2017       2018       2019       2020
# sigungu
# 강원도 강릉시   12.119058  11.705613  11.317047  10.963582  10.657570
# 강원도 고성군    8.501021   8.209680   7.903578   7.731771   7.629285
# 강원도 동해시   13.692390  13.305967  12.958653  12.553940  12.172935
# 강원도 삼척시   10.597065  10.279212  10.007892   9.854593   9.679533
# 강원도 속초시   12.912047  12.356794  11.949759  11.658169  11.433620
# ...             ...        ...        ...        ...        ...
# 충청북도 증평군  15.495062  15.292779  14.951745  14.485107  13.899656
# 충청북도 진천군  14.425135  14.371274  14.508486  14.584241  14.441631
# 충청북도 청원구  17.108621  17.058742  16.790646  16.455619  15.986121
# 충청북도 충주시  12.554374  12.200356  11.949605  11.729170  11.479146
# 충청북도 흥덕구  15.568897  15.100934  14.703165  14.419788  14.203905
#
# [222 rows x 5 columns]

# %%
under14_rate=pd.DataFrame({'2020':under14_pop['youth_2020']})
under14_rate
# Out:
#            2020
# sigungu
# 강원도 강릉시   22556
# 강원도 고성군    2044
# 강원도 동해시   10933
# 강원도 삼척시    6352
# 강원도 속초시    9318
# ...         ...
# 충청북도 증평군   5128
# 충청북도 진천군  11836
# 충청북도 청원구  31054
# 충청북도 충주시  24001
# 충청북도 흥덕구  37304
#
# [222 rows x 1 columns]

# %%
under14_rate['pop']=total_pop[['total_2020']]
under14_rate['인구감소지수 분류']='안심지역'
under14_rate['rate']=under14_rate['2020']/under14_rate['pop']*100

# %%
under14_rate
# Out:
#            2020       pop 인구감소지수 분류       rate
# sigungu
# 강원도 강릉시   22556  211643.0      안심지역  10.657570
# 강원도 고성군    2044   26791.5      안심지역   7.629285
# 강원도 동해시   10933   89814.0      안심지역  12.172935
# 강원도 삼척시    6352   65623.0      안심지역   9.679533
# 강원도 속초시    9318   81496.5      안심지역  11.433620
# ...         ...       ...       ...        ...
# 충청북도 증평군   5128   36893.0      안심지역  13.899656
# 충청북도 진천군  11836   81957.5      안심지역  14.441631
# 충청북도 청원구  31054  194256.0      안심지역  15.986121
# 충청북도 충주시  24001  209083.5      안심지역  11.479146
# 충청북도 흥덕구  37304  262632.0      안심지역  14.203905
#
# [222 rows x 4 columns]

# %%
ingu_89 = ['부산광역시 동구', '부산광역시 서구', '부산광역시 영도구', '대구광역시 남구', '대구광역시 서구',
           '인천광역시 강화군', '인천광역시 옹진군', '경기도 가평군', '경기도 연천군', '강원도 고성군', '강원도 삼척시',
          '강원도 양구군', '강원도 양양군', '강원도 영월군', '강원도 정선군', '강원도 철원군', '강원도 태백시',
          '강원도 평창군', '강원도 홍천군', '강원도 화천군', '강원도 횡성군', '충청북도 괴산군', '충청북도 단양군',
          '충청북도 보은군', '충청북도 영동군', '충청북도 옥천군', '충청북도 제천시', '충청남도 공주시', '충청남도 금산군',
          '충청남도 논산시', '충청남도 보령시', '충청남도 부여군', '충청남도 서천군', '충청남도 예산군', '충청남도 청양군',
          '충청남도 태안군', '전라북도 고창군', '전라북도 김제시', '전라북도 남원시', '전라북도 무주군', '전라북도 부안군',
          '전라북도 순창군', '전라북도 임실군', '전라북도 장수군', '전라북도 정읍시', '전라북도 진안군', '전라남도 강진군',
          '전라남도 고흥군', '전라남도 곡성군', '전라남도 구례군', '전라남도 담양군', '전라남도 보성군', '전라남도 신안군',
          '전라남도 영광군', '전라남도 영암군', '전라남도 완도군', '전라남도 장성군', '전라남도 장흥군', '전라남도 진도군',
          '전라남도 함평군', '전라남도 해남군', '전라남도 화순군', '경상북도 고령군', '경상북도 군위군', '경상북도 문경시',
          '경상북도 봉화군', '경상북도 상주시', '경상북도 성주군', '경상북도 안동시', '경상북도 영덕군', '경상북도 영양군',
          '경상북도 영주시', '경상북도 영천시', '경상북도 울릉군', '경상북도 울진군', '경상북도 의성군', '경상북도 청도군',
          '경상북도 청송군', '경상남도 거창군', '경상남도 고성군', '경상남도 남해군', '경상남도 밀양시', '경상남도 산청군',
          '경상남도 의령군', '경상남도 창녕군', '경상남도 하동군', '경상남도 함안군', '경상남도 함양군', '경상남도 합천군']

# %%
semi_18 = ['대전광역시 동구','인천광역시 동구','부산광역시 중구','부산광역시 금정구','광주광역시 동구','경상남도 통영시',
           '강원도 강릉시','강원도 동해시','대전광역시 중구','경상북도 경주시','경상남도 사천시', '경상북도 김천시',
          '대전광역시 대덕구','강원도 인제군','전라북도 익산시','경기도 동두천시','강원도 속초시','경기도 포천시']

# %%
for i in ingu_89 :
    under14_rate.loc[i,'인구감소지수 분류'] = '인구감소지역'
    
for i in semi_18 :
    under14_rate.loc[i,'인구감소지수 분류'] = '관심지역'

under14_rate
# Out:
#            2020       pop 인구감소지수 분류       rate
# sigungu
# 강원도 강릉시   22556  211643.0      관심지역  10.657570
# 강원도 고성군    2044   26791.5    인구감소지역   7.629285
# 강원도 동해시   10933   89814.0      관심지역  12.172935
# 강원도 삼척시    6352   65623.0    인구감소지역   9.679533
# 강원도 속초시    9318   81496.5      관심지역  11.433620
# ...         ...       ...       ...        ...
# 충청북도 증평군   5128   36893.0      안심지역  13.899656
# 충청북도 진천군  11836   81957.5      안심지역  14.441631
# 충청북도 청원구  31054  194256.0      안심지역  15.986121
# 충청북도 충주시  24001  209083.5      안심지역  11.479146
# 충청북도 흥덕구  37304  262632.0      안심지역  14.203905
#
# [222 rows x 4 columns]

# %%
under14_rate['인구감소지수 분류']=under14_rate['인구감소지수 분류']
under14_rate
# Out:
#            2020       pop 인구감소지수 분류       rate
# sigungu
# 강원도 강릉시   22556  211643.0      관심지역  10.657570
# 강원도 고성군    2044   26791.5    인구감소지역   7.629285
# 강원도 동해시   10933   89814.0      관심지역  12.172935
# 강원도 삼척시    6352   65623.0    인구감소지역   9.679533
# 강원도 속초시    9318   81496.5      관심지역  11.433620
# ...         ...       ...       ...        ...
# 충청북도 증평군   5128   36893.0      안심지역  13.899656
# 충청북도 진천군  11836   81957.5      안심지역  14.441631
# 충청북도 청원구  31054  194256.0      안심지역  15.986121
# 충청북도 충주시  24001  209083.5      안심지역  11.479146
# 충청북도 흥덕구  37304  262632.0      안심지역  14.203905
#
# [222 rows x 4 columns]

# %%
under14_89 = under14_rate[under14_rate['인구감소지수 분류'].isin(['인구감소지역'])]
under14_89
# Out:
#            2020       pop 인구감소지수 분류       rate
# sigungu
# 강원도 고성군    2044   26791.5    인구감소지역   7.629285
# 강원도 삼척시    6352   65623.0    인구감소지역   9.679533
# 강원도 양구군    2649   22379.0    인구감소지역  11.836990
# 강원도 양양군    2206   27627.5    인구감소지역   7.984798
# 강원도 영월군    2899   38345.0    인구감소지역   7.560308
# ...         ...       ...       ...        ...
# 충청북도 단양군   2180   29143.0    인구감소지역   7.480355
# 충청북도 보은군   2493   32402.5    인구감소지역   7.693851
# 충청북도 영동군   3982   47736.5    인구감소지역   8.341625
# 충청북도 옥천군   4553   50381.0    인구감소지역   9.037137
# 충청북도 제천시  14523  132882.5    인구감소지역  10.929204
#
# [89 rows x 4 columns]

# %%
under14_5y_rate['total_2016']=total_pop['total_2016']
under14_5y_rate['total_2017']=total_pop['total_2017']
under14_5y_rate['total_2018']=total_pop['total_2018']
under14_5y_rate['total_2019']=total_pop['total_2019']
under14_5y_rate['total_2020']=total_pop['total_2020']
under14_5y_rate['인구감소지수 분류']=under14_rate['인구감소지수 분류']
under14_5y_rate
# Out:
#                2016       2017       2018       2019       2020  total_2017  \
# sigungu
# 강원도 강릉시   12.119058  11.705613  11.317047  10.963582  10.657570    212129.0
# 강원도 고성군    8.501021   8.209680   7.903578   7.731771   7.629285     29855.0
# 강원도 동해시   13.692390  13.305967  12.958653  12.553940  12.172935     92327.0
# 강원도 삼척시   10.597065  10.279212  10.007892   9.854593   9.679533     68371.0
# 강원도 속초시   12.912047  12.356794  11.949759  11.658169  11.433620     81307.5
# ...             ...        ...        ...        ...        ...         ...
# 충청북도 증평군  15.495062  15.292779  14.951745  14.485107  13.899656     37357.5
# 충청북도 진천군  14.425135  14.371274  14.508486  14.584241  14.441631     71295.0
# 충청북도 청원구  17.108621  17.058742  16.790646  16.455619  15.986121    191438.5
# 충청북도 충주시  12.554374  12.200356  11.949605  11.729170  11.479146    206912.0
# 충청북도 흥덕구  15.568897  15.100934  14.703165  14.419788  14.203905    252342.0
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rc

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='darkgrid')

sns.scatterplot(x='total_2020', 
                y='2020', 
                hue='인구감소지수 분류', # different colors by group
                style='인구감소지수 분류', # different shapes by group
                s=80, # marker size
                data=under14_5y_rate)

plt.title('2020년 유소년 비율')
plt.xlabel('인구수')
plt.ylabel('유소년 비율')

plt.savefig('output/under14_rate_2020.png')
plt.show()

# %%
under14_89.to_csv('under14_rate_result.csv')

# %%
under14_18 = under14_rate[under14_rate['인구감소지수 분류'].isin(['관심지역'])]
under14_18

# %%
under14_non = under14_rate[under14_rate['인구감소지수 분류'].isin(['안심지역'])]
under14_non
# Out:
#            2020       pop 인구감소지수 분류       rate
# sigungu
# 강원도 원주시   45939  349361.0      안심지역  13.149436
# 강원도 춘천시   34726  279744.5      안심지역  12.413470
# 경기도 과천시    7744   59890.5      안심지역  12.930264
# 경기도 광명시   39586  304481.0      안심지역  13.001140
# 경기도 광주시   52343  374978.5      안심지역  13.958934
# ...         ...       ...       ...        ...
# 충청북도 증평군   5128   36893.0      안심지역  13.899656
# 충청북도 진천군  11836   81957.5      안심지역  14.441631
# 충청북도 청원구  31054  194256.0      안심지역  15.986121
# 충청북도 충주시  24001  209083.5      안심지역  11.479146
# 충청북도 흥덕구  37304  262632.0      안심지역  14.203905
#
# [115 rows x 4 columns]

# %%
under14_mean = pd.DataFrame({'인구감소지역':under14_89.mean()})
under14_mean['관심지역']=under14_18.mean()
under14_mean['안심지역']=under14_non.mean()
#under14_mean['전국']=under14_rate.mean()
under14_mean
# Out:
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_1380/2572496780.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   under14_mean = pd.DataFrame({'인구감소지역':under14_89.mean()})
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_1380/2572496780.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   under14_mean['관심지역']=under14_18.mean()
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_1380/2572496780.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# ...

# %%
df=under14_mean.plot(kind='bar')

plt.title('5년간 유소년 비율의 변화')

plt.xticks(rotation=0)
plt.xlabel('연도')
plt.ylabel(' 비율의 평균')
lgd=df.legend(bbox_to_anchor=(1,1))

plt.savefig('output/under14_5years_mean_bar.png',bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()

# %%
under14_5y_rate
# Out:
#                2016       2017       2018       2019       2020  total_2017  \
# sigungu
# 강원도 강릉시   12.119058  11.705613  11.317047  10.963582  10.657570    212129.0
# 강원도 고성군    8.501021   8.209680   7.903578   7.731771   7.629285     29855.0
# 강원도 동해시   13.692390  13.305967  12.958653  12.553940  12.172935     92327.0
# 강원도 삼척시   10.597065  10.279212  10.007892   9.854593   9.679533     68371.0
# 강원도 속초시   12.912047  12.356794  11.949759  11.658169  11.433620     81307.5
# ...             ...        ...        ...        ...        ...         ...
# 충청북도 증평군  15.495062  15.292779  14.951745  14.485107  13.899656     37357.5
# 충청북도 진천군  14.425135  14.371274  14.508486  14.584241  14.441631     71295.0
# 충청북도 청원구  17.108621  17.058742  16.790646  16.455619  15.986121    191438.5
# 충청북도 충주시  12.554374  12.200356  11.949605  11.729170  11.479146    206912.0
# 충청북도 흥덕구  15.568897  15.100934  14.703165  14.419788  14.203905    252342.0
#
# ...

# %%
fy_mean = pd.DataFrame(under14_5y_rate.mean())
fy_mean.rename({'0':'mean'},inplace=True)
fy_mean=fy_mean.T
fy_mean
# Out:
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_1380/667982526.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   fy_mean = pd.DataFrame(under14_5y_rate.mean())
#        2016       2017       2018       2019       2020     total_2017  \
# 0  12.48692  12.168081  11.853383  11.522088  11.198745  182890.563063
#
#      total_2018     total_2019     total_2020     total_2016
# 0  183357.20045  183642.864865  183790.581081  182197.846847

# %%
plt.style.use('ggplot')
fig=plt.figure(figsize=(8,5))
ax=fig.add_subplot(1,1,1)

ax.plot(under14_mean['인구감소지역'],marker='o',markerfacecolor='#ff5050',markersize=8,color='#ff5050',label='인구감소지수 분류')
ax.plot(under14_mean['관심지역'],marker='o',markerfacecolor='orange',markersize=8,color='orange',label='관심지역')
ax.plot(under14_mean['안심지역'],marker='o',markerfacecolor='#00ccff',markersize=8,color='#00ccff',label='안심지역')
#ax.plot(under14_mean['전국'],marker='o',markerfacecolor='indigo',markersize=8,color='skyblue',label='전국')

ax.legend(loc='best')

ax.set_title('5년간 유소년 비율의 변화')

ax.set_ylabel('유소년 비율의 평균')
ax.set_xlabel('연도')


plt.savefig('output/under14_5years_mean_line.png')
plt.show()
