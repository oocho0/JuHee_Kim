# %% [markdown]
# ## 유소년비율
# - 자료출처
# <br>통계청,「인구동향조사」, 2021, 2022.12.20, 시군구/성/연령(5세)별 주민등록연앙인구

# %%
import pandas as pd

under14_pop=pd.read_csv('./under14_pop.csv')
total_pop=pd.read_csv('../total_pop/total_pop.csv')
under14_pop
# Out:
#        행정구역(시군구)별  youth_2016  youth_2017  youth_2018  youth_2019  youth_2020
# 0      부산광역시 > 중구      3322.0        3068        2774        2510        2284
# 1      부산광역시 > 서구      9918.0        9489        9354        9189        8989
# 2      부산광역시 > 동구      7188.5        6813        6506        6332        6338
# 3     부산광역시 > 영도구     11269.0       10652       10053        9433        8825
# 4    부산광역시 > 부산진구     39603.5       38069       36385       34654       33445
# ..            ...         ...         ...         ...         ...         ...
# 217    경상남도 > 하동군      4271.5        4028        3843        3643        3361
# 218    경상남도 > 산청군      2983.0        2897        2806        2645        2436
# 219    경상남도 > 함양군      3955.0        3747        3601        3443        3272
# 220    경상남도 > 거창군      7268.5        7098        6931        6741        6468
# 221    경상남도 > 합천군      3614.0        3348        3137        2972        2812
#
# [222 rows x 6 columns]

# %%
total_pop
# Out:
#        행정구역(시군구)별  total_2016  total_2017  total_2018  total_2019  total_2020
# 0      부산광역시 > 중구     44191.5     43386.0     42206.5     41066.5     40445.5
# 1      부산광역시 > 서구    112041.5    109135.5    107981.5    107094.5    105948.0
# 2      부산광역시 > 동구     89046.5     87490.5     86074.5     85757.0     86801.0
# 3     부산광역시 > 영도구    125772.5    122860.5    119749.5    116364.5    113042.5
# 4    부산광역시 > 부산진구    373849.5    368927.5    361954.5    355134.5    354107.5
# ..            ...         ...         ...         ...         ...         ...
# 217    경상남도 > 하동군     49639.5     48933.0     47890.0     46756.0     45389.5
# 218    경상남도 > 산청군     35772.0     35918.5     35853.0     35389.5     34845.0
# 219    경상남도 > 함양군     39952.0     39870.0     39778.0     39519.0     39045.0
# 220    경상남도 > 거창군     62894.5     62656.5     62244.5     61957.5     61478.0
# 221    경상남도 > 합천군     48109.0     47048.5     46005.5     45111.5     44159.5
#
# [222 rows x 6 columns]

# %%
under14_pop.rename(columns={'행정구역(시군구)별':'sigungu',
                           'youth_2016':'2016',
                           'youth_2017':'2017',
                           'youth_2018':'2018',
                           'youth_2019':'2019',
                           'youth_2020':'2020'}, inplace=True)
under14_pop.set_index('sigungu', inplace=True)
under14_pop.sort_index(inplace=True)
under14_pop
# Out:
#                2016   2017   2018   2019   2020
# sigungu
# 강원도 > 강릉시   25745.0  24831  23960  23182  22556
# 강원도 > 고성군    2539.0   2451   2282   2125   2044
# 강원도 > 동해시   12714.0  12285  11833  11317  10933
# 강원도 > 삼척시    7363.0   7028   6784   6618   6352
# 강원도 > 속초시   10482.0  10047   9709   9443   9318
# ...             ...    ...    ...    ...    ...
# 충청북도 > 증평군   5703.5   5713   5585   5381   5128
# 충청북도 > 진천군   9873.5  10246  10946  11547  11836
# 충청북도 > 청원구  31746.5  32657  32684  32202  31054
# 충청북도 > 충주시  25960.5  25244  24855  24541  24001
# 충청북도 > 흥덕구  39249.5  38106  37161  37036  37304
#
# [222 rows x 5 columns]

# %%
under14_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 222 entries, 강원도 > 강릉시 to 충청북도 > 흥덕구
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2016    222 non-null    float64
#  1   2017    222 non-null    int64
#  2   2018    222 non-null    int64
#  3   2019    222 non-null    int64
#  4   2020    222 non-null    int64
# dtypes: float64(1), int64(4)
# memory usage: 10.4+ KB

# %%
total_pop.rename(columns={'행정구역(시군구)별':'sigungu',
                           'total_2016':'2016',
                           'total_2017':'2017',
                           'total_2018':'2018',
                           'total_2019':'2019',
                           'total_2020':'2020'}, inplace=True)
total_pop.set_index('sigungu', inplace=True)
total_pop.sort_index(inplace=True)
total_pop
# Out:
#                 2016      2017      2018      2019      2020
# sigungu
# 강원도 > 강릉시   212434.0  212129.0  211716.0  211445.5  211643.0
# 강원도 > 고성군    29867.0   29855.0   28873.0   27484.0   26791.5
# 강원도 > 동해시    92854.5   92327.0   91313.5   90147.0   89814.0
# 강원도 > 삼척시    69481.5   68371.0   67786.5   67156.5   65623.0
# 강원도 > 속초시    81180.0   81307.5   81248.5   80999.0   81496.5
# ...              ...       ...       ...       ...       ...
# 충청북도 > 증평군   36808.5   37357.5   37353.5   37148.5   36893.0
# 충청북도 > 진천군   68446.5   71295.0   75445.5   79174.5   81957.5
# 충청북도 > 청원구  185558.5  191438.5  194656.0  195690.0  194256.0
# 충청북도 > 충주시  206784.5  206912.0  207998.5  209230.5  209083.5
# 충청북도 > 흥덕구  252102.0  252342.0  252741.5  256841.5  262632.0
#
# [222 rows x 5 columns]

# %%
total_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 222 entries, 강원도 > 강릉시 to 충청북도 > 흥덕구
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2016    222 non-null    float64
#  1   2017    222 non-null    float64
#  2   2018    222 non-null    float64
#  3   2019    222 non-null    float64
#  4   2020    222 non-null    float64
# dtypes: float64(5)
# memory usage: 10.4+ KB

# %%
under14_rate=under14_pop/total_pop*100
under14_rate['인구감소지수 분류']='안심지역'

# %%
ingu_89 = ['부산광역시 > 동구', '부산광역시 > 서구', '부산광역시 > 영도구', '대구광역시 > 남구', '대구광역시 > 서구',
           '인천광역시 > 강화군', '인천광역시 > 옹진군', '경기도 > 가평군', '경기도 > 연천군', '강원도 > 고성군', '강원도 > 삼척시',
          '강원도 > 양구군', '강원도 > 양양군', '강원도 > 영월군', '강원도 > 정선군', '강원도 > 철원군', '강원도 > 태백시',
          '강원도 > 평창군', '강원도 > 홍천군', '강원도 > 화천군', '강원도 > 횡성군', '충청북도 > 괴산군', '충청북도 > 단양군',
          '충청북도 > 보은군', '충청북도 > 영동군', '충청북도 > 옥천군', '충청북도 > 제천시', '충청남도 > 공주시', '충청남도 > 금산군',
          '충청남도 > 논산시', '충청남도 > 보령시', '충청남도 > 부여군', '충청남도 > 서천군', '충청남도 > 예산군', '충청남도 > 청양군',
          '충청남도 > 태안군', '전라북도 > 고창군', '전라북도 > 김제시', '전라북도 > 남원시', '전라북도 > 무주군', '전라북도 > 부안군',
          '전라북도 > 순창군', '전라북도 > 임실군', '전라북도 > 장수군', '전라북도 > 정읍시', '전라북도 > 진안군', '전라남도 > 강진군',
          '전라남도 > 고흥군', '전라남도 > 곡성군', '전라남도 > 구례군', '전라남도 > 담양군', '전라남도 > 보성군', '전라남도 > 신안군',
          '전라남도 > 영광군', '전라남도 > 영암군', '전라남도 > 완도군', '전라남도 > 장성군', '전라남도 > 장흥군', '전라남도 > 진도군',
          '전라남도 > 함평군', '전라남도 > 해남군', '전라남도 > 화순군', '경상북도 > 고령군', '경상북도 > 군위군', '경상북도 > 문경시',
          '경상북도 > 봉화군', '경상북도 > 상주시', '경상북도 > 성주군', '경상북도 > 안동시', '경상북도 > 영덕군', '경상북도 > 영양군',
          '경상북도 > 영주시', '경상북도 > 영천시', '경상북도 > 울릉군', '경상북도 > 울진군', '경상북도 > 의성군', '경상북도 > 청도군',
          '경상북도 > 청송군', '경상남도 > 거창군', '경상남도 > 고성군', '경상남도 > 남해군', '경상남도 > 밀양시', '경상남도 > 산청군',
          '경상남도 > 의령군', '경상남도 > 창녕군', '경상남도 > 하동군', '경상남도 > 함안군', '경상남도 > 함양군', '경상남도 > 합천군']

# %%
semi_18 = ['대전광역시 > 동구','인천광역시 > 동구','부산광역시 > 중구','부산광역시 > 금정구','광주광역시 > 동구','경상남도 > 통영시',
           '강원도 > 강릉시','강원도 > 동해시','대전광역시 > 중구','경상북도 > 경주시','경상남도 > 사천시', '경상북도 > 김천시',
          '대전광역시 > 대덕구','강원도 > 인제군','전라북도 > 익산시','경기도 > 동두천시','강원도 > 속초시','경기도 > 포천시']

# %%
for i in ingu_89 :
    under14_rate.loc[i,'인구감소지수 분류'] = '인구감소지역'
    
for i in semi_18 :
    under14_rate.loc[i,'인구감소지수 분류'] = '관심지역'

under14_rate
# Out:
#                  2016       2017       2018       2019       2020 인구감소지수 분류
# sigungu
# 강원도 > 강릉시   12.119058  11.705613  11.317047  10.963582  10.657570      관심지역
# 강원도 > 고성군    8.501021   8.209680   7.903578   7.731771   7.629285    인구감소지역
# 강원도 > 동해시   13.692390  13.305967  12.958653  12.553940  12.172935      관심지역
# 강원도 > 삼척시   10.597065  10.279212  10.007892   9.854593   9.679533    인구감소지역
# 강원도 > 속초시   12.912047  12.356794  11.949759  11.658169  11.433620      관심지역
# ...               ...        ...        ...        ...        ...       ...
# 충청북도 > 증평군  15.495062  15.292779  14.951745  14.485107  13.899656      안심지역
# 충청북도 > 진천군  14.425135  14.371274  14.508486  14.584241  14.441631      안심지역
# 충청북도 > 청원구  17.108621  17.058742  16.790646  16.455619  15.986121      안심지역
# 충청북도 > 충주시  12.554374  12.200356  11.949605  11.729170  11.479146      안심지역
# 충청북도 > 흥덕구  15.568897  15.100934  14.703165  14.419788  14.203905      안심지역
#
# [222 rows x 6 columns]

# %%
under14_rate_g = pd.DataFrame(under14_rate['2020'])
under14_rate_g['total_2020']=total_pop['2020']
under14_rate_g['인구감소지수 분류']=under14_rate['인구감소지수 분류']
under14_rate_g
# Out:
#                  2020  total_2020 인구감소지수 분류
# sigungu
# 강원도 > 강릉시   10.657570    211643.0      관심지역
# 강원도 > 고성군    7.629285     26791.5    인구감소지역
# 강원도 > 동해시   12.172935     89814.0      관심지역
# 강원도 > 삼척시    9.679533     65623.0    인구감소지역
# 강원도 > 속초시   11.433620     81496.5      관심지역
# ...               ...         ...       ...
# 충청북도 > 증평군  13.899656     36893.0      안심지역
# 충청북도 > 진천군  14.441631     81957.5      안심지역
# 충청북도 > 청원구  15.986121    194256.0      안심지역
# 충청북도 > 충주시  11.479146    209083.5      안심지역
# 충청북도 > 흥덕구  14.203905    262632.0      안심지역
#
# [222 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rc

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='darkgrid')

sns.scatterplot(x='total_2020', 
                y='2020', 
                hue='인구감소지수 분류', # different colors by group
                style='인구감소지수 분류', # different shapes by group
                s=80, # marker size
                data=under14_rate_g)

plt.title('2020년 유소년 비율')
plt.xlabel('인구수')
plt.ylabel('유소년 비율')

plt.savefig('output/under14_rate_2020.png')
plt.show()

# %%
under14_89 = under14_rate[under14_rate['인구감소지수 분류'].isin(['인구감소지역'])]
under14_89
# Out:
#                  2016       2017       2018       2019       2020 인구감소지수 분류
# sigungu
# 강원도 > 고성군    8.501021   8.209680   7.903578   7.731771   7.629285    인구감소지역
# 강원도 > 삼척시   10.597065  10.279212  10.007892   9.854593   9.679533    인구감소지역
# 강원도 > 양구군   12.856186  12.537590  12.402573  12.271142  11.836990    인구감소지역
# 강원도 > 양양군    9.201031   8.765663   8.408608   8.150493   7.984798    인구감소지역
# 강원도 > 영월군    9.004877   8.617962   8.249676   7.879708   7.560308    인구감소지역
# ...               ...        ...        ...        ...        ...       ...
# 충청북도 > 단양군   9.064332   8.560480   8.166951   7.826951   7.480355    인구감소지역
# 충청북도 > 보은군   8.928545   8.676116   8.448019   8.079218   7.693851    인구감소지역
# 충청북도 > 영동군   9.277027   8.962028   8.782701   8.585290   8.341625    인구감소지역
# 충청북도 > 옥천군  10.364003  10.029659   9.656883   9.305390   9.037137    인구감소지역
# 충청북도 > 제천시  12.055954  11.719286  11.511756  11.256910  10.929204    인구감소지역
#
# [89 rows x 6 columns]

# %%
under14_18 = under14_rate[under14_rate['인구감소지수 분류'].isin(['관심지역'])]
under14_18
# Out:
#                   2016       2017       2018       2019       2020 인구감소지수 분류
# sigungu
# 강원도 > 강릉시    12.119058  11.705613  11.317047  10.963582  10.657570      관심지역
# 강원도 > 동해시    13.692390  13.305967  12.958653  12.553940  12.172935      관심지역
# 강원도 > 속초시    12.912047  12.356794  11.949759  11.658169  11.433620      관심지역
# 강원도 > 인제군    13.064829  12.846383  12.551482  12.128186  11.780204      관심지역
# 경기도 > 동두천시   13.910925  13.413397  12.823427  12.223019  11.669340      관심지역
# 경기도 > 포천시    12.200713  11.723703  11.122985  10.524857  10.007554      관심지역
# 경상남도 > 사천시   13.930246  13.601862  13.228179  12.764723  12.375372      관심지역
# 경상남도 > 통영시   14.719648  14.375297  13.979250  13.525528  13.071181      관심지역
# 경상북도 > 경주시   11.611435  11.320909  11.012298  10.715058  10.476030      관심지역
# 경상북도 > 김천시   12.086820  12.091179  12.007238  11.840938  11.650007      관심지역
# 광주광역시 > 동구   10.182130   9.927312   9.787565   9.847020  10.144445      관심지역
# 대전광역시 > 대덕구  13.199788  12.629534  12.041903  11.433845  10.946657      관심지역
# 대전광역시 > 동구   13.183389  12.722852  12.241540  11.733299  11.255211      관심지역
# 대전광역시 > 중구   13.134619  12.642974  12.097903  11.582983  11.110923      관심지역
# 부산광역시 > 금정구  10.253685  10.032215   9.851155   9.590643   9.321388      관심지역
# 부산광역시 > 중구    7.517283   7.071406   6.572447   6.112038   5.647105      관심지역
# 인천광역시 > 동구   12.634302  12.288059  11.787819  11.152416  10.472775      관심지역
# 전라북도 > 익산시   13.589911  13.114567  12.622093  12.140673  11.658224      관심지역

# %%
under14_non = under14_rate[under14_rate['인구감소지수 분류'].isin(['안심지역'])]
under14_non
# Out:
#                  2016       2017       2018       2019       2020 인구감소지수 분류
# sigungu
# 강원도 > 원주시   14.515681  14.105296  13.719183  13.388866  13.149436      안심지역
# 강원도 > 춘천시   13.663964  13.266397  12.916383  12.650901  12.413470      안심지역
# 경기도 > 과천시   13.647315  13.383889  13.188822  12.960120  12.930264      안심지역
# 경기도 > 광명시   15.051933  14.527943  13.967687  13.379154  13.001140      안심지역
# 경기도 > 광주시   15.283784  14.932399  14.653869  14.344111  13.958934      안심지역
# ...               ...        ...        ...        ...        ...       ...
# 충청북도 > 증평군  15.495062  15.292779  14.951745  14.485107  13.899656      안심지역
# 충청북도 > 진천군  14.425135  14.371274  14.508486  14.584241  14.441631      안심지역
# 충청북도 > 청원구  17.108621  17.058742  16.790646  16.455619  15.986121      안심지역
# 충청북도 > 충주시  12.554374  12.200356  11.949605  11.729170  11.479146      안심지역
# 충청북도 > 흥덕구  15.568897  15.100934  14.703165  14.419788  14.203905      안심지역
#
# [115 rows x 6 columns]

# %%
under14_mean = pd.DataFrame({'인구감소지역':under14_89.mean()})
under14_mean['관심지역']=under14_18.mean()
under14_mean['안심지역']=under14_non.mean()
under14_mean['전국']=under14_rate.mean()
under14_mean
# Out:
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_2465/170280613.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   under14_mean = pd.DataFrame({'인구감소지역':under14_89.mean()})
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_2465/170280613.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   under14_mean['관심지역']=under14_18.mean()
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_2465/170280613.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   under14_mean['안심지역']=under14_non.mean()
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_2465/170280613.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   under14_mean['전국']=under14_rate.mean()
#         인구감소지역       관심지역       안심지역         전국
# 2016  9.762453  12.441290  14.602563  12.486920
# 2017  9.426033  12.065001  14.306321  12.168081
# 2018  9.117200  11.664041  14.000586  11.853383
# 2019  8.822363  11.249495  13.654106  11.522088
# 2020  8.540271  10.880586  13.305971  11.198745

# %%
df=under14_mean.plot(kind='bar')

plt.title('5년간 유소년 비율의 변화')

plt.xticks(rotation=0)
plt.xlabel('연도')
plt.ylabel(' 비율의 평균')
lgd=df.legend(bbox_to_anchor=(1,1))

plt.savefig('output/under14_5years_mean_bar.png',bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()

# %%
plt.style.use('ggplot')
fig=plt.figure(figsize=(8,5))
ax=fig.add_subplot(1,1,1)

ax.plot(under14_mean['인구감소지역'],marker='o',markerfacecolor='#ff5050',markersize=8,color='#ff5050',label='인구감소지수 분류')
ax.plot(under14_mean['관심지역'],marker='o',markerfacecolor='orange',markersize=8,color='orange',label='관심지역')
ax.plot(under14_mean['안심지역'],marker='o',markerfacecolor='#00ccff',markersize=8,color='#00ccff',label='안심지역')
#ax.plot(under14_mean['전국'],marker='o',markerfacecolor='indigo',markersize=8,color='skyblue',label='전국')

ax.legend(loc='best')

ax.set_title('5년간 유소년 비율의 변화')

ax.set_ylabel('유소년 비율의 평균')
ax.set_xlabel('연도')


plt.savefig('output/under14_5years_mean_line.png')
plt.show()
