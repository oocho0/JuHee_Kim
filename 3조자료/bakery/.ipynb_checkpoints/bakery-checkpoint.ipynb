# %% [markdown]
# ## 인구감소지역 뚜레쥬르와 파리바게트 수
# - 자료출저
# <br>네이버지도
# <br>https://www.tlj.co.kr:7008/store/search.asp

# %%
import pandas as pd

bakery = pd.read_csv('./bakery.csv')
pop = pd.read_csv('../total_pop/pop_89.csv')
sig_cd = pd.read_csv('../total_pop/sig_cd.csv')
bakery
# Out:
#      sigungu  뚜레쥬르  파바  sum
# 0    강원도 고성군     0   2    2
# 1    강원도 삼척시     1   3    4
# 2    강원도 양구군     1   1    2
# 3    강원도 양양군     1   1    2
# 4    강원도 영월군     2   2    4
# ..       ...   ...  ..  ...
# 84  충청북도 단양군     1   2    3
# 85  충청북도 보은군     1   1    2
# 86  충청북도 영동군     1   2    3
# 87  충청북도 옥천군     2   2    4
# 88  충청북도 제천시     7  10   17
#
# [89 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

plt.scatter(bakery['뚜레쥬르'], bakery['파바'], s = 5)

for i in range(len(bakery)): # 행 개수만큼 순회
    row = bakery.iloc[i] # 한 행씩 꺼내기
    name = row['sigungu'] # 이름이 저장된 열
    x = row['뚜레쥬르'] # x좌표가 저장된 열
    y = row['파바'] # y좌표가 저장된 열
    if name in ['충청북도 제천시']:
        plt.text(x-0.5, y-0.5, name, fontsize=6)
    elif name in ['경상북도 안동시']:
        plt.text(x-0.8, y+0.2, name, fontsize=6)
    elif name in ['대구광역시 서구','대구광역시 남구','부산광역시 동구','충청남도 보령시',
                  '부산광역시 서구', '경기도 가평군'] : 
        plt.text(x-0.5, y+0.2, name, fontsize=6) # x 좌표, y좌표, 이름 순서로 input 지정
    elif name in ['경상북도 영천시', '충청남도 논산시'] :
        plt.text(x-0.5, y+0.5, name, fontsize=6)
    elif name in ['경상북도 영주시'] :
        plt.text(x-0.5, y+0.8, name, fontsize=6)
    elif name in ['전라북도 정읍시'] : 
        plt.text(x-0.5, y+1.1, name, fontsize=6)
    else :
        pass

plt.title('인구감소지역 뚜레쥬르-파리바게트 매장 수')
plt.xlabel('뚜레쥬르 매장')
plt.ylabel('파리바게트 매장')
plt.savefig('output/bakery.png', bbox_inches='tight')
plt.show()

# %%
bakery.set_index('sigungu',inplace=True)
bakery.sort_index(inplace=True)
bakery['pop']=pop['total_2020']
bakery
# Out:
#           뚜레쥬르  파바  sum       pop
# sigungu
# 강원도 고성군      0   2    2   26791.5
# 강원도 삼척시      1   3    4   65623.0
# 강원도 양구군      1   1    2   22379.0
# 강원도 양양군      1   1    2   27627.5
# 강원도 영월군      2   2    4   38345.0
# ...        ...  ..  ...       ...
# 충청북도 단양군     1   2    3   29143.0
# 충청북도 보은군     1   1    2   32402.5
# 충청북도 영동군     1   2    3   47736.5
# 충청북도 옥천군     2   2    4   50381.0
# 충청북도 제천시     7  10   17  132882.5
#
# [89 rows x 4 columns]

# %%
pop = pd.read_csv('../total_pop/pop_89.csv')
pop.rename(columns={'행정구역(시군구)별':'sigungu'},inplace=True)
pop.set_index('sigungu',inplace=True)
pop.sort_index(inplace=True)
pop
# Out:
#           total_2016  total_2017  total_2018  total_2019  total_2020
# sigungu
# 강원도 고성군      29867.0     29855.0     28873.0     27484.0     26791.5
# 강원도 삼척시      69481.5     68371.0     67786.5     67156.5     65623.0
# 강원도 양구군      23899.0     23776.5     23479.0     22940.0     22379.0
# 강원도 양양군      27160.0     27014.5     27067.5     27323.5     27627.5
# 강원도 영월군      39573.0     39510.5     39347.0     38872.0     38345.0
# ...              ...         ...         ...         ...         ...
# 충청북도 단양군     30272.5     30010.0     29901.0     29679.5     29143.0
# 충청북도 보은군     33930.5     33828.5     33570.0     33023.0     32402.5
# 충청북도 영동군     50237.0     50011.0     49597.5     48851.0     47736.5
# 충청북도 옥천군     51881.5     51587.0     51207.0     50841.5     50381.0
# 충청북도 제천시    135290.0    135469.0    134949.0    134051.0    132882.5
#
# [89 rows x 5 columns]

# %%
sido=pd.read_csv('../total_pop/sido.csv')
sido.set_index('sigungu', inplace=True)
sido.sort_index(inplace=True)
sido
# Out:
#           sido
# sigungu
# 강원도 고성군    강원도
# 강원도 삼척시    강원도
# 강원도 양구군    강원도
# 강원도 양양군    강원도
# 강원도 영월군    강원도
# ...        ...
# 충청북도 단양군  충청북도
# 충청북도 보은군  충청북도
# 충청북도 영동군  충청북도
# 충청북도 옥천군  충청북도
# 충청북도 제천시  충청북도
#
# [89 rows x 1 columns]

# %%
bakery['pop']=pop['total_2020']
bakery['sido']=sido['sido']
bakery['rate']=bakery['sum']/bakery['pop']*10000
bakery.reset_index(inplace=True)
bakery
# Out:
#      sigungu  뚜레쥬르  파바  sum       pop  sido    hp_bin  sig_cd      rate
# 0    강원도 고성군     0   2    2   26791.5   강원도      0~4개   42820  0.746505
# 1    강원도 삼척시     1   3    4   65623.0   강원도      0~4개   42230  0.609542
# 2    강원도 양구군     1   1    2   22379.0   강원도      0~4개   42800  0.893695
# 3    강원도 양양군     1   1    2   27627.5   강원도      0~4개   42830  0.723916
# 4    강원도 영월군     2   2    4   38345.0   강원도      0~4개   42750  1.043161
# ..       ...   ...  ..  ...       ...   ...       ...     ...       ...
# 84  충청북도 단양군     1   2    3   29143.0  충청북도      0~4개   43800  1.029407
# 85  충청북도 보은군     1   1    2   32402.5  충청북도      0~4개   43720  0.617236
# 86  충청북도 영동군     1   2    3   47736.5  충청북도      0~4개   43740  0.628450
# 87  충청북도 옥천군     2   2    4   50381.0  충청북도      0~4개   43730  0.793950
# 88  충청북도 제천시     7  10   17  132882.5  충청북도  13.5~18개   43150  1.279326
#
# [89 rows x 9 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

sns.scatterplot(x='pop', y='sum',s=60,data=bakery)

for i in range(len(bakery)): # 행 개수만큼 순회
    row = bakery.iloc[i] # 한 행씩 꺼내기
    name = row['sigungu'] # 이름이 저장된 열
    x = row['pop'] # x좌표가 저장된 열
    y = row['sum'] # y좌표가 저장된 열
    if name in ['경상북도 안동시','충청북도 제천시','대구광역시 남구','대구광역시 서구','충청남도 보령시', '부산광역시 서구','부산광역시 영도구'] :
        plt.text(x-14000, y+0.5, name, fontsize=6)
    elif name in ['부산광역시 동구', '충청남도 논산시'] :
        plt.text(x-14000, y+1.2, name, fontsize=6)
    elif name in ['경상북도 울릉군'] :
        plt.text(x-7000, y-0.5, name, fontsize=6)
    elif name in ['경상북도 청송군'] :
        plt.text(x-500, y-0.5, name, fontsize=6)
    else :
        pass


plt.title('인구감소지역 뚜레쥬르-파리바게트 매장 수')
plt.xlabel('인구수')
plt.ylabel('매장 수')
plt.legend(fontsize=6)
plt.savefig('output/bakery_pop.png', bbox_inches='tight')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

sns.scatterplot(x='pop', y='rate',s=60,data=bakery)

for i in range(len(bakery)): # 행 개수만큼 순회
    row = bakery.iloc[i] # 한 행씩 꺼내기
    name = row['sigungu'] # 이름이 저장된 열
    x = row['pop'] # x좌표가 저장된 열
    y = row['rate'] # y좌표가 저장된 열
    if name in ['경상북도 울진군','경기도 가평군','부산광역시 동구','충청남도 보령시','충청남도 논산시','부산광역시 서구','충청북도 제천시',
               '대구광역시 남구', '경상북도 울릉군'] :
        plt.text(x-0.2, y-0.05, name, fontsize=6)
    elif name in ['대구광역시 서구','경상북도 안동시'] : 
        plt.text(x-16000, y-0.05, name, fontsize=6)
    elif name in ['경상북도 청송군'] :
        plt.text(x-10000, y+0.06, name, fontsize=6)
    else :
        pass

plt.title('인구감소지역 뚜레쥬르-파리바게트 매장 비율, 1만명 당')
plt.xlabel('인구수')
plt.ylabel('매장 수/인구수')
plt.legend(fontsize=6)
plt.savefig('output/bakery_rate.png', bbox_inches='tight')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np

count, bin_dividers=np.histogram(bakery['sum'], bins=4)
bin_dividers
# Out:
# array([ 0. ,  4.5,  9. , 13.5, 18. ])

# %%
bin_names=['0~4개', '4.5~8개','9~13개','13.5~18개']

bakery['hp_bin']=pd.cut(x=bakery['sum'], bins=bin_dividers, labels=bin_names, include_lowest=True)
bakery
# Out:
#           뚜레쥬르  파바  sum       pop  sido    hp_bin
# sigungu
# 강원도 고성군      0   2    2   26791.5   강원도      0~4개
# 강원도 삼척시      1   3    4   65623.0   강원도      0~4개
# 강원도 양구군      1   1    2   22379.0   강원도      0~4개
# 강원도 양양군      1   1    2   27627.5   강원도      0~4개
# 강원도 영월군      2   2    4   38345.0   강원도      0~4개
# ...        ...  ..  ...       ...   ...       ...
# 충청북도 단양군     1   2    3   29143.0  충청북도      0~4개
# 충청북도 보은군     1   1    2   32402.5  충청북도      0~4개
# 충청북도 영동군     1   2    3   47736.5  충청북도      0~4개
# 충청북도 옥천군     2   2    4   50381.0  충청북도      0~4개
# 충청북도 제천시     7  10   17  132882.5  충청북도  13.5~18개
#
# [89 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

sns.scatterplot(x='pop', y='sum', hue='hp_bin',style='hp_bin',s=60,data=bakery)

plt.title('인구감소지역 뚜레쥬르-파리바게트 매장 수')
plt.xlabel('인구수')
plt.ylabel('매장 수')
plt.legend(fontsize=6)
plt.savefig('output/bakery_pop_bins.png', bbox_inches='tight')
plt.show()

# %%
sig_cd.set_index('sigungu',inplace=True)
sig_cd.sort_index(inplace=True)
sig_cd
# Out:
#           SIG_CD SIG_KOR_NM
# sigungu
# 강원도 고성군    42820        고성군
# 강원도 삼척시    42230        삼척시
# 강원도 양구군    42800        양구군
# 강원도 양양군    42830        양양군
# 강원도 영월군    42750        영월군
# ...          ...        ...
# 충청북도 단양군   43800        단양군
# 충청북도 보은군   43720        보은군
# 충청북도 영동군   43740        영동군
# 충청북도 옥천군   43730        옥천군
# 충청북도 제천시   43150        제천시
#
# [89 rows x 2 columns]

# %%
bakery['sig_cd']=sig_cd['SIG_CD']
bakery
# Out:
#           뚜레쥬르  파바  sum       pop  sido    hp_bin  sig_cd
# sigungu
# 강원도 고성군      0   2    2   26791.5   강원도      0~4개   42820
# 강원도 삼척시      1   3    4   65623.0   강원도      0~4개   42230
# 강원도 양구군      1   1    2   22379.0   강원도      0~4개   42800
# 강원도 양양군      1   1    2   27627.5   강원도      0~4개   42830
# 강원도 영월군      2   2    4   38345.0   강원도      0~4개   42750
# ...        ...  ..  ...       ...   ...       ...     ...
# 충청북도 단양군     1   2    3   29143.0  충청북도      0~4개   43800
# 충청북도 보은군     1   1    2   32402.5  충청북도      0~4개   43720
# 충청북도 영동군     1   2    3   47736.5  충청북도      0~4개   43740
# 충청북도 옥천군     2   2    4   50381.0  충청북도      0~4개   43730
# 충청북도 제천시     7  10   17  132882.5  충청북도  13.5~18개   43150
#
# [89 rows x 7 columns]

# %%
bakery.to_csv('bakery_result.csv')
