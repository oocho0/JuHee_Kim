# %% [markdown]
# ## 고령화비율
# - 자료출처
# <br>통계청,「인구동향조사」, 2021, 2022.12.20, 시군구/성/연령(5세)별 주민등록연앙인구

# %%
import pandas as pd

senior_pop=pd.read_csv('./senior_pop.csv')
total_pop=pd.read_csv('../total_pop/total_pop.csv')
sig_cd=pd.read_csv('../total_pop/sig_cd.csv')
senior_pop
# Out:
#      행정구역(시군구)별  senior_2016  senior_2017  senior_2018  senior_2019  \
# 0      부산광역시 중구         9092         9372         9685         9989
# 1      부산광역시 서구        23012        23481        24124        24887
# 2      부산광역시 동구        19597        20138        20659        21227
# 3     부산광역시 영도구        26201        27105        28021        28912
# 4    부산광역시 부산진구        58089        60204        62200        64239
# ..          ...          ...          ...          ...          ...
# 217    경상남도 하동군        14409        14563        14729        14923
# 218    경상남도 산청군        11505        11693        11921        12181
# 219    경상남도 함양군        12147        12341        12509        12642
# 220    경상남도 거창군        15386        15696        16009        16317
# 221    경상남도 합천군        16795        16934        16989        17018
#
#      senior_2020
# 0          10430
# 1          25914
# 2          22184
# 3          30088
# 4          67324
# ..           ...
# 217        15238
# ...

# %%
sig_cd.set_index('sigungu', inplace=True)
sig_cd.sort_index(inplace=True)
sig_cd
# Out:
#           SIG_CD SIG_KOR_NM
# sigungu
# 강원도 고성군    42820        고성군
# 강원도 삼척시    42230        삼척시
# 강원도 양구군    42800        양구군
# 강원도 양양군    42830        양양군
# 강원도 영월군    42750        영월군
# ...          ...        ...
# 충청북도 단양군   43800        단양군
# 충청북도 보은군   43720        보은군
# 충청북도 영동군   43740        영동군
# 충청북도 옥천군   43730        옥천군
# 충청북도 제천시   43150        제천시
#
# [89 rows x 2 columns]

# %%
total_pop
# Out:
#      행정구역(시군구)별  total_2016  total_2017  total_2018  total_2019  total_2020
# 0      부산광역시 중구     44191.5     43386.0     42206.5     41066.5     40445.5
# 1      부산광역시 서구    112041.5    109135.5    107981.5    107094.5    105948.0
# 2      부산광역시 동구     89046.5     87490.5     86074.5     85757.0     86801.0
# 3     부산광역시 영도구    125772.5    122860.5    119749.5    116364.5    113042.5
# 4    부산광역시 부산진구    373849.5    368927.5    361954.5    355134.5    354107.5
# ..          ...         ...         ...         ...         ...         ...
# 217    경상남도 하동군     49639.5     48933.0     47890.0     46756.0     45389.5
# 218    경상남도 산청군     35772.0     35918.5     35853.0     35389.5     34845.0
# 219    경상남도 함양군     39952.0     39870.0     39778.0     39519.0     39045.0
# 220    경상남도 거창군     62894.5     62656.5     62244.5     61957.5     61478.0
# 221    경상남도 합천군     48109.0     47048.5     46005.5     45111.5     44159.5
#
# [222 rows x 6 columns]

# %%
senior_pop.rename(columns={'행정구역(시군구)별':'sigungu',
                           'senior_2016':'2016',
                           'senior_2017':'2017',
                           'senior_2018':'2018',
                           'senior_2019':'2019',
                           'senior_2020':'2020'}, inplace=True)
senior_pop.set_index('sigungu', inplace=True)
senior_pop.sort_index(inplace=True)
senior_pop
# Out:
#            2016   2017   2018   2019   2020
# sigungu
# 강원도 강릉시   36929  38337  40087  41726  43830
# 강원도 고성군    7036   7188   7319   7493   7754
# 강원도 동해시   14804  15293  15983  16699  17571
# 강원도 삼척시   14356  14653  15101  15543  16075
# 강원도 속초시   12483  12959  13549  14217  15169
# ...         ...    ...    ...    ...    ...
# 충청북도 증평군   5200   5435   5696   5952   6235
# 충청북도 진천군  11054  11500  12045  12605  13289
# 충청북도 청원구  19754  20732  21799  22776  23977
# 충청북도 충주시  34142  35504  37168  38716  40566
# 충청북도 흥덕구  22872  23993  25200  26642  28477
#
# [222 rows x 5 columns]

# %%
senior_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 222 entries, 강원도 강릉시 to 충청북도 흥덕구
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2016    222 non-null    int64
#  1   2017    222 non-null    int64
#  2   2018    222 non-null    int64
#  3   2019    222 non-null    int64
#  4   2020    222 non-null    int64
# dtypes: int64(5)
# memory usage: 10.4+ KB

# %%
total_pop.rename(columns={'행정구역(시군구)별':'sigungu',
                           'total_2016':'2016',
                           'total_2017':'2017',
                           'total_2018':'2018',
                           'total_2019':'2019',
                           'total_2020':'2020'}, inplace=True)
total_pop.set_index('sigungu', inplace=True)
total_pop.sort_index(inplace=True)
total_pop
# Out:
#               2016      2017      2018      2019      2020
# sigungu
# 강원도 강릉시   212434.0  212129.0  211716.0  211445.5  211643.0
# 강원도 고성군    29867.0   29855.0   28873.0   27484.0   26791.5
# 강원도 동해시    92854.5   92327.0   91313.5   90147.0   89814.0
# 강원도 삼척시    69481.5   68371.0   67786.5   67156.5   65623.0
# 강원도 속초시    81180.0   81307.5   81248.5   80999.0   81496.5
# ...            ...       ...       ...       ...       ...
# 충청북도 증평군   36808.5   37357.5   37353.5   37148.5   36893.0
# 충청북도 진천군   68446.5   71295.0   75445.5   79174.5   81957.5
# 충청북도 청원구  185558.5  191438.5  194656.0  195690.0  194256.0
# 충청북도 충주시  206784.5  206912.0  207998.5  209230.5  209083.5
# 충청북도 흥덕구  252102.0  252342.0  252741.5  256841.5  262632.0
#
# [222 rows x 5 columns]

# %%
total_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 222 entries, 강원도 강릉시 to 충청북도 흥덕구
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2016    222 non-null    float64
#  1   2017    222 non-null    float64
#  2   2018    222 non-null    float64
#  3   2019    222 non-null    float64
#  4   2020    222 non-null    float64
# dtypes: float64(5)
# memory usage: 10.4+ KB

# %%
senior_rate=senior_pop/total_pop*100
senior_rate['인구감소지수 분류']='안심지역'

# %%
ingu_89 = ['부산광역시 동구', '부산광역시 서구', '부산광역시 영도구', '대구광역시 남구', '대구광역시 서구',
           '인천광역시 강화군', '인천광역시 옹진군', '경기도 가평군', '경기도 연천군', '강원도 고성군', '강원도 삼척시',
          '강원도 양구군', '강원도 양양군', '강원도 영월군', '강원도 정선군', '강원도 철원군', '강원도 태백시',
          '강원도 평창군', '강원도 홍천군', '강원도 화천군', '강원도 횡성군', '충청북도 괴산군', '충청북도 단양군',
          '충청북도 보은군', '충청북도 영동군', '충청북도 옥천군', '충청북도 제천시', '충청남도 공주시', '충청남도 금산군',
          '충청남도 논산시', '충청남도 보령시', '충청남도 부여군', '충청남도 서천군', '충청남도 예산군', '충청남도 청양군',
          '충청남도 태안군', '전라북도 고창군', '전라북도 김제시', '전라북도 남원시', '전라북도 무주군', '전라북도 부안군',
          '전라북도 순창군', '전라북도 임실군', '전라북도 장수군', '전라북도 정읍시', '전라북도 진안군', '전라남도 강진군',
          '전라남도 고흥군', '전라남도 곡성군', '전라남도 구례군', '전라남도 담양군', '전라남도 보성군', '전라남도 신안군',
          '전라남도 영광군', '전라남도 영암군', '전라남도 완도군', '전라남도 장성군', '전라남도 장흥군', '전라남도 진도군',
          '전라남도 함평군', '전라남도 해남군', '전라남도 화순군', '경상북도 고령군', '경상북도 군위군', '경상북도 문경시',
           '경상북도 봉화군', '경상북도 상주시', '경상북도 성주군', '경상북도 안동시', '경상북도 영덕군', '경상북도 영양군',
          '경상북도 영주시', '경상북도 영천시', '경상북도 울릉군', '경상북도 울진군', '경상북도 의성군', '경상북도 청도군',
          '경상북도 청송군', '경상남도 거창군', '경상남도 고성군', '경상남도 남해군', '경상남도 밀양시', '경상남도 산청군',
          '경상남도 의령군', '경상남도 창녕군', '경상남도 하동군', '경상남도 함안군', '경상남도 함양군', '경상남도 합천군']

# %%
semi_18 = ['대전광역시 동구','인천광역시 동구','부산광역시 중구','부산광역시 금정구','광주광역시 동구','경상남도 통영시',
           '강원도 강릉시','강원도 동해시','대전광역시 중구','경상북도 경주시','경상남도 사천시', '경상북도 김천시',
          '대전광역시 대덕구','강원도 인제군','전라북도 익산시','경기도 동두천시','강원도 속초시','경기도 포천시']

# %%
for i in ingu_89 :
    senior_rate.loc[i,'인구감소지수 분류'] = '인구감소지역'
    
for i in semi_18 :
    senior_rate.loc[i,'인구감소지수 분류']='관심지역'

senior_rate
# Out:
#                2016       2017       2018       2019       2020 인구감소지수 분류
# sigungu
# 강원도 강릉시   17.383752  18.072494  18.934327  19.733690  20.709402      관심지역
# 강원도 고성군   23.557773  24.076369  25.348942  27.263135  28.942015    인구감소지역
# 강원도 동해시   15.943223  16.563952  17.503436  18.524188  19.563765      관심지역
# 강원도 삼척시   20.661615  21.431601  22.277297  23.144446  24.495985    인구감소지역
# 강원도 속초시   15.376940  15.938259  16.676000  17.552069  18.613069      관심지역
# ...             ...        ...        ...        ...        ...       ...
# 충청북도 증평군  14.127172  14.548618  15.248906  16.022181  16.900225      안심지역
# 충청북도 진천군  16.149840  16.130163  15.965167  15.920530  16.214501      안심지역
# 충청북도 청원구  10.645699  10.829588  11.198730  11.638816  12.342991      안심지역
# 충청북도 충주시  16.510909  17.158985  17.869360  18.503994  19.401818      안심지역
# 충청북도 흥덕구   9.072518   9.508128   9.970662  10.372934  10.842929      안심지역
#
# [222 rows x 6 columns]

# %%
senior_rate_g = pd.DataFrame(senior_rate['2020'])
senior_rate_g['total_2020']=total_pop['2020']
senior_rate_g['인구감소지수 분류']=senior_rate['인구감소지수 분류']
senior_rate_g
# Out:
#                2020  total_2020 인구감소지수 분류
# sigungu
# 강원도 강릉시   20.709402    211643.0      관심지역
# 강원도 고성군   28.942015     26791.5    인구감소지역
# 강원도 동해시   19.563765     89814.0      관심지역
# 강원도 삼척시   24.495985     65623.0    인구감소지역
# 강원도 속초시   18.613069     81496.5      관심지역
# ...             ...         ...       ...
# 충청북도 증평군  16.900225     36893.0      안심지역
# 충청북도 진천군  16.214501     81957.5      안심지역
# 충청북도 청원구  12.342991    194256.0      안심지역
# 충청북도 충주시  19.401818    209083.5      안심지역
# 충청북도 흥덕구  10.842929    262632.0      안심지역
#
# [222 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rc

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='darkgrid')

sns.scatterplot(x='total_2020', 
                y='2020', 
                hue='인구감소지수 분류', # different colors by group
                style='인구감소지수 분류', # different shapes by group
                s=80, # marker size
                data=senior_rate_g)

plt.title('2020년 고령화 비율')
plt.xlabel('인구수')
plt.ylabel('고령화 비율')

plt.savefig('output/aging_rate_2020.png')
plt.show()

# %%
senior_89 = senior_rate[senior_rate['인구감소지수 분류'].isin(['인구감소지역'])]
senior_89
# Out:
#                2016       2017       2018       2019       2020 인구감소지수 분류
# sigungu
# 강원도 고성군   23.557773  24.076369  25.348942  27.263135  28.942015    인구감소지역
# 강원도 삼척시   20.661615  21.431601  22.277297  23.144446  24.495985    인구감소지역
# 강원도 양구군   16.988159  17.441591  18.122578  19.054054  20.362840    인구감소지역
# 강원도 양양군   25.452872  26.308094  27.313198  28.199169  29.253461    인구감소지역
# 강원도 영월군   24.445961  25.233799  26.276463  27.389895  28.819924    인구감소지역
# ...             ...        ...        ...        ...        ...       ...
# 충청북도 단양군  25.699893  26.497834  27.400421  28.403443  30.027794    인구감소지역
# 충청북도 보은군  29.660630  30.249642  31.158773  32.347152  33.843068    인구감소지역
# 충청북도 영동군  27.004001  27.611925  28.469177  29.395509  30.806615    인구감소지역
# 충청북도 옥천군  25.047464  25.946459  26.986545  28.000747  29.195530    인구감소지역
# 충청북도 제천시  17.466923  18.212285  19.194659  20.094591  21.257126    인구감소지역
#
# [89 rows x 6 columns]

# %%
senior_18 = senior_rate[senior_rate['인구감소지수 분류'].isin(['관심지역'])]
senior_18
# Out:
#                 2016       2017       2018       2019       2020 인구감소지수 분류
# sigungu
# 강원도 강릉시    17.383752  18.072494  18.934327  19.733690  20.709402      관심지역
# 강원도 동해시    15.943223  16.563952  17.503436  18.524188  19.563765      관심지역
# 강원도 속초시    15.376940  15.938259  16.676000  17.552069  18.613069      관심지역
# 강원도 인제군    16.891098  17.498190  18.289480  19.060830  19.998730      관심지역
# 경기도 동두천시   16.040977  16.800745  17.767793  18.694029  19.763567      관심지역
# 경기도 포천시    15.499190  16.120831  17.009745  17.989597  19.207120      관심지역
# 경상남도 사천시   18.400305  19.036975  19.629311  20.411060  21.539671      관심지역
# 경상남도 통영시   14.789055  15.669169  16.650721  17.618139  18.867237      관심지역
# 경상북도 경주시   18.497437  19.227984  20.048330  20.900400  21.979914      관심지역
# 경상북도 김천시   19.934525  20.332312  21.060645  21.793881  22.615560      관심지역
# 광주광역시 동구   19.852853  20.558092  21.189960  21.393001  21.390385      관심지역
# ...

# %%
senior_non = senior_rate[senior_rate['인구감소지수 분류'].isin(['안심지역'])]
senior_non
# Out:
#                2016       2017       2018       2019       2020 인구감소지수 분류
# sigungu
# 강원도 원주시   12.396499  12.852006  13.458495  13.984773  14.651321      안심지역
# 강원도 춘천시   14.784517  15.218786  15.904080  16.539869  17.365131      안심지역
# 경기도 과천시   11.656526  12.386166  13.016534  13.436377  13.855286      안심지역
# 경기도 광명시   10.422589  11.025891  11.736752  12.501570  13.360111      안심지역
# 경기도 광주시   10.594577  11.013484  11.526254  12.075698  12.873005      안심지역
# ...             ...        ...        ...        ...        ...       ...
# 충청북도 증평군  14.127172  14.548618  15.248906  16.022181  16.900225      안심지역
# 충청북도 진천군  16.149840  16.130163  15.965167  15.920530  16.214501      안심지역
# 충청북도 청원구  10.645699  10.829588  11.198730  11.638816  12.342991      안심지역
# 충청북도 충주시  16.510909  17.158985  17.869360  18.503994  19.401818      안심지역
# 충청북도 흥덕구   9.072518   9.508128   9.970662  10.372934  10.842929      안심지역
#
# [115 rows x 6 columns]

# %%
senior_mean = pd.DataFrame({'인구감소지역':senior_89.mean()})
senior_mean['관심지역']=senior_18.mean()
senior_mean['안심지역']=senior_non.mean()
#senior_mean['전국']=senior_rate.mean()
senior_mean
# Out:
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_2343/2253616141.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   senior_mean = pd.DataFrame({'인구감소지역':senior_89.mean()})
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_2343/2253616141.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   senior_mean['관심지역']=senior_18.mean()
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_2343/2253616141.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# ...

# %%
df=senior_mean.plot(kind='bar')

plt.title('5년간 고령화 비율의 변화')

plt.xticks(rotation=0)
plt.xlabel('연도')
plt.ylabel('고령화 비율의 평균')
lgd=df.legend(bbox_to_anchor=(1,1))

plt.savefig('output/aging_5years_mean_bar.png',bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()

# %%
plt.style.use('ggplot')
fig=plt.figure(figsize=(8,5))
ax=fig.add_subplot(1,1,1)

ax.plot(senior_mean['인구감소지역'],marker='o',markerfacecolor='#ff5050',markersize=8,color='#ff5050',label='인구감소지역')
ax.plot(senior_mean['관심지역'],marker='o',markerfacecolor='orange',markersize=8,color='orange',label='관심지역')
ax.plot(senior_mean['안심지역'],marker='o',markerfacecolor='#00ccff',markersize=8,color='#00ccff',label='안심지역')
#ax.plot(senior_mean['전국'],marker='o',markerfacecolor='indigo',markersize=10,color='skyblue',label='전국')

ax.legend(loc='best')

ax.set_title('5년간 고령화 비율의 변화')

ax.set_ylabel('고령화 비율의 평균')
ax.set_xlabel('연도')
plt.legend(loc=6)

plt.savefig('output/aging_5years_mean_line.png', bbox_inches='tight')
plt.show()

# %%
sido_89 = pd.read_csv('../total_pop/sido.csv')
sido_89.set_index('sigungu', inplace=True)
sido_89.sort_index(inplace=True)
sido_89
# Out:
#           sido
# sigungu
# 강원도 고성군    강원도
# 강원도 삼척시    강원도
# 강원도 양구군    강원도
# 강원도 양양군    강원도
# 강원도 영월군    강원도
# ...        ...
# 충청북도 단양군  충청북도
# 충청북도 보은군  충청북도
# 충청북도 영동군  충청북도
# 충청북도 옥천군  충청북도
# 충청북도 제천시  충청북도
#
# [89 rows x 1 columns]

# %%
pop_89=pd.read_csv('../total_pop/pop_89.csv')
pop_89.rename(columns={'행정구역(시군구)별':'sigungu'}, inplace=True)
pop_89.set_index('sigungu',inplace=True)
pop_89.sort_index(inplace=True)
pop_89
# Out:
#           total_2016  total_2017  total_2018  total_2019  total_2020
# sigungu
# 강원도 고성군      29867.0     29855.0     28873.0     27484.0     26791.5
# 강원도 삼척시      69481.5     68371.0     67786.5     67156.5     65623.0
# 강원도 양구군      23899.0     23776.5     23479.0     22940.0     22379.0
# 강원도 양양군      27160.0     27014.5     27067.5     27323.5     27627.5
# 강원도 영월군      39573.0     39510.5     39347.0     38872.0     38345.0
# ...              ...         ...         ...         ...         ...
# 충청북도 단양군     30272.5     30010.0     29901.0     29679.5     29143.0
# 충청북도 보은군     33930.5     33828.5     33570.0     33023.0     32402.5
# 충청북도 영동군     50237.0     50011.0     49597.5     48851.0     47736.5
# 충청북도 옥천군     51881.5     51587.0     51207.0     50841.5     50381.0
# 충청북도 제천시    135290.0    135469.0    134949.0    134051.0    132882.5
#
# [89 rows x 5 columns]

# %%
senior_89['sido']=sido_89['sido']
senior_89['pop']=pop_89['total_2020']
senior_89
# Out:
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_2343/3028850726.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   senior_89['sido']=sido_89['sido']
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_2343/3028850726.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   senior_89['pop']=pop_89['total_2020']
#                2016       2017       2018       2019       2020 인구감소지수 분류  \
# sigungu
# 강원도 고성군   23.557773  24.076369  25.348942  27.263135  28.942015    인구감소지역
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

sns.scatterplot(x='pop', y='2020',s=60,data=senior_89)

plt.title('인구감소지역 고령화비율')
plt.xlabel('인구수')
plt.ylabel('고령화비율')
plt.legend(fontsize=6)
plt.savefig('output/aging_rate_89_sido.png', bbox_inches='tight')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np

count, bin_dividers = np.histogram(senior_89['2020'],bins=4)
bin_dividers
# Out:
# array([20.36284016, 25.47649824, 30.59015631, 35.70381438, 40.81747246])

# %%
bin_names=['20.3~25','25.4~30','30.5~35','35.7~41']

senior_89['hp_bin']=pd.cut(x=senior_89['2020'],bins=bin_dividers,labels=bin_names,include_lowest=True)
senior_89
# Out:
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_2343/3734216179.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   senior_89['hp_bin']=pd.cut(x=senior_89['2020'],bins=bin_dividers,labels=bin_names,include_lowest=True)
#                2016       2017       2018       2019       2020 인구감소지수 분류  \
# sigungu
# 강원도 고성군   23.557773  24.076369  25.348942  27.263135  28.942015    인구감소지역
# 강원도 삼척시   20.661615  21.431601  22.277297  23.144446  24.495985    인구감소지역
# 강원도 양구군   16.988159  17.441591  18.122578  19.054054  20.362840    인구감소지역
# 강원도 양양군   25.452872  26.308094  27.313198  28.199169  29.253461    인구감소지역
# 강원도 영월군   24.445961  25.233799  26.276463  27.389895  28.819924    인구감소지역
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

sns.scatterplot(x='pop', y='2020', hue='hp_bin',style='hp_bin',s=60,data=senior_89)

plt.title('인구감소지역 고령화비율')
plt.xlabel('인구수')
plt.ylabel('고령화비율')
plt.legend(fontsize=6)
plt.savefig('output/aging_rate_89_bins.png', bbox_inches='tight')
plt.show()

# %%
senior_89['sig_cd']=sig_cd['SIG_CD']
senior_89
# Out:
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_2343/3887934186.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   senior_89['sig_cd']=sig_cd['SIG_CD']
#                2016       2017       2018       2019       2020 인구감소지수 분류  \
# sigungu
# 강원도 고성군   23.557773  24.076369  25.348942  27.263135  28.942015    인구감소지역
# 강원도 삼척시   20.661615  21.431601  22.277297  23.144446  24.495985    인구감소지역
# 강원도 양구군   16.988159  17.441591  18.122578  19.054054  20.362840    인구감소지역
# 강원도 양양군   25.452872  26.308094  27.313198  28.199169  29.253461    인구감소지역
# 강원도 영월군   24.445961  25.233799  26.276463  27.389895  28.819924    인구감소지역
# ...             ...        ...        ...        ...        ...       ...
# ...

# %%
senior_89.to_csv('senior_89_result.csv')
