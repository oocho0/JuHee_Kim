# %% [markdown]
# ## 1인가구 비율 조사
# - 자료 출처
# <br><t>통계청,「인구총조사」, 2021, 2022.12.22, 가구형태별 가구 및 가구원 - 읍면동(연도 끝자리 0,5), 시군구(그 외 연도)
# <br><t>통계청,「인구총조사」, 2021, 2022.12.21, 성 및 연령별 1인가구 - 시군구

# %%
import pandas as pd

oph_2016=pd.read_csv('./one_person_household_2016.csv')
oph_2020=pd.read_csv('./one_person_household_2020.csv')
total_hh=pd.read_csv('../total_household/total_household.csv')
oph_2016
# Out:
#        행정구역별(시군구)  전체_남녀_2016  미성년_남녀_2016  청년_남녀_2016  장년_남녀_2016  \
# 0      부산광역시 > 중구        8609         36.0        1850        4328
# 1      부산광역시 > 서구       15965        107.0        3370        7224
# 2      부산광역시 > 동구       12890         36.0        1824        6201
# 3     부산광역시 > 영도구       16617        193.0        2964        7391
# 4    부산광역시 > 부산진구       48209        467.0       14764       20936
# ..            ...         ...          ...         ...         ...
# 217    경상남도 > 하동군        6482         16.0         377        2555
# 218    경상남도 > 산청군        5533         15.0         248        2208
# 219    경상남도 > 함양군        6041         20.0         324        2176
# 220    경상남도 > 거창군        7851         38.0         800        2780
# 221    경상남도 > 합천군        7757         11.0         339        2390
#
#      노년_남녀_2016  전체_남_2016  미성년_남_2016  청년_남_2016  장년_남_2016  노년_남_2016  \
# 0          2395       4086        15.0       1002       2381        688
# ...

# %%
oph_2020
# Out:
#        행정구역별(시군구)  전체_남녀_2020  미성년_남녀_2020  청년_남녀_2020  장년_남녀_2020  \
# 0      부산광역시 > 중구       10007         42.0        2633        4361
# 1      부산광역시 > 서구       18384        202.0        4746        7083
# 2      부산광역시 > 동구       15508         40.0        2909        6865
# 3     부산광역시 > 영도구       19073        582.0        3514        7498
# 4    부산광역시 > 부산진구       58924        741.0       20266       22972
# ..            ...         ...          ...         ...         ...
# 217    경상남도 > 하동군        7072          9.0         406        2814
# 218    경상남도 > 산청군        6032          NaN         286        2447
# 219    경상남도 > 함양군        6679         11.0         451        2458
# 220    경상남도 > 거창군        8787         34.0         968        3186
# 221    경상남도 > 합천군        8080          5.0         385        2633
#
#      노년_남녀_2020  전체_남_2020  미성년_남_2020  청년_남_2020  장년_남_2020  노년_남_2020  \
# 0          2971       4716        14.0       1245       2500        957
# ...

# %%
total_hh
# Out:
#        행정구역별(읍면동)  총가구_2016  일반가구_2016  집단가구_비혈연_2016  집단가구_집단시설_2016  \
# 0      부산광역시 > 중구     20923      20468            5.0            15.0
# 1      부산광역시 > 서구     46808      46391           11.0            30.0
# 2      부산광역시 > 동구     37981      37308           11.0            13.0
# 3     부산광역시 > 영도구     52345      51910            7.0            19.0
# 4    부산광역시 > 부산진구    152729     151910           15.0            33.0
# ..            ...       ...        ...            ...             ...
# 217    경상남도 > 하동군     19389      19208            6.0            14.0
# 218    경상남도 > 산청군     15254      15044            5.0            17.0
# 219    경상남도 > 함양군     16920      16780            NaN            16.0
# 220    경상남도 > 거창군     25143      24958            NaN            19.0
# 221    경상남도 > 합천군     20503      20313            NaN            16.0
#
#      외국인가구_2016  총가구_2017  일반가구_2017  집단가구_비혈연_2017  집단가구_집단시설_2017  ...  \
# ...

# %%
total_hh.rename(columns={'행정구역별(읍면동)':'sigungu'}, inplace=True)
total_hh.set_index('sigungu', inplace=True)
total_hh.sort_index(inplace=True)
total_hh
# Out:
#             총가구_2016  일반가구_2016  집단가구_비혈연_2016  집단가구_집단시설_2016  외국인가구_2016  \
# sigungu
# 강원도 > 강릉시      89302      88622           14.0            66.0         600
# 강원도 > 고성군      13104      12982            NaN            13.0         105
# 강원도 > 동해시      36237      35990            6.0            10.0         231
# 강원도 > 삼척시      29453      29243            9.0            18.0         183
# 강원도 > 속초시      33123      32809            9.0            16.0         289
# ...              ...        ...            ...             ...         ...
# 충청북도 > 증평군     14843      14557            NaN            12.0         272
# 충청북도 > 진천군     28651      26817           12.0            51.0        1771
# 충청북도 > 청원구     73871      72501           11.0            34.0        1325
# 충청북도 > 충주시     86707      85152           16.0            65.0        1474
# 충청북도 > 흥덕구     99178      97008            6.0            34.0        2130
#
# ...

# %%
oph_2016.rename(columns={'행정구역별(시군구)':'sigungu'}, inplace=True)
oph_2016.set_index('sigungu', inplace=True)
oph_2016.sort_index(inplace=True)
oph_2016
# Out:
#             전체_남녀_2016  미성년_남녀_2016  청년_남녀_2016  장년_남녀_2016  노년_남녀_2016  \
# sigungu
# 강원도 > 강릉시        29554        706.0        8809       12139        7900
# 강원도 > 고성군         5723        151.0        2329        1595        1648
# 강원도 > 동해시        10054         53.0        1467        5292        3242
# 강원도 > 삼척시        10647        430.0        2757        3915        3545
# 강원도 > 속초시        10011         32.0        1297        5761        2921
# ...                ...          ...         ...         ...         ...
# 충청북도 > 증평군        4527         32.0        1108        2204        1183
# 충청북도 > 진천군        8048         83.0        1368        4238        2359
# 충청북도 > 청원구       21477        250.0        8000        9563        3664
# 충청북도 > 충주시       27502        874.0        8331       11310        6987
# 충청북도 > 흥덕구       29523        187.0       10450       14768        4118
#
#             전체_남_2016  미성년_남_2016  청년_남_2016  장년_남_2016  노년_남_2016  전체_여_2016  \
# sigungu
# ...

# %%
oph_2020.rename(columns={'행정구역별(시군구)':'sigungu'}, inplace=True)
oph_2020.set_index('sigungu', inplace=True)
oph_2020.sort_index(inplace=True)
oph_2020
# Out:
#             전체_남녀_2020  미성년_남녀_2020  청년_남녀_2020  장년_남녀_2020  노년_남녀_2020  \
# sigungu
# 강원도 > 강릉시        37635       2174.0       11689       13816        9956
# 강원도 > 고성군         4413         41.0         812        1677        1883
# 강원도 > 동해시        11497         69.0        1410        5800        4218
# 강원도 > 삼척시        12516        819.0        3486        4164        4047
# 강원도 > 속초시        12122         34.0        1751        6460        3877
# ...                ...          ...         ...         ...         ...
# 충청북도 > 증평군        5589         34.0        1409        2637        1509
# 충청북도 > 진천군       11855        153.0        2898        5907        2897
# 충청북도 > 청원구       28208        670.0       10629       11959        4950
# 충청북도 > 충주시       33557        951.0        9892       13532        9182
# 충청북도 > 흥덕구       39230        327.0       15485       17930        5488
#
#             전체_남_2020  미성년_남_2020  청년_남_2020  장년_남_2020  노년_남_2020  전체_여_2020  \
# sigungu
# ...

# %%
oph_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 222 entries, 강원도 > 강릉시 to 충청북도 > 흥덕구
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   전체_남녀_2016   222 non-null    int64
#  1   미성년_남녀_2016  219 non-null    float64
#  2   청년_남녀_2016   222 non-null    int64
#  3   장년_남녀_2016   222 non-null    int64
#  4   노년_남녀_2016   222 non-null    int64
#  5   전체_남_2016    222 non-null    int64
#  6   미성년_남_2016   212 non-null    float64
#  7   청년_남_2016    222 non-null    int64
#  8   장년_남_2016    222 non-null    int64
#  9   노년_남_2016    222 non-null    int64
#  10  전체_여_2016    222 non-null    int64
#  11  미성년_여_2016   204 non-null    float64
#  12  청년_여_2016    222 non-null    int64
#  13  장년_여_2016    222 non-null    int64
#  14  노년_여_2016    222 non-null    int64
# dtypes: float64(3), int64(12)
# memory usage: 27.8+ KB

# %%
oph_2016.isnull().sum()
# Out:
# 전체_남녀_2016      0
# 미성년_남녀_2016     3
# 청년_남녀_2016      0
# 장년_남녀_2016      0
# 노년_남녀_2016      0
# 전체_남_2016       0
# 미성년_남_2016     10
# 청년_남_2016       0
# 장년_남_2016       0
# 노년_남_2016       0
# 전체_여_2016       0
# 미성년_여_2016     18
# 청년_여_2016       0
# 장년_여_2016       0
# 노년_여_2016       0
# dtype: int64

# %%
oph_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 222 entries, 강원도 > 강릉시 to 충청북도 > 흥덕구
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   전체_남녀_2020   222 non-null    int64
#  1   미성년_남녀_2020  217 non-null    float64
#  2   청년_남녀_2020   222 non-null    int64
#  3   장년_남녀_2020   222 non-null    int64
#  4   노년_남녀_2020   222 non-null    int64
#  5   전체_남_2020    222 non-null    int64
#  6   미성년_남_2020   196 non-null    float64
#  7   청년_남_2020    222 non-null    int64
#  8   장년_남_2020    222 non-null    int64
#  9   노년_남_2020    222 non-null    int64
#  10  전체_여_2020    222 non-null    int64
#  11  미성년_여_2020   191 non-null    float64
#  12  청년_여_2020    222 non-null    int64
#  13  장년_여_2020    222 non-null    int64
#  14  노년_여_2020    222 non-null    int64
# dtypes: float64(3), int64(12)
# memory usage: 27.8+ KB

# %%
oph_2020.isnull().sum()
# Out:
# 전체_남녀_2020      0
# 미성년_남녀_2020     5
# 청년_남녀_2020      0
# 장년_남녀_2020      0
# 노년_남녀_2020      0
# 전체_남_2020       0
# 미성년_남_2020     26
# 청년_남_2020       0
# 장년_남_2020       0
# 노년_남_2020       0
# 전체_여_2020       0
# 미성년_여_2020     31
# 청년_여_2020       0
# 장년_여_2020       0
# 노년_여_2020       0
# dtype: int64

# %%
oph_2016['미성년_남녀_2016'].fillna(oph_2016['미성년_남녀_2016'].mean(axis=0),inplace=True)
oph_2016['미성년_남_2016'].fillna(oph_2016['미성년_남_2016'].mean(axis=0),inplace=True)
oph_2016['미성년_여_2016'].fillna(oph_2016['미성년_여_2016'].mean(axis=0),inplace=True)
oph_2020['미성년_남녀_2020'].fillna(oph_2020['미성년_남녀_2020'].mean(axis=0),inplace=True)
oph_2020['미성년_남_2020'].fillna(oph_2020['미성년_남_2020'].mean(axis=0),inplace=True)
oph_2020['미성년_여_2020'].fillna(oph_2020['미성년_여_2020'].mean(axis=0),inplace=True)
oph_2016.isnull().sum()
# Out:
# 전체_남녀_2016     0
# 미성년_남녀_2016    0
# 청년_남녀_2016     0
# 장년_남녀_2016     0
# 노년_남녀_2016     0
# 전체_남_2016      0
# 미성년_남_2016     0
# 청년_남_2016      0
# 장년_남_2016      0
# 노년_남_2016      0
# 전체_여_2016      0
# 미성년_여_2016     0
# 청년_여_2016      0
# 장년_여_2016      0
# 노년_여_2016      0
# dtype: int64

# %%
oph_2020.isnull().sum()
# Out:
# 전체_남녀_2020     0
# 미성년_남녀_2020    0
# 청년_남녀_2020     0
# 장년_남녀_2020     0
# 노년_남녀_2020     0
# 전체_남_2020      0
# 미성년_남_2020     0
# 청년_남_2020      0
# 장년_남_2020      0
# 노년_남_2020      0
# 전체_여_2020      0
# 미성년_여_2020     0
# 청년_여_2020      0
# 장년_여_2020      0
# 노년_여_2020      0
# dtype: int64

# %%
oph_2016
# Out:
#             전체_남녀_2016  미성년_남녀_2016  청년_남녀_2016  장년_남녀_2016  노년_남녀_2016  \
# sigungu
# 강원도 > 강릉시        29554        706.0        8809       12139        7900
# 강원도 > 고성군         5723        151.0        2329        1595        1648
# 강원도 > 동해시        10054         53.0        1467        5292        3242
# 강원도 > 삼척시        10647        430.0        2757        3915        3545
# 강원도 > 속초시        10011         32.0        1297        5761        2921
# ...                ...          ...         ...         ...         ...
# 충청북도 > 증평군        4527         32.0        1108        2204        1183
# 충청북도 > 진천군        8048         83.0        1368        4238        2359
# 충청북도 > 청원구       21477        250.0        8000        9563        3664
# 충청북도 > 충주시       27502        874.0        8331       11310        6987
# 충청북도 > 흥덕구       29523        187.0       10450       14768        4118
#
#             전체_남_2016  미성년_남_2016  청년_남_2016  장년_남_2016  노년_남_2016  전체_여_2016  \
# sigungu
# ...

# %%
oph_2020
# Out:
#             전체_남녀_2020  미성년_남녀_2020  청년_남녀_2020  장년_남녀_2020  노년_남녀_2020  \
# sigungu
# 강원도 > 강릉시        37635       2174.0       11689       13816        9956
# 강원도 > 고성군         4413         41.0         812        1677        1883
# 강원도 > 동해시        11497         69.0        1410        5800        4218
# 강원도 > 삼척시        12516        819.0        3486        4164        4047
# 강원도 > 속초시        12122         34.0        1751        6460        3877
# ...                ...          ...         ...         ...         ...
# 충청북도 > 증평군        5589         34.0        1409        2637        1509
# 충청북도 > 진천군       11855        153.0        2898        5907        2897
# 충청북도 > 청원구       28208        670.0       10629       11959        4950
# 충청북도 > 충주시       33557        951.0        9892       13532        9182
# 충청북도 > 흥덕구       39230        327.0       15485       17930        5488
#
#             전체_남_2020  미성년_남_2020  청년_남_2020  장년_남_2020  노년_남_2020  전체_여_2020  \
# sigungu
# ...

# %%
total_hh
# Out:
#             총가구_2016  일반가구_2016  집단가구_비혈연_2016  집단가구_집단시설_2016  외국인가구_2016  \
# sigungu
# 강원도 > 강릉시      89302      88622           14.0            66.0         600
# 강원도 > 고성군      13104      12982            NaN            13.0         105
# 강원도 > 동해시      36237      35990            6.0            10.0         231
# 강원도 > 삼척시      29453      29243            9.0            18.0         183
# 강원도 > 속초시      33123      32809            9.0            16.0         289
# ...              ...        ...            ...             ...         ...
# 충청북도 > 증평군     14843      14557            NaN            12.0         272
# 충청북도 > 진천군     28651      26817           12.0            51.0        1771
# 충청북도 > 청원구     73871      72501           11.0            34.0        1325
# 충청북도 > 충주시     86707      85152           16.0            65.0        1474
# 충청북도 > 흥덕구     99178      97008            6.0            34.0        2130
#
# ...

# %%
oph_rate=pd.DataFrame({'전체_1인가구비율_2016':oph_2016['전체_남녀_2016']/total_hh['총가구_2016'],
                        '전체_1인가구_미성년_2016':oph_2016['미성년_남녀_2016']/total_hh['총가구_2016'],
                        '전체_1인가구_청년_2016':oph_2016['청년_남녀_2016']/total_hh['총가구_2016'],
                        '전체_1인가구_장년_2016':oph_2016['장년_남녀_2016']/total_hh['총가구_2016'],
                        '전체_1인가구_노년_2016':oph_2016['노년_남녀_2016']/total_hh['총가구_2016'],
                        '전체_1인가구비율_2020':oph_2020['전체_남녀_2020']/total_hh['총가구_2020'],
                        '전체_1인가구_미성년_2020':oph_2020['미성년_남녀_2020']/total_hh['총가구_2020'],
                        '전체_1인가구_청년_2020':oph_2020['청년_남녀_2020']/total_hh['총가구_2020'],
                        '전체_1인가구_장년_2020':oph_2020['장년_남녀_2020']/total_hh['총가구_2020'],
                        '전체_1인가구_노년_2020':oph_2020['노년_남녀_2020']/total_hh['총가구_2020'],
                      '총가구_2016':total_hh['총가구_2016'],
                      '총가구_2020':total_hh['총가구_2020']})
oph_rate
# Out:
#             전체_1인가구비율_2016  전체_1인가구_미성년_2016  전체_1인가구_청년_2016  \
# sigungu
# 강원도 > 강릉시         0.330944          0.007906         0.098643
# 강원도 > 고성군         0.436737          0.011523         0.177732
# 강원도 > 동해시         0.277451          0.001463         0.040483
# 강원도 > 삼척시         0.361491          0.014600         0.093607
# 강원도 > 속초시         0.302237          0.000966         0.039157
# ...                    ...               ...              ...
# 충청북도 > 증평군        0.304992          0.002156         0.074648
# 충청북도 > 진천군        0.280898          0.002897         0.047747
# 충청북도 > 청원구        0.290737          0.003384         0.108297
# 충청북도 > 충주시        0.317183          0.010080         0.096082
# 충청북도 > 흥덕구        0.297677          0.001885         0.105366
#
#             전체_1인가구_장년_2016  전체_1인가구_노년_2016  전체_1인가구비율_2020  \
# sigungu
# 강원도 > 강릉시          0.135932         0.088464        0.379733
# 강원도 > 고성군          0.121719         0.125763        0.364831
# ...

# %%
oph_rate['인구감소지수 분류']='안심지역'
oph_rate
# Out:
#             전체_1인가구비율_2016  전체_1인가구_미성년_2016  전체_1인가구_청년_2016  \
# sigungu
# 강원도 > 강릉시         0.330944          0.007906         0.098643
# 강원도 > 고성군         0.436737          0.011523         0.177732
# 강원도 > 동해시         0.277451          0.001463         0.040483
# 강원도 > 삼척시         0.361491          0.014600         0.093607
# 강원도 > 속초시         0.302237          0.000966         0.039157
# ...                    ...               ...              ...
# 충청북도 > 증평군        0.304992          0.002156         0.074648
# 충청북도 > 진천군        0.280898          0.002897         0.047747
# 충청북도 > 청원구        0.290737          0.003384         0.108297
# 충청북도 > 충주시        0.317183          0.010080         0.096082
# 충청북도 > 흥덕구        0.297677          0.001885         0.105366
#
#             전체_1인가구_장년_2016  전체_1인가구_노년_2016  전체_1인가구비율_2020  \
# sigungu
# 강원도 > 강릉시          0.135932         0.088464        0.379733
# 강원도 > 고성군          0.121719         0.125763        0.364831
# ...

# %%
ingu_89 = ['부산광역시 > 동구', '부산광역시 > 서구', '부산광역시 > 영도구', '대구광역시 > 남구', '대구광역시 > 서구',
           '인천광역시 > 강화군', '인천광역시 > 옹진군', '경기도 > 가평군', '경기도 > 연천군', '강원도 > 고성군', '강원도 > 삼척시',
          '강원도 > 양구군', '강원도 > 양양군', '강원도 > 영월군', '강원도 > 정선군', '강원도 > 철원군', '강원도 > 태백시',
          '강원도 > 평창군', '강원도 > 홍천군', '강원도 > 화천군', '강원도 > 횡성군', '충청북도 > 괴산군', '충청북도 > 단양군',
          '충청북도 > 보은군', '충청북도 > 영동군', '충청북도 > 옥천군', '충청북도 > 제천시', '충청남도 > 공주시', '충청남도 > 금산군',
          '충청남도 > 논산시', '충청남도 > 보령시', '충청남도 > 부여군', '충청남도 > 서천군', '충청남도 > 예산군', '충청남도 > 청양군',
          '충청남도 > 태안군', '전라북도 > 고창군', '전라북도 > 김제시', '전라북도 > 남원시', '전라북도 > 무주군', '전라북도 > 부안군',
          '전라북도 > 순창군', '전라북도 > 임실군', '전라북도 > 장수군', '전라북도 > 정읍시', '전라북도 > 진안군', '전라남도 > 강진군',
          '전라남도 > 고흥군', '전라남도 > 곡성군', '전라남도 > 구례군', '전라남도 > 담양군', '전라남도 > 보성군', '전라남도 > 신안군',
          '전라남도 > 영광군', '전라남도 > 영암군', '전라남도 > 완도군', '전라남도 > 장성군', '전라남도 > 장흥군', '전라남도 > 진도군',
          '전라남도 > 함평군', '전라남도 > 해남군', '전라남도 > 화순군', '경상북도 > 고령군', '경상북도 > 군위군', '경상북도 > 문경시',
          '경상북도 > 봉화군', '경상북도 > 상주시', '경상북도 > 성주군', '경상북도 > 안동시', '경상북도 > 영덕군', '경상북도 > 영양군',
          '경상북도 > 영주시', '경상북도 > 영천시', '경상북도 > 울릉군', '경상북도 > 울진군', '경상북도 > 의성군', '경상북도 > 청도군',
          '경상북도 > 청송군', '경상남도 > 거창군', '경상남도 > 고성군', '경상남도 > 남해군', '경상남도 > 밀양시', '경상남도 > 산청군',
          '경상남도 > 의령군', '경상남도 > 창녕군', '경상남도 > 하동군', '경상남도 > 함안군', '경상남도 > 함양군', '경상남도 > 합천군']

# %%
semi_18 = ['대전광역시 > 동구','인천광역시 > 동구','부산광역시 > 중구','부산광역시 > 금정구','광주광역시 > 동구','경상남도 > 통영시',
           '강원도 > 강릉시','강원도 > 동해시','대전광역시 > 중구','경상북도 > 경주시','경상남도 > 사천시', '경상북도 > 김천시',
          '대전광역시 > 대덕구','강원도 > 인제군','전라북도 > 익산시','경기도 > 동두천시','강원도 > 속초시','경기도 > 포천시']

# %%
for i in ingu_89 :
    oph_rate.loc[i,'인구감소지수 분류'] = '인구감소지역'

for i in semi_18 :
    oph_rate.loc[i,'인구감소지수 분류'] = '관심지역'

oph_rate
# Out:
#             전체_1인가구비율_2016  전체_1인가구_미성년_2016  전체_1인가구_청년_2016  \
# sigungu
# 강원도 > 강릉시         0.330944          0.007906         0.098643
# 강원도 > 고성군         0.436737          0.011523         0.177732
# 강원도 > 동해시         0.277451          0.001463         0.040483
# 강원도 > 삼척시         0.361491          0.014600         0.093607
# 강원도 > 속초시         0.302237          0.000966         0.039157
# ...                    ...               ...              ...
# 충청북도 > 증평군        0.304992          0.002156         0.074648
# 충청북도 > 진천군        0.280898          0.002897         0.047747
# 충청북도 > 청원구        0.290737          0.003384         0.108297
# 충청북도 > 충주시        0.317183          0.010080         0.096082
# 충청북도 > 흥덕구        0.297677          0.001885         0.105366
#
#             전체_1인가구_장년_2016  전체_1인가구_노년_2016  전체_1인가구비율_2020  \
# sigungu
# 강원도 > 강릉시          0.135932         0.088464        0.379733
# 강원도 > 고성군          0.121719         0.125763        0.364831
# ...

# %%
oph_89 = oph_rate[oph_rate['인구감소지수 분류'].isin(['인구감소지역'])]
oph_89
# Out:
#             전체_1인가구비율_2016  전체_1인가구_미성년_2016  전체_1인가구_청년_2016  \
# sigungu
# 강원도 > 고성군         0.436737          0.011523         0.177732
# 강원도 > 삼척시         0.361491          0.014600         0.093607
# 강원도 > 양구군         0.364687          0.001166         0.158324
# 강원도 > 양양군         0.334627          0.000882         0.035711
# 강원도 > 영월군         0.341264          0.001721         0.031477
# ...                    ...               ...              ...
# 충청북도 > 단양군        0.318560          0.017041         0.022604
# 충청북도 > 보은군        0.317451          0.000502         0.016073
# 충청북도 > 영동군        0.346648          0.008492         0.065136
# 충청북도 > 옥천군        0.266720          0.001342         0.018633
# 충청북도 > 제천시        0.312518          0.004674         0.074982
#
#             전체_1인가구_장년_2016  전체_1인가구_노년_2016  전체_1인가구비율_2020  \
# sigungu
# 강원도 > 고성군          0.121719         0.125763        0.364831
# 강원도 > 삼척시          0.132924         0.120361        0.403534
# ...

# %%
oph_18 = oph_rate[oph_rate['인구감소지수 분류'].isin(['관심지역'])]
oph_18
# Out:
#              전체_1인가구비율_2016  전체_1인가구_미성년_2016  전체_1인가구_청년_2016  \
# sigungu
# 강원도 > 강릉시          0.330944          0.007906         0.098643
# 강원도 > 동해시          0.277451          0.001463         0.040483
# 강원도 > 속초시          0.302237          0.000966         0.039157
# 강원도 > 인제군          0.349359          0.000691         0.108056
# 경기도 > 동두천시         0.264992          0.001372         0.036804
# 경기도 > 포천시          0.268965          0.001413         0.047232
# 경상남도 > 사천시         0.290780          0.001275         0.040472
# 경상남도 > 통영시         0.279482          0.000874         0.036931
# 경상북도 > 경주시         0.315633          0.006515         0.071302
# 경상북도 > 김천시         0.301896          0.002867         0.057433
# 광주광역시 > 동구         0.392434          0.010600         0.148105
# 대전광역시 > 대덕구        0.281332          0.007226         0.074162
# 대전광역시 > 동구         0.349826          0.022003         0.124971
# 대전광역시 > 중구         0.265839          0.001716         0.058263
# ...

# %%
oph_non = oph_rate[oph_rate['인구감소지수 분류'].isin(['안심지역'])]
oph_non
# Out:
#             전체_1인가구비율_2016  전체_1인가구_미성년_2016  전체_1인가구_청년_2016  \
# sigungu
# 강원도 > 원주시         0.297927          0.004696         0.081047
# 강원도 > 춘천시         0.302081          0.005373         0.092799
# 경기도 > 과천시         0.192765          0.001170         0.042681
# 경기도 > 광명시         0.189236          0.000492         0.033697
# 경기도 > 광주시         0.207996          0.000933         0.040545
# ...                    ...               ...              ...
# 충청북도 > 증평군        0.304992          0.002156         0.074648
# 충청북도 > 진천군        0.280898          0.002897         0.047747
# 충청북도 > 청원구        0.290737          0.003384         0.108297
# 충청북도 > 충주시        0.317183          0.010080         0.096082
# 충청북도 > 흥덕구        0.297677          0.001885         0.105366
#
#             전체_1인가구_장년_2016  전체_1인가구_노년_2016  전체_1인가구비율_2020  \
# sigungu
# 강원도 > 원주시          0.151258         0.060925        0.342413
# 강원도 > 춘천시          0.133613         0.070297        0.332646
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rc

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='darkgrid')

sns.scatterplot(x='총가구_2020', 
                y='전체_1인가구비율_2020', 
                hue='인구감소지수 분류', # different colors by group
                style='인구감소지수 분류', # different shapes by group
                s=80, # marker size
                data=oph_rate)

plt.title('2020년 1인가구비율')
plt.xlabel('가구수')
plt.ylabel('1인가구비율')

plt.savefig('output/one_person_household_total_rate_2020.png', bbox_inches='tight')
plt.show()

# %%
sns.scatterplot(x='총가구_2016', 
                y='전체_1인가구비율_2016', 
                hue='인구감소지수 분류', # different colors by group
                style='인구감소지수 분류', # different shapes by group
                s=80, # marker size
                data=oph_rate)

plt.title('2016년 1인가구비율')
plt.xlabel('가구수')
plt.ylabel('1인가구비율')

plt.savefig('output/one_person_household_total_rate_2016.png', bbox_inches='tight')
plt.show()

# %%
sns.scatterplot(x='총가구_2020', 
                y='전체_1인가구_청년_2020', 
                hue='인구감소지수 분류', # different colors by group
                style='인구감소지수 분류', # different shapes by group
                s=80, # marker size
                data=oph_rate)

plt.title('2020년 청년 1인가구비율')
plt.xlabel('인구수')
plt.ylabel('청년 1인가구비율')

plt.savefig('output/one_person_household_youth_rate_2020.png', bbox_inches='tight')
plt.show()

# %%
sns.scatterplot(y='전체_1인가구_노년_2020', 
                x='총가구_2020', 
                hue='인구감소지수 분류', # different colors by group
                style='인구감소지수 분류', # different shapes by group
                s=80, # marker size
                data=oph_rate)

plt.title('2020년 노년 1인가구비율')
plt.xlabel('인구수')
plt.ylabel('노년 1인가구비율')

plt.savefig('output/one_person_household_senior_rate_2020.png', bbox_inches='tight')
plt.show()

# %%
oph_89 = oph_rate[oph_rate['인구감소지수 분류'].isin(['인구감소지역'])]
oph_89
# Out:
#             전체_1인가구비율_2016  전체_1인가구_미성년_2016  전체_1인가구_청년_2016  \
# sigungu
# 강원도 > 고성군         0.436737          0.011523         0.177732
# 강원도 > 삼척시         0.361491          0.014600         0.093607
# 강원도 > 양구군         0.364687          0.001166         0.158324
# 강원도 > 양양군         0.334627          0.000882         0.035711
# 강원도 > 영월군         0.341264          0.001721         0.031477
# ...                    ...               ...              ...
# 충청북도 > 단양군        0.318560          0.017041         0.022604
# 충청북도 > 보은군        0.317451          0.000502         0.016073
# 충청북도 > 영동군        0.346648          0.008492         0.065136
# 충청북도 > 옥천군        0.266720          0.001342         0.018633
# 충청북도 > 제천시        0.312518          0.004674         0.074982
#
#             전체_1인가구_장년_2016  전체_1인가구_노년_2016  전체_1인가구비율_2020  \
# sigungu
# 강원도 > 고성군          0.121719         0.125763        0.364831
# 강원도 > 삼척시          0.132924         0.120361        0.403534
# ...

# %%
oph_18 = oph_rate[oph_rate['인구감소지수 분류'].isin(['관심지역'])]
oph_18
# Out:
#              전체_1인가구비율_2016  전체_1인가구_미성년_2016  전체_1인가구_청년_2016  \
# sigungu
# 강원도 > 강릉시          0.330944          0.007906         0.098643
# 강원도 > 동해시          0.277451          0.001463         0.040483
# 강원도 > 속초시          0.302237          0.000966         0.039157
# 강원도 > 인제군          0.349359          0.000691         0.108056
# 경기도 > 동두천시         0.264992          0.001372         0.036804
# 경기도 > 포천시          0.268965          0.001413         0.047232
# 경상남도 > 사천시         0.290780          0.001275         0.040472
# 경상남도 > 통영시         0.279482          0.000874         0.036931
# 경상북도 > 경주시         0.315633          0.006515         0.071302
# 경상북도 > 김천시         0.301896          0.002867         0.057433
# 광주광역시 > 동구         0.392434          0.010600         0.148105
# 대전광역시 > 대덕구        0.281332          0.007226         0.074162
# 대전광역시 > 동구         0.349826          0.022003         0.124971
# 대전광역시 > 중구         0.265839          0.001716         0.058263
# ...

# %%
oph_non = oph_rate[oph_rate['인구감소지수 분류'].isin(['안심지역'])]
oph_non
# Out:
#             전체_1인가구비율_2016  전체_1인가구_미성년_2016  전체_1인가구_청년_2016  \
# sigungu
# 강원도 > 원주시         0.297927          0.004696         0.081047
# 강원도 > 춘천시         0.302081          0.005373         0.092799
# 경기도 > 과천시         0.192765          0.001170         0.042681
# 경기도 > 광명시         0.189236          0.000492         0.033697
# 경기도 > 광주시         0.207996          0.000933         0.040545
# ...                    ...               ...              ...
# 충청북도 > 증평군        0.304992          0.002156         0.074648
# 충청북도 > 진천군        0.280898          0.002897         0.047747
# 충청북도 > 청원구        0.290737          0.003384         0.108297
# 충청북도 > 충주시        0.317183          0.010080         0.096082
# 충청북도 > 흥덕구        0.297677          0.001885         0.105366
#
#             전체_1인가구_장년_2016  전체_1인가구_노년_2016  전체_1인가구비율_2020  \
# sigungu
# 강원도 > 원주시          0.151258         0.060925        0.342413
# 강원도 > 춘천시          0.133613         0.070297        0.332646
# ...

# %%
oph_mean = pd.DataFrame({'인구감소지역':oph_89.mean()})
oph_mean['관심지역']=oph_18.mean()
oph_mean['안심지역']=oph_non.mean()
#oph_mean['전국']=oph_rate.mean()
oph_mean=oph_mean.T
oph_mean
# Out:
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_2116/3700170201.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   oph_mean = pd.DataFrame({'인구감소지역':oph_89.mean()})
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_2116/3700170201.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   oph_mean['관심지역']=oph_18.mean()
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_2116/3700170201.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# ...

# %%
#oph_mean_g = pd.DataFrame({'전체':(oph_mean['전체_1인가구비율_2020']-oph_mean['전체_1인가구비율_2016'])})
oph_mean_g = pd.DataFrame({'미성년':(oph_mean['전체_1인가구_미성년_2020']-oph_mean['전체_1인가구_미성년_2016'])})
oph_mean_g['청년']=oph_mean['전체_1인가구_청년_2020']-oph_mean['전체_1인가구_청년_2016']
oph_mean_g['장년']=oph_mean['전체_1인가구_장년_2020']-oph_mean['전체_1인가구_장년_2016']
oph_mean_g['노년']=oph_mean['전체_1인가구_노년_2020']-oph_mean['전체_1인가구_노년_2016']

oph_mean_g = oph_mean_g.T
oph_mean_g
# Out:
#        인구감소지역      관심지역      안심지역
# 미성년  0.001506  0.001113  0.000445
# 청년  -0.000924  0.008050  0.013490
# 장년   0.009005  0.007404  0.010530
# 노년   0.012922  0.018082  0.012413

# %%
plt.figure(figsize=(20,10))

df=oph_mean_g.plot(kind='bar')

plt.title('2016년과 2020년 1인가구비율 변화')
plt.xticks(rotation=0)
plt.xlabel('세대별')
plt.ylabel('2020년-2016년 1인가구비율')
lgd=df.legend(bbox_to_anchor=(1,1))

plt.savefig('output/one_person_household_mean_bar.png',bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()
