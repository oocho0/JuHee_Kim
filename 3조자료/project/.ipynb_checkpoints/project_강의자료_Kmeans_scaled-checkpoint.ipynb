# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #서브 패키지 pyplot 사용
# %matplotlib inline
from sklearn.cluster import KMeans

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
else:
    print('Unknown system...  sorry~~~')

# %%
import seaborn as sns #seaborn 패키지 임포트

# %%
data=pd.read_csv('project.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SIG_CD       89 non-null     int64
#  1   SIG_KOR_NM   89 non-null     object
#  2   유소년비율        89 non-null     float64
#  3   조출생률         89 non-null     float64
#  4   1인 가구비율      89 non-null     float64
#  5   터널수          89 non-null     int64
#  6   만명당 매장 수     89 non-null     float64
#  7   만명 당 의료기관 수  89 non-null     float64
#  8   만명당 3차병원수    89 non-null     float64
#  9   만명당 2차병원 수   89 non-null     float64
#  10  만명당 1차병원 수   89 non-null     float64
#  11  만명당 요양병원 수   89 non-null     float64
#  12  만먕당 한의원 수    89 non-null     float64
#  13  1차산업비율       89 non-null     float64
#  14  2차산업비율       89 non-null     float64
#  15  ktx거리        89 non-null     float64
#  16  빈집비율         89 non-null     float64
#  17  산지면적/도시면적    89 non-null     float64
#  18  재정자립도        89 non-null     float64
#  19  연평균인구증감률     89 non-null     float64
#  20  시도           89 non-null     object
#  21  시군구          89 non-null     object
# dtypes: float64(17), int64(2), object(3)
# memory usage: 15.4+ KB

# %%
pj_data = data.drop(['SIG_CD','SIG_KOR_NM','시도'], axis=1)
pj_data.set_index('시군구', inplace=True)
pj_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 89 entries, 강원도 고성군 to 충청북도 제천시
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   유소년비율        89 non-null     float64
#  1   조출생률         89 non-null     float64
#  2   1인 가구비율      89 non-null     float64
#  3   터널수          89 non-null     int64
#  4   만명당 매장 수     89 non-null     float64
#  5   만명 당 의료기관 수  89 non-null     float64
#  6   만명당 3차병원수    89 non-null     float64
#  7   만명당 2차병원 수   89 non-null     float64
#  8   만명당 1차병원 수   89 non-null     float64
#  9   만명당 요양병원 수   89 non-null     float64
#  10  만먕당 한의원 수    89 non-null     float64
#  11  1차산업비율       89 non-null     float64
#  12  2차산업비율       89 non-null     float64
#  13  ktx거리        89 non-null     float64
#  14  빈집비율         89 non-null     float64
#  15  산지면적/도시면적    89 non-null     float64
#  16  재정자립도        89 non-null     float64
#  17  연평균인구증감률     89 non-null     float64
# dtypes: float64(17), int64(1)
# memory usage: 13.2+ KB

# %%
X=pj_data
from sklearn import preprocessing
X=preprocessing.StandardScaler().fit(X).transform(X)

# %%
kmeans=KMeans(n_clusters=3, init='k-means++',max_iter=300, random_state=0)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
kmeans.labels_
# Out:
# array([0, 2, 1, 1, 2, 2, 0, 2, 1, 1, 0, 1, 2, 0, 0, 2, 2, 2, 1, 2, 2, 2,
#        2, 2, 0, 2, 1, 2, 1, 2, 1, 2, 2, 1, 2, 2, 0, 0, 2, 2, 1, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 1, 2, 2, 2, 1, 2, 1, 2, 2, 2, 2, 2, 2, 2, 1, 0, 1, 2, 2, 2, 1,
#        2], dtype=int32)

# %%
cluster = kmeans.predict(X)
cluster
# Out:
# array([0, 2, 1, 1, 2, 2, 0, 2, 1, 1, 0, 1, 2, 0, 0, 2, 2, 2, 1, 2, 2, 2,
#        2, 2, 0, 2, 1, 2, 1, 2, 1, 2, 2, 1, 2, 2, 0, 0, 2, 2, 1, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 1, 2, 2, 2, 1, 2, 1, 2, 2, 2, 2, 2, 2, 2, 1, 0, 1, 2, 2, 2, 1,
#        2], dtype=int32)

# %%
pj_data['cluster']=kmeans.labels_

# %%
pj_data.head(3)
# Out:
#              유소년비율      조출생률   1인 가구비율  터널수  만명당 매장 수  만명 당 의료기관 수  만명당 3차병원수  \
# 시군구
# 강원도 고성군   7.629285  3.657877  0.364831    1  0.746505     8.584812        0.0
# 강원도 삼척시   9.679533  5.455404  0.403534   20  0.609542     8.381208        0.0
# 강원도 양구군  11.836990  7.104875  0.294097    7  0.893695     8.936950        0.0
#
#          만명당 2차병원 수  만명당 1차병원 수  만명당 요양병원 수  만먕당 한의원 수  1차산업비율  2차산업비율  \
#        [-1.99496019e+01,  6.47975034e+00],
#        [-2.48888205e+01, -3.90584478e-02],
#        [-4.71025206e+00,  3.88448798e+01],
#        [-2.24095176e+01, -6.52387475e+00],
#        [-7.39650109e+00,  1.17591384e+01],
#        [-1.05640885e+01,  1.25618263e+01],
#        [-1.64340572e+01, -4.78210771e+00],
#        [-1.37935843e+01,  8.23666790e+00],
#        [-2.38465984e+01, -2.54677054e+00],
#        [-1.38075646e+01, -4.81537027e+00],
#        [-2.61666516e+01, -4.44961213e+00],
#        [-1.43686934e+01, -2.59344175e+01],
#        [ 1.93488310e+01,  8.13353572e+00],
#        [-2.16869116e+01, -1.80569122e+00],
#        [ 7.08664649e+00, -1.11612448e+01],
#        [ 2.08386160e-01, -6.31330064e+00],
#        [ 4.73398490e+01, -1.13737844e+01],
#        [-2.59469303e+01, -2.13012532e+01],
#        [ 6.71396724e+01, -2.18598077e+01],
#        [-1.90083978e+01, -1.36562568e+01],
#        [-1.33157262e+01, -1.20942436e-01],
#        [-2.83663992e+01, -1.87895440e+01],
#        [-1.47707336e+01,  1.95875068e+01],
#        [-1.75027554e+01, -6.32729915e+00],
#        [-1.90940852e+01,  3.81543299e+00],
#        [-1.87035728e+01,  2.28868807e+00],
#        [ 2.92980617e+01, -4.71494499e+00],
#        [-7.10892925e+00,  4.80622964e+01],
#        [ 2.33675171e+01, -1.41126578e+01],
#        [-1.46897733e+01, -2.44351849e+01],
#        [-8.21545456e-01,  2.74553468e+00],
#        [-4.16361594e-01,  7.28744839e+00],
#        [ 3.07710496e+01, -2.50884064e+01],
#        [-2.64976423e+01, -2.07399690e+01]])

# %%
pj_data['pca_x']=pca_transformed[:,0]
pj_data['pca_y']=pca_transformed[:,1]
pj_data.head()
# Out:
#              유소년비율      조출생률   1인 가구비율  터널수  만명당 매장 수  만명 당 의료기관 수  만명당 3차병원수  \
# 시군구
# 강원도 고성군   7.629285  3.657877  0.364831    1  0.746505     8.584812        0.0
# 강원도 삼척시   9.679533  5.455404  0.403534   20  0.609542     8.381208        0.0
# 강원도 양구군  11.836990  7.104875  0.294097    7  0.893695     8.936950        0.0
# 강원도 양양군   7.984798  3.221428  0.361109   52  0.723916     7.239164        0.0
# 강원도 영월군   7.560308  3.207719  0.378748   11  1.043161     8.345286        0.0
#
#          만명당 2차병원 수  만명당 1차병원 수  만명당 요양병원 수  ...  1차산업비율  2차산업비율    ktx거리  \
# 시군구                                          ...
# 강원도 고성군    0.000000    0.000000    0.000000  ...   23.08   12.13  78.2998
# 강원도 삼척시    0.152386    0.152386    0.152386  ...    9.12   16.64   6.5740
# 강원도 양구군    0.000000    1.340542    0.000000  ...   28.26    7.83  69.6764
# 강원도 양양군    0.000000    0.000000    0.000000  ...   25.15   12.57  42.4503
# 강원도 영월군    0.260790    0.260790    0.260790  ...   25.87   12.82  23.6510
#
#          빈집비율   산지면적/도시면적  재정자립도  연평균인구증감률  cluster       pca_x      pca_y
# 시군구
# 강원도 고성군  15.6   44.137726    8.6   -2.9116        0   26.001930  46.577977
# 강원도 삼척시  17.2   13.059622   13.5   -1.6028        2  -22.188643 -17.414424
# 강원도 양구군   7.8  142.838275    8.1   -1.8544        1  118.711348  15.331218
# 강원도 양양군  23.7   44.811864   14.1    0.6621        1   22.618265   4.444090
# 강원도 영월군  11.3   36.154246   15.2   -0.8921        2    6.476984  -5.721065
#
# [5 rows x 21 columns]

# %%
plt.scatter(x=pj_data.loc[:,'pca_x'],y=pj_data.loc[:,'pca_y'],
           c=pj_data['cluster'])

# %%
pj_data.reset_index(inplace=True)
clusterDF = pd.DataFrame(data=pca_transformed, columns=['ftr1','ftr2'])
clusterDF['cluster'] = pj_data['cluster']
clusterDF
# Out:
#           ftr1       ftr2  cluster
# 0    26.001930  46.577977        0
# 1   -22.188643 -17.414424        2
# 2   118.711348  15.331218        1
# 3    22.618265   4.444090        1
# 4     6.476984  -5.721065        2
# ..         ...        ...      ...
# 84  -14.689773 -24.435185        2
# 85   -0.821545   2.745535        2
# 86   -0.416362   7.287448        2
# 87   30.771050 -25.088406        1
# 88  -26.497642 -20.739969        2
#
# [89 rows x 3 columns]

# %%
centers=kmeans.cluster_centers_
centers
# Out:
# array([[  6.32036161,  44.46903801],
#        [ 45.2086858 , -11.31776696],
#        [-14.3763928 ,  -3.95033729]])

# %%
unique_labels=np.unique(cluster)
unique_labels
# Out:
# array([0, 1, 2], dtype=int32)

# %%
markers=['o','s','^','P','D','H','x']

for target in unique_labels :
    target_cluster = clusterDF[clusterDF['cluster']==target]
    plt.scatter(x=target_cluster['ftr1'], y=target_cluster['ftr2'],
               edgecolor='k', marker=markers[target])
plt.show()

# %%
for label in unique_labels:
    
    label_cluster=clusterDF[clusterDF['cluster']==label]
    center_x_y=centers[label]
    plt.scatter(x=label_cluster['ftr1'], y=label_cluster['ftr2'],
                edgecolor='k', marker=markers[label])
    
    center_x_y=centers[label]
    
    plt.scatter(x=center_x_y[0], y=center_x_y[1], s=220, color='white',
               alpha=0.9, edgecolor='k',  marker=markers[label])
    
    plt.scatter(x=center_x_y[0], y=center_x_y[1], s=80, color='k',
                edgecolor='k', marker='$%d$' % label)
    
    
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
# %matplotlib inline

# %%
pj_data.set_index('시군구',inplace=True)
pj_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 89 entries, 강원도 고성군 to 충청북도 제천시
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   유소년비율        89 non-null     float64
#  1   조출생률         89 non-null     float64
#  2   1인 가구비율      89 non-null     float64
#  3   터널수          89 non-null     int64
#  4   만명당 매장 수     89 non-null     float64
#  5   만명 당 의료기관 수  89 non-null     float64
#  6   만명당 3차병원수    89 non-null     float64
#  7   만명당 2차병원 수   89 non-null     float64
#  8   만명당 1차병원 수   89 non-null     float64
#  9   만명당 요양병원 수   89 non-null     float64
#  10  만먕당 한의원 수    89 non-null     float64
#  11  1차산업비율       89 non-null     float64
#  12  2차산업비율       89 non-null     float64
#  13  ktx거리        89 non-null     float64
#  14  빈집비율         89 non-null     float64
#  15  산지면적/도시면적    89 non-null     float64
#  16  재정자립도        89 non-null     float64
#  17  연평균인구증감률     89 non-null     float64
#  18  cluster      89 non-null     int32
#  19  pca_x        89 non-null     float64
#  20  pca_y        89 non-null     float64
# dtypes: float64(19), int32(1), int64(1)
# memory usage: 14.9+ KB

# %%
pj_data.to_csv('project_result.csv')

# %%
inertia=[]
for k in range(2,7):
    km=KMeans(n_clusters=k)
    km.fit(X)
    inertia.append(km.inertia_)
plt.plot(range(2,7), inertia)
plt.xlabel('k')
plt.ylabel('inertia')
plt.savefig('approprate_k.png')
plt.show()

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

print(__doc__)

# Generating the sample data from make_blobs
# This particular setting has one distinct cluster and 3 clusters placed close
# together.
# Out:
# Automatically created module for IPython interactive environment

# %%
X= pca_transformed

# %%
y= kmeans.labels_

# %%
range_n_clusters = [2, 3, 4, 5, 6]

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, (ax1, ax2) = plt.subplots(1, 2)
#     fig.set_size_inches(18, 7)
    fig.set_size_inches(12, 4)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(X, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    # 2nd Plot showing the actual clusters formed
    colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
    ax2.scatter(X[:, 0], X[:, 1], marker='.', s=30, lw=0, alpha=0.7,
                c=colors, edgecolor='k')

    # Labeling the clusters
    centers = clusterer.cluster_centers_
    # Draw white circles at cluster centers
    ax2.scatter(centers[:, 0], centers[:, 1], marker='o',
                c="white", alpha=1, s=200, edgecolor='k')

    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker='$%d$' % i, alpha=1,
                    s=50, edgecolor='k')

    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature space for the 1st feature")
    ax2.set_ylabel("Feature space for the 2nd feature")

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')

plt.show()
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.5014481428826069
# For n_clusters = 3 The average silhouette_score is : 0.5093421736715819
# For n_clusters = 4 The average silhouette_score is : 0.3591304600777184
# For n_clusters = 5 The average silhouette_score is : 0.36476394751668517
# For n_clusters = 6 The average silhouette_score is : 0.3802344791205391

# %% [markdown]
# ####
