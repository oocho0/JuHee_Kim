# %% [markdown]
# ## 고용률
# - 자료출처
# <br>「지역별고용조사」, 통계청

# %%
import pandas as pd

emp_rate = pd.read_csv('./empRate.csv')
emp_rate
# Out:
#         sigungu  경제활동인구   고용율
# 0      부산광역시 중구    41.8  53.1
# 1      부산광역시 서구   100.6  51.5
# 2      부산광역시 동구    82.3  50.4
# 3     부산광역시 영도구    99.9  47.5
# 4    부산광역시 부산진구   355.2  54.0
# ..          ...     ...   ...
# 196    경상남도 하동군    51.0  70.3
# 197    경상남도 산청군    44.7  74.5
# 198    경상남도 함양군    45.8  67.6
# 199    경상남도 거창군    71.7  67.9
# 200    경상남도 합천군    49.6  66.8
#
# [201 rows x 3 columns]

# %%
emp_rate.set_index('sigungu', inplace=True)
emp_rate.sort_index(inplace=True)
emp_rate
# Out:
#           경제활동인구   고용율
# sigungu
# 강원도 강릉시    235.2  61.4
# 강원도 고성군     34.2  70.1
# 강원도 동해시     91.4  61.9
# 강원도 삼척시     70.0  61.0
# 강원도 속초시     84.5  62.3
# ...          ...   ...
# 충청북도 제천시   144.9  60.1
# 충청북도 증평군    41.8  65.8
# 충청북도 진천군   113.0  71.4
# 충청북도 청주시   928.1  61.7
# 충청북도 충주시   241.2  63.8
#
# [201 rows x 2 columns]

# %%
emp_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 201 entries, 강원도 강릉시 to 충청북도 충주시
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   경제활동인구  201 non-null    float64
#  1   고용율     201 non-null    float64
# dtypes: float64(2)
# memory usage: 4.7+ KB

# %%
ingu_89 = ['부산광역시 동구', '부산광역시 서구', '부산광역시 영도구', '대구광역시 남구', '대구광역시 서구',
           '인천광역시 강화군', '인천광역시 옹진군', '경기도 가평군', '경기도 연천군', '강원도 고성군', '강원도 삼척시',
          '강원도 양구군', '강원도 양양군', '강원도 영월군', '강원도 정선군', '강원도 철원군', '강원도 태백시',
          '강원도 평창군', '강원도 홍천군', '강원도 화천군', '강원도 횡성군', '충청북도 괴산군', '충청북도 단양군',
          '충청북도 보은군', '충청북도 영동군', '충청북도 옥천군', '충청북도 제천시', '충청남도 공주시', '충청남도 금산군',
          '충청남도 논산시', '충청남도 보령시', '충청남도 부여군', '충청남도 서천군', '충청남도 예산군', '충청남도 청양군',
          '충청남도 태안군', '전라북도 고창군', '전라북도 김제시', '전라북도 남원시', '전라북도 무주군', '전라북도 부안군',
          '전라북도 순창군', '전라북도 임실군', '전라북도 장수군', '전라북도 정읍시', '전라북도 진안군', '전라남도 강진군',
          '전라남도 고흥군', '전라남도 곡성군', '전라남도 구례군', '전라남도 담양군', '전라남도 보성군', '전라남도 신안군',
          '전라남도 영광군', '전라남도 영암군', '전라남도 완도군', '전라남도 장성군', '전라남도 장흥군', '전라남도 진도군',
          '전라남도 함평군', '전라남도 해남군', '전라남도 화순군', '경상북도 고령군', '경상북도 군위군', '경상북도 문경시',
          '경상북도 봉화군', '경상북도 상주시', '경상북도 성주군', '경상북도 안동시', '경상북도 영덕군', '경상북도 영양군',
          '경상북도 영주시', '경상북도 영천시', '경상북도 울릉군', '경상북도 울진군', '경상북도 의성군', '경상북도 청도군',
          '경상북도 청송군', '경상남도 거창군', '경상남도 고성군', '경상남도 남해군', '경상남도 밀양시', '경상남도 산청군',
          '경상남도 의령군', '경상남도 창녕군', '경상남도 하동군', '경상남도 함안군', '경상남도 함양군', '경상남도 합천군']

# %%
semi_18 = ['대전광역시 동구','인천광역시 동구','부산광역시 중구','부산광역시 금정구','광주광역시 동구','경상남도 통영시',
           '강원도 강릉시','강원도 동해시','대전광역시 중구','경상북도 경주시','경상남도 사천시', '경상북도 김천시',
          '대전광역시 대덕구','강원도 인제군','전라북도 익산시','경기도 동두천시','강원도 속초시','경기도 포천시']

# %%
emp_rate['인구감소지수 분류']='안심지역'

for i in ingu_89 :
    emp_rate.loc[i,'인구감소지수 분류'] = '인구감소지역'
    
for i in semi_18 :
    emp_rate.loc[i,'인구감소지수 분류'] = '관심지역'

emp_rate
# Out:
#           경제활동인구   고용율 인구감소지수 분류
# sigungu
# 강원도 강릉시    235.2  61.4      관심지역
# 강원도 고성군     34.2  70.1    인구감소지역
# 강원도 동해시     91.4  61.9      관심지역
# 강원도 삼척시     70.0  61.0    인구감소지역
# 강원도 속초시     84.5  62.3      관심지역
# ...          ...   ...       ...
# 충청북도 제천시   144.9  60.1    인구감소지역
# 충청북도 증평군    41.8  65.8      안심지역
# 충청북도 진천군   113.0  71.4      안심지역
# 충청북도 청주시   928.1  61.7      안심지역
# 충청북도 충주시   241.2  63.8      안심지역
#
# [201 rows x 3 columns]

# %%
emp_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 201 entries, 강원도 강릉시 to 충청북도 충주시
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   경제활동인구     201 non-null    float64
#  1   고용율        201 non-null    float64
#  2   인구감소지수 분류  201 non-null    object
# dtypes: float64(2), object(1)
# memory usage: 14.4+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rc

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')
sns.scatterplot(x='경제활동인구', 
                y='고용율', 
                hue='인구감소지수 분류', # different colors by group
                style='인구감소지수 분류', # different shapes by group
                s=80, # marker size
                data=emp_rate)

plt.title('2021년 고용률')
plt.xlabel('경제활동인구')
plt.ylabel('고용률 비율')

plt.savefig('output/employment_rate_2021.png')
plt.show()

# %%
emp_89 = emp_rate[emp_rate['인구감소지수 분류'].isin(['인구감소지역'])]
emp_89
# Out:
#           경제활동인구   고용율 인구감소지수 분류
# sigungu
# 강원도 고성군     34.2  70.1    인구감소지역
# 강원도 삼척시     70.0  61.0    인구감소지역
# 강원도 양구군     23.4  71.2    인구감소지역
# 강원도 양양군     33.9  71.5    인구감소지역
# 강원도 영월군     43.4  65.8    인구감소지역
# ...          ...   ...       ...
# 충청북도 단양군    32.6  66.1    인구감소지역
# 충청북도 보은군    39.3  69.1    인구감소지역
# 충청북도 영동군    53.4  63.0    인구감소지역
# 충청북도 옥천군    56.4  63.2    인구감소지역
# 충청북도 제천시   144.9  60.1    인구감소지역
#
# [89 rows x 3 columns]

# %%
sido_89 = pd.read_csv('../total_pop/sido.csv')
sido_89.set_index('sigungu', inplace=True)
sido_89.sort_index(inplace=True)
sido_89
# Out:
#           sido
# sigungu
# 강원도 고성군    강원도
# 강원도 삼척시    강원도
# 강원도 양구군    강원도
# 강원도 양양군    강원도
# 강원도 영월군    강원도
# ...        ...
# 충청북도 단양군  충청북도
# 충청북도 보은군  충청북도
# 충청북도 영동군  충청북도
# 충청북도 옥천군  충청북도
# 충청북도 제천시  충청북도
#
# [89 rows x 1 columns]

# %%
pop_89=pd.read_csv('../total_pop/pop_89.csv')
pop_89.rename(columns={'행정구역(시군구)별':'sigungu'}, inplace=True)
pop_89.set_index('sigungu',inplace=True)
pop_89.sort_index(inplace=True)
pop_89
# Out:
#           total_2016  total_2017  total_2018  total_2019  total_2020
# sigungu
# 강원도 고성군      29867.0     29855.0     28873.0     27484.0     26791.5
# 강원도 삼척시      69481.5     68371.0     67786.5     67156.5     65623.0
# 강원도 양구군      23899.0     23776.5     23479.0     22940.0     22379.0
# 강원도 양양군      27160.0     27014.5     27067.5     27323.5     27627.5
# 강원도 영월군      39573.0     39510.5     39347.0     38872.0     38345.0
# ...              ...         ...         ...         ...         ...
# 충청북도 단양군     30272.5     30010.0     29901.0     29679.5     29143.0
# 충청북도 보은군     33930.5     33828.5     33570.0     33023.0     32402.5
# 충청북도 영동군     50237.0     50011.0     49597.5     48851.0     47736.5
# 충청북도 옥천군     51881.5     51587.0     51207.0     50841.5     50381.0
# 충청북도 제천시    135290.0    135469.0    134949.0    134051.0    132882.5
#
# [89 rows x 5 columns]

# %%
emp_89['sido']=sido_89['sido']
emp_89['pop']=pop_89['total_2020']
emp_89
# Out:
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_2920/2762604305.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emp_89['sido']=sido_89['sido']
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_2920/2762604305.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emp_89['pop']=pop_89['total_2020']
#           경제활동인구   고용율 인구감소지수 분류  sido       pop
# sigungu
# 강원도 고성군     34.2  70.1    인구감소지역   강원도   26791.5
# 강원도 삼척시     70.0  61.0    인구감소지역   강원도   65623.0
# 강원도 양구군     23.4  71.2    인구감소지역   강원도   22379.0
# 강원도 양양군     33.9  71.5    인구감소지역   강원도   27627.5
# 강원도 영월군     43.4  65.8    인구감소지역   강원도   38345.0
# ...          ...   ...       ...   ...       ...
# 충청북도 단양군    32.6  66.1    인구감소지역  충청북도   29143.0
# 충청북도 보은군    39.3  69.1    인구감소지역  충청북도   32402.5
# 충청북도 영동군    53.4  63.0    인구감소지역  충청북도   47736.5
# 충청북도 옥천군    56.4  63.2    인구감소지역  충청북도   50381.0
# 충청북도 제천시   144.9  60.1    인구감소지역  충청북도  132882.5
#
# [89 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

sns.scatterplot(x='경제활동인구', y='고용율',s=60,data=emp_89)

plt.title('인구감소지역 고용률')
plt.xlabel('경제활동인구')
plt.ylabel('교용률')
plt.legend(fontsize=6)
plt.savefig('output/emp_rate_89_sido.png', bbox_inches='tight')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sig_cd = pd.read_csv('../total_pop/sig_cd.csv')
sig_cd.set_index('sigungu', inplace=True)
sig_cd.sort_index(inplace=True)
sig_cd
# Out:
#           SIG_CD SIG_KOR_NM
# sigungu
# 강원도 고성군    42820        고성군
# 강원도 삼척시    42230        삼척시
# 강원도 양구군    42800        양구군
# 강원도 양양군    42830        양양군
# 강원도 영월군    42750        영월군
# ...          ...        ...
# 충청북도 단양군   43800        단양군
# 충청북도 보은군   43720        보은군
# 충청북도 영동군   43740        영동군
# 충청북도 옥천군   43730        옥천군
# 충청북도 제천시   43150        제천시
#
# [89 rows x 2 columns]

# %%
emp_89['sig_cd']=sig_cd['SIG_CD']
emp_89
# Out:
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_2920/1897561922.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emp_89['sig_cd']=sig_cd['SIG_CD']
#           경제활동인구   고용율 인구감소지수 분류  sido       pop  sig_cd
# sigungu
# 강원도 고성군     34.2  70.1    인구감소지역   강원도   26791.5   42820
# 강원도 삼척시     70.0  61.0    인구감소지역   강원도   65623.0   42230
# 강원도 양구군     23.4  71.2    인구감소지역   강원도   22379.0   42800
# 강원도 양양군     33.9  71.5    인구감소지역   강원도   27627.5   42830
# 강원도 영월군     43.4  65.8    인구감소지역   강원도   38345.0   42750
# ...          ...   ...       ...   ...       ...     ...
# 충청북도 단양군    32.6  66.1    인구감소지역  충청북도   29143.0   43800
# 충청북도 보은군    39.3  69.1    인구감소지역  충청북도   32402.5   43720
# 충청북도 영동군    53.4  63.0    인구감소지역  충청북도   47736.5   43740
# 충청북도 옥천군    56.4  63.2    인구감소지역  충청북도   50381.0   43730
# 충청북도 제천시   144.9  60.1    인구감소지역  충청북도  132882.5   43150
#
# [89 rows x 6 columns]

# %%
emp_89.to_csv('emp_89_result.csv')
