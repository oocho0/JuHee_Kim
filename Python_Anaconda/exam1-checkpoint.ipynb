# %% [markdown]
# # 정적 웹 크롤링과 스크래핑

# %% [markdown]
# ### <span style='color:red'>urllib.request.urlopen()</span> 함수로 웹페이지 소스 크롤링하기

# %%
import urllib.request
res = urllib.request.urlopen("http://www.naver.com/")
print(type(res))
print(res.status)
print("NAVER 웹페이지의 소스 내용----------------------------------------------------------------")
print(res.read().decode('utf-8'))
# Out:
# <class 'http.client.HTTPResponse'>
# 200
# NAVER 웹페이지의 소스 내용----------------------------------------------------------------
#
# <!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>  <link rel="stylesheet" href="https://pm.pstatic.net/dist/css/nmain.20221110.css"> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css"> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1"/>  <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"/> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"/> <script>window.nmain=window.nmain||{},window.nmain.supportFlicking=!1;var nsc="navertop.v4",ua=navigator.userAgent,useIeJSFlag="1";window.nmain.isIE="0"===useIeJSFlag,document.getElementsByTagName("html")[0].setAttribute("data-useragent",ua),window.nmain.isIE&&(Object.create=function(n){function a(){}return a.prototype=n,new a})</script> <script>var darkmode= false;window.naver_corp_da=window.naver_corp_da||{main:{}},window.naver_corp_da.main=window.naver_corp_da.main||{},window.naver_corp_da.main.darkmode=darkmode,window.gladsdk=window.gladsdk||{cmd:[]},window.gladsdk.cmd.push((function(){window.gladsdk.setHostMeta("theme",darkmode?"dark":"light")})),window.ndpsdk=window.ndpsdk||{cmd:[],polyfill:{cmd:[]}},window.ndpsdk.cmd.push((function(){window.ndpsdk.setHostMeta("theme",darkmode?"dark":"light")}))</script>  <script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script async src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script>  <script> window.nmain.gv = {  isLogin: false,
# useId: null,   daInfo: {"BEAUTY":{"menu":"BEAUTY","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000163","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_1","tb":"BEAUTY_1","unit":"SU10595","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000164","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_2","tb":"BEAUTY_1","unit":"SU10596","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVING":{"menu":"LIVING","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000183","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_1","tb":"LIVING_1","unit":"SU10597","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000184","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_2","tb":"LIVING_1","unit":"SU10606","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVINGHOME":{"menu":"LIVINGHOME","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000185","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_livinghome_1","tb":"LIVINGHOME_1","unit":"SU10571","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000186","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_livinghome_2","tb":"LIVINGHOME_1","unit":"SU10572","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]}},
# svt: 20221116112545,
# }; </script> <script> window.nmain.newsstand = {
# rcode: '02190111',
# newsCastSubsInfo: '',
# newsStandSubsInfo: ''
# };
# window.etc = {  };
# window.svr = "<!--aweb15-->"; </script> <script src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js" defer="defer"></script>   <script src="https://pm.pstatic.net/dist/js/external.2961eaa5.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script> <script src="https://pm.pstatic.net/dist/js/preload.5fe99fda.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script> <script src="https://pm.pstatic.net/dist/js/polyfill.f3c68d2d.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script>  <script src="https://pm.pstatic.net/dist/js/vendors~more~nmain~notice~search~sidebar_notice.40da85e0.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script>   <script src="https://pm.pstatic.net/dist/js/search.607b49e4.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script>  <script src="https://pm.pstatic.net/dist/js/vendors~more~nmain~sidebar_notice.7aad5e27.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script> <script src="https://pm.pstatic.net/dist/js/nmain.e31af4db.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script> <style>:root{color-scheme:light}#_nx_kbd .setkorhelp a{display:none}</style> </head> <body> <div id="u_skip"> <a href="#newsstand"><span>뉴스스탠드 바로가기</span></a> <a href="#themecast"><span>주제별캐스트 바로가기</span></a> <a href="#timesquare"><span>타임스퀘어 바로가기</span></a> <a href="#shopcast"><span>쇼핑캐스트 바로가기</span></a> <a href="#account"><span>로그인 바로가기</span></a> </div> <div id="wrap">
# <style>._1syGnXOL{padding-right:18px;font-size:14px;line-height:0;letter-spacing:-.25px;color:#000}._1syGnXOL span,._1syGnXOL strong{line-height:49px}._1syGnXOL:before{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220513@2x.png);background-repeat:no-repeat;background-size:141px 112px;width:18px;height:18px;margin:16px 8px 0 0;background-position:-98px 0}[data-useragent*="MSIE 8"] ._1syGnXOL:before{background-image:url(https://static-whale.pstatic.net/main/sprite-20220513.png)}._1syGnXOL._3dsvmZg2:before{background-position:-47px -85px}._1syGnXOL._1NBFx1WK:before{width:20px;height:20px;margin:15px 8px 0 0;background-position:-21px -89px}._1syGnXOL._2mcQEKCd:before{width:22px;height:22px;margin:14px 7px 0 0;background-position:-47px -63px}._1syGnXOL._36slsKuJ:before{width:21px;height:49px;margin:0 14px 0 0;background-position:0 -63px}._1syGnXOL._3qlJVWzR:before{width:24px;height:49px;margin:0 10px 0 0;background-position:-117px 0}._1syGnXOL._3di88A4c{padding-right:12px;font-size:17px}._1syGnXOL._3di88A4c:before{content:none}._1syGnXOL ._19K4X1CD{text-decoration:underline}._2aeXMlrb{display:inline-block;position:relative;font-size:12px;height:49px;width:78px;text-decoration:none;color:#fff;font-weight:700;letter-spacing:-.5px;vertical-align:top}._2aeXMlrb span{text-align:center;margin:9px 0;height:31px;display:block;line-height:31px;border-radius:15px}._2aeXMlrb span:before{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220513@2x.png);background-repeat:no-repeat;background-size:141px 112px}[data-useragent*="MSIE 8"] ._2aeXMlrb span:before{background-image:url(https://static-whale.pstatic.net/main/sprite-20220513.png)}._2aeXMlrb.BMgpjddw{font-size:11px;width:94px}._2aeXMlrb.BMgpjddw span:before{margin:9px 3px 0 0;width:17px;height:13px;background-position:-89px -63px}._3h-N8T9V{position:absolute;top:0;left:0;right:0;bottom:0;background:rgba(0,0,0,0)}._1KncATpM{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220513@2x.png);background-repeat:no-repeat;background-size:141px 112px;margin-top:14px;float:left;width:98px;height:21px;background-position:0 -21px}[data-useragent*="MSIE 8"] ._1KncATpM{background-image:url(https://static-whale.pstatic.net/main/sprite-20220513.png)}._1KncATpM._2v3uxv2x{background-position:0 0}._1KncATpM._1yl_Ow6o{background-position:0 -42px}._20PYt6lT{font-size:11px;height:49px;cursor:pointer;position:absolute;top:0;right:0;color:#666;opacity:.7}._20PYt6lT:after{width:15px;height:15px;margin-left:4px;background-position:-98px -33px;display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220513@2x.png);background-repeat:no-repeat;background-size:141px 112px}[data-useragent*="MSIE 8"] ._20PYt6lT:after{background-image:url(https://static-whale.pstatic.net/main/sprite-20220513.png)}._20PYt6lT._39oMCV2N:after{background-position:-98px -18px}._20PYt6lT._3MOWOORv{color:#c3c2c2}._20PYt6lT._3MOWOORv:after{background-position:-80px -85px}._20PYt6lT._3wm5EzmJ{color:#fff}._20PYt6lT._3wm5EzmJ:after{background-position:-65px -85px}._1hiMWemA{height:49px}._1hiMWemA .tY_u8r23{position:relative;width:1130px;margin:0 auto}._1hiMWemA .tY_u8r23 a{text-decoration:none}._1hiMWemA._23U_6TM_{position:relative}._1hiMWemA._23U_6TM_:after{position:absolute;z-index:1;content:"";display:block;width:100%;height:1px;bottom:0;background-color:rgba(0,0,0,.050980392156862744)}</style>
# <div
# id="NM_TOP_BANNER"
# data-clk-prefix="top"
# class="_1hiMWemA"
# style="background-color: #21232b"
# >
# <div class="tY_u8r23">
# <a
# class="_3h-N8T9V"
# href="https://whale.naver.com/banner/details/darkmode?=main&wpid=RydDy7"
# data-clk="dropbanner1b"
# ></a
# ><i class="_1KncATpM _1yl_Ow6o"><span class="blind">NAVER whale</span></i
# ><img
# src="https://static-whale.pstatic.net/main/img_darkmode_v12@2x.png"
# width="200"
# height="49"
# alt=""
# style="padding-left: 100px"
# /><span
# class="_1syGnXOL _3di88A4c"
# data-clk="dropbanner1b"
# style="padding-right: 20px; color: white; padding-left: 20px"
# ><span>눈부심 없는 편안~함 </span
# ><strong style="color: #22d4ad">내가 다크 모드 쓰는 이유</strong></span
# ><a
# href="https://installer-whale.pstatic.net/downloads/banner/RydDy7/WhaleSetup.exe"
# class="_2aeXMlrb BMgpjddw"
# id="NM_whale_download_btn"
# data-clk="dropdownload1b"
# ><span style="background-color: #03bc93">다운로드</span></a
# ><button
# type="button"
# data-ui-cookie-exp-days="3"
# data-ui-cookie-key="NM_TOP_PROMOTION"
# data-ui-cookie-value="1"
# data-ui-hide-target="#NM_TOP_BANNER"
# data-clk="dropclose1b"
# class="_20PYt6lT _3wm5EzmJ"
# >
# 3일 동안 보지 않기
# </button>
# </div>
# </div>  <div id="header" role="banner">
#
#
#
#
#
#
#
#
# <div class="special_bg">
# <div class="group_flex">
# <div class="logo_area">
# <h1 class="logo_default">
# <a href="/" class="logo_naver" data-clk="top.logo"
# ><span class="blind">네이버</span></a
# >
# </h1>
# </div>
# <div class="service_area">
# <a id="NM_set_home_btn" href="https://help.naver.com/support/welcomePage/guide.help" class="link_set" data-clk="top.mkhome">네이버를 시작페이지로</a>
# <i class="sa_bar"></i>
# <a href="https://jr.naver.com" class="link_jrnaver" data-clk="top.jrnaver"><i class="ico_jrnaver"></i><span class="blind">쥬니어네이버</span></a>
# <a href="https://happybean.naver.com" class="link_happybin" data-clk="top.happybean"><i class="ico_happybin"></i><span class="blind">해피빈</span></a>
# </div>
#
# <div id="search" class="search_area" data-clk-prefix="sch">
# <form id="sform" name="sform" action="https://search.naver.com/search.naver" method="get" role="search">
# <fieldset>
# <legend class="blind">검색</legend>
# <select id="where" name="where" title="검색 범위 선택" class="blind">
# <option value="nexearch" selected="selected">통합검색</option><option value="post">블로그</option><option value="cafeblog">카페</option><option value="cafe">- 카페명</option><option value="article">- 카페글</option><option value="kin">지식iN</option><option value="news">뉴스</option><option value="web">사이트</option><option value="category">- 카테고리</option><option value="site">- 사이트</option><option value="movie">영화</option><option value="webkr">웹문서</option><option value="dic">사전</option><option value="100">- 백과사전</option><option value="endic">- 영어사전</option><option value="eedic">- 영영사전</option><option value="krdic">- 국어사전</option><option value="jpdic">- 일본어사전</option><option value="hanja">- 한자사전</option><option value="terms">- 용어사전</option><option value="book">책</option><option value="music">음악</option><option value="doc">전문자료</option><option value="shop">쇼핑</option><option value="local">지역</option><option value="video">동영상</option><option value="image">이미지</option><option value="mypc">내PC</option><optgroup label="스마트 파인더"><option value="movie">영화</option><option value="auto">자동차</option><option value="game">게임</option><option value="health">건강</option><option value="people">인물</option></optgroup><optgroup label="네이버 랩"><option>긍정부정검색</option></optgroup>
# </select>
# <input type="hidden" id="sm" name="sm" value="top_hty" />
# <input type="hidden" id="fbm" name="fbm" value="0" />
# <input type="hidden" id="acr" name="acr" value="" disabled="disabled" />
# <input type="hidden" id="acq" name="acq" value="" disabled="disabled" />
# <input type="hidden" id="qdt" name="qdt" value="" disabled="disabled" />
# <input type="hidden" id="ie" name="ie" value="utf8" />
# <input type="hidden" id="acir" name="acir" value="" disabled="disabled" />
# <input type="hidden" id="os" name="os" value="" disabled="disabled" />
# <input type="hidden" id="bid" name="bid" value="" disabled="disabled" />
# <input type="hidden" id="pkid" name="pkid" value="" disabled="disabled" />
# <input type="hidden" id="eid" name="eid" value="" disabled="disabled" />
# <input type="hidden" id="mra" name="mra" value="" disabled="disabled" />
#
#
#
# <div class="green_window" style=''>
# <!-- [AU] data-atcmp-element 에 해당하는 attribute를 추가해주세요. -->
# <input id="query" name="query" type="text" title="검색어 입력" maxlength="255" class="input_text" tabindex="1" accesskey="s" style="ime-mode:active;" autocomplete="off"  placeholder="검색어를 입력해 주세요." onclick="document.getElementById('fbm').value=1;" value="" data-atcmp-element>
# </div>
# <button id="search_btn" type="submit" title="검색" tabindex="3" class="btn_submit" onclick="window.nclick(this,'sch.action','','',event);" style=''>
# <span class="blind">검색</span>
# <span class="ico_search_submit"></span>
# </button>
# </fieldset>
# </form>
# <!-- 한글입력기 -->
# <a href="#" id="ke_kbd_btn" role="button" class="btn_keyboard" onclick="return false;"><span class="blind">한글 입력기</span><span class="ico_keyboard"></span></a>
# <div id="_nx_kbd" style="display:none;"></div>
# <div class="autocomplete">
# <!-- 자동완성 열린 경우 fold 클래스 추가, 딤드인 경우 dim 추가 -->
# <a href="#" role="button" id="nautocomplete" tabindex="2" class="btn_arw _btn_arw fold" aria-pressed="false" data-atcmp-element><span class="blind">자동완성 레이어</span><span class="ico_arr"></span></a>
# </div>
# <!-- 자동완성레이어 -->
# <div id="autoFrame" class="reatcmp" style="display: none;">
# <!-- [AU] data-atcmp-element attribute를 추가해주세요. -->
# <div class="ly_atcmp" data-atcmp-element>
# <div class="api_atcmp_wrap">
# <!-- 최근검색어 -->
# <!-- [AU] _recent_layer 클래스를 추가해주세요. -->
# <div class="atcmp_fixer _recent_layer" style="display:none;">
# <!-- [AU] _recent_header 클래스를 추가해주세요. -->
# <div class="atcmp_header _recent_header">
# <strong class="tit">최근검색어</strong>
# <div class="option">
# <!-- [AU] _delAll 클래스를 추가해주세요. -->
# <a role="button" href="#" class="item _delAll" aria-pressed="false">전체삭제</a>
# </div>
# </div>
# <div class="atcmp_container">
# <!-- [AU] _recent 클래스를 추가해주세요. -->
# <ul class="kwd_lst _recent">
# <!-- 최근검색어 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="history" data-keyword="@in_txt@" attribute를 추가해주세요. -->
# <li class="item _item" data-rank="@rank@" data-template-type="history" data-keyword="@in_txt@">
# <a href="#" class="kwd">
# <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span><span>@txt@</span></span>
# </a>
# <span class="etc">
# <em class="date">@date@.</em>
# <!-- [AU] _del 클래스를 추가해주세요. -->
# <a href="#" role="button" class="bt_item _del" aria-pressed="false"><i class="imsc ico_del">삭제</i></a>
# </span>
# </li>
# </ul>
# <!-- [D] 검색어 저장 꺼진 경우 atcmp_fixer에 type_off 추가 -->
# <!-- [AU] _offMsg 클래스를 추가해주세요. -->
# <div class="kwd_info kwd_off _offMsg" style="display: none;">검색어 저장 기능이 꺼져 있습니다.<br><span class="kwd_dsc">설정이 초기화 된다면 <a href="https://help.naver.com/support/alias/search/word/word_29.naver" class="kwd_help" data-clk="sly.help" target="_blank">도움말</a>을 확인해주세요.</span></div>
# <!-- [D] 검색어 내역 없는 경우 atcmp_fixer에 type_off 추가 -->
# <!-- [AU] _recentNone 클래스를 추가해주세요. -->
# <div class="kwd_info kwd_none _recentNone" style="display: none;">최근 검색어 내역이 없습니다.<br><span class="kwd_dsc">설정이 초기화 된다면 <a href="https://help.naver.com/support/alias/search/word/word_29.naver" class="kwd_help" data-clk="sly.help" target="_blank">도움말</a>을 확인해주세요.</span></div>
# </div>
# <div class="atcmp_footer">
# <span class="side_opt_area">
# <span class="opt_item"><a href="https://help.naver.com/support/service/main.help?serviceNo=605&amp;categoryNo=1991" data-clk="sly.help" target="_blank">도움말</a></span>
# </span>
# <span class="rside_opt_area">
# <span class="opt_item">
# <!-- [AU] _keywordOnOff 클래스를 추가해주세요. -->
# <a href="#" class="close _keywordOnOff">자동저장 끄기</a>
# </span>
# </span>
# </div>
# </div>
# <!-- 자동완성 -->
# <!-- [AU] _atcmp_layer 클래스를 추가해주세요. -->
# <div class="atcmp_fixer _atcmp_layer" style="display:none;">
# <!-- [AU] _words 클래스를 추가해주세요. -->
# <div class="atcmp_container _words">
# <!-- 정답형 템플릿 : 로또당첨번호 -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_3" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
# <div class="atcmp_correct type_lotto _answer" data-template-type="answer_3" data-code="@code@" data-keyword="@1@">
# <a href="#" class="link_item">
# <span class="common_ico_kwd"><i class="imsc ico_search"></i></span>
# <div class="dsc_area">
# <span class="tit">@5@회차 당첨번호</span>
# <span class="dsc">
# <span class="item">추첨 @13@.</span><span class="item">지급기한 1년</span>
# </span>
# </div>
# <span class="etc_area">
# <span class="etc lotto">
# <em class="n@6@">@6@</em><em class="n@7@">@7@</em><em class="n@8@">@8@</em><em class="n@9@">@9@</em><em class="n@10@">@10@</em><em class="n@11@">@11@</em><em class="imsc_bf bonus n@12@">@12@</em>
# </span>
# </span>
# </a>
# </div>
# <!-- 정답형 템플릿 : 환율 -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_9" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
# <div class="atcmp_correct type_exchange _answer" data-template-type="answer_9" data-code="@code@" data-keyword="@1@">
# <!-- [D] 상승 up, 하락 down 추가 -->
# <a href="#" class="link_item @11@">
# <!-- [D] 국가별 class 가나다순
# ZAR 남아프리카 공화국
# NPR 네팔
# NOK 노르웨이
# NZD 뉴질랜드
# TWD 대만
# DKK 덴마크
# RUB 러시아
# MOP 마카오
# MYR 말레이시아
# MXN 멕시코
# MNT 몽골
# USD 미국
# BHD 바레인
# BDT 방글라데시
# VND 베트남
# BRL 브라질
# SAR 사우디아라비아
# SEK 스웨덴
# CHF 스위스
# SGD 싱가포르
# AED 아랍에미리트
# GBP 영국
# EUR 유럽연합
# ILS 이스라엘
# EGP 이집트
# INR 인도
# IDR 인도네시아
# JPY 일본
# CNY 중국
# CZK 체코
# CLP 칠레
# KZT 카자흐스탄
# QAR 카타르
# CAD 캐나다
# KWD 쿠웨이트
# THB 태국
# TRY 터키
# PKR 파키스탄
# PLN 폴란드
# PHP 필리핀
# HUF 헝가리
# AUD 호주
# HKD 홍콩
# -->
# <span class="common_ico_kwd"><i class="imsc ico @12@">@14@</i></span>
# <div class="dsc_area">
# <span class="tit">@txt@<span class="sub">@currency@</span></span>
# <span class="dsc">
# <span class="item"><i class="imsc ico_arr"></i>@8@(@9@%)</span>
# </span>
# </div>
# <span class="etc_area">
# <span class="etc"><em class="num">@6@</em>원</span>
# </span>
# </a>
# </div>
# <!-- 정답형 템플릿 : 날씨(국내11, 해외12) -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_11" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
# <div class="atcmp_correct type_weather _answer" data-template-type="answer_11" data-code="@code@" data-keyword="@1@">
# <!-- [D] 상승 up, 하락 down 추가 -->
# <a href="#" class="link_item @12@">
# <span class="common_ico_kwd"><i class="imsc ico_search"></i></span>
# <div class="dsc_area">
# <span class="tit">@txt@</span>
# <span class="dsc">
# <span class="item">@7@, @message@</span>
# </span>
# </div>
# <span class="etc_area">
# <span class="etc">
# <!-- [D] 날씨별 class
# ico1 맑음(낮)
# ico2 맑음(밤)
# ico3 구름조금(낮)
# ico4 구름조금(밤)
# ico5 구름많음(낮)
# ico6 구름많음(밤)
# ico7 흐림
# ico8 약한비
# ico9 비
# ico10 강한비
# ico11 약한눈
# ico12 눈
# ico13 강한눈
# ico14 진눈깨비
# ico15 소나기
# ico16 안개
# ico17 소낙눈
# ico18 번개뇌우
# ico19 우박
# ico20 황사
# ico21 비또는눈
# ico22 가끔비
# ico23 가끔눈
# ico24 가끔비또는눈
# ico25 흐린후갬
# ico26 뇌우후갬
# ico27 비후갬
# ico28 눈후갬
# ico29 흐려져비
# ico30 흐려져눈
# -->
# <span class="ico_weather"><i class="imsc ico ico@iconNo@">@7@</i></span>
# <em class="degree">@8@<sup class="celsius">°</sup></em>
# </span>
# </span>
# </a>
# </div>
# <!-- 정답형 템플릿 : 사이트 바로가기 -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_17" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
# <div class="atcmp_correct type_site _answer" data-template-type="answer_17" data-code="@code@" data-keyword="@1@">
# <a href="@5@" class="link_item" target="_blank">
# <span class="common_ico_kwd"><i class="imsc ico_url"></i></span>
# <div class="dsc_area">
# <span class="tit">@txt@</span>
# <span class="dsc">
# <span class="item">@5@</span>
# </span>
# </div>
# <span class="etc_area">
# <span class="etc">바로가기</span>
# </span>
# </a>
# </div>
# <!-- [AU] _kwd_list 클래스를 추가해주세요. -->
# <ul class="kwd_lst _kwd_list">
# <!-- [AU] 자동완성 검색어 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-rank="@rank@" data-template-type="suggestion" data-keyword="@in_txt@" attribute를 추가해주세요. -->
# <li class="item _item" data-rank="@rank@" data-template-type="suggestion" data-keyword="@in_txt@">
# <a href="#" class="kwd">
# <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@txt@</span>
# </a>
# <span class="etc">
# <a href="#" role="button" class="bt_item _add" aria-pressed="false"><i class="imsc ico_insert">추가</i></a>
# </span>
# </li>
# <!-- [AU] 최근검색어 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-rank="@rank@" data-template-type="history" data-keyword="@in_txt@" attribute를 추가해주세요. -->
# <li class="item has_correct _item" data-rank="@rank@" data-template-type="history" data-keyword="@in_txt@">
# <a href="#" class="kwd">
# <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@txt@</span>
# </a>
# <span class="etc">
# <!-- 최근검색어 있으면 날짜 표시 -->
# <em class="date">@date@.</em>
# <a href="#" role="button" class="bt_item _add" aria-pressed="false"><i class="imsc ico_insert">추가</i></a>
# </span>
# </li>
# </ul>
# <!-- [AU] 문맥검색 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-rank="@rank@" data-template-type="intend" data-keyword="@transQuery@" attribute를 추가해주세요. -->
# <li class="item has_correct _item" data-rank="@rank@" data-intend-rank="@intendRank@" data-template-type="intend" data-keyword="@transQuery@">
# <a href="#" class="kwd">
# <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@query@ <span class="context">@intend@</span></span>
# </a>
# <span class="etc">
# <a href="#" role="button" class="bt_item _add" aria-pressed="false"><i class="imsc ico_insert">추가</i></a>
# </span>
# </li>
# <!-- [D] 선거안내문구 -->
# <!-- [AU] _alert 클래스를 추가해주세요. -->
# <div class="atcmp_alert _alert">
# <div class="dsc_election">
# <p class="dsc">
# <i class="imsc ico_election"></i><span class="_alert_passage"></span>
# </p>
# <span class="dsc_inner">
# <!-- [AU] _alert_passage2 클래스를 추가해주세요. -->
# <span class="_alert_passage2"></span>
# <!-- [AU] _alert_link 클래스를 추가해주세요. -->
# <a href="#" class="link _alert_link" target="_blank">자세히보기</a>
# </span>
# </div>
# </div>
# <!-- [AU] _plus 클래스를 추가해주세요. -->
# <div class="atcmp_plus _plus">
# <div class="dsc_plus">
# <a href="https://help.naver.com/support/alias/search/word/word_16.naver" class="link_dsc" data-clk="sug.cxhelp" target="_blank">관심사를 반영한 컨텍스트 자동완성<i class="imsc ico_help">도움말</i></a>
# </div>
# <div class="switch">
# <!-- [D] 선택시 aria-pressed="ture/false" -->
# <!-- [AU] _plus_btn 클래스를 추가해주세요. -->
# <a role="button" href="#" class="bt_switch active _plus_btn" aria-pressed="false"><i class="imsc ico_option">컨텍스트 자동완성</i></a>
# </div>
# <!-- [AU] _plus_layer 클래스를 추가해주세요. -->
# <div class="layer_plus _plus_layer">
# <strong class="tit">컨텍스트 자동완성</strong>
# <!-- [AU] _plus_layer_isloggedin 클래스를 추가해주세요. -->
# <!-- [AU] style="display:none" 추가해주세요. -->
# <div class="_plus_layer_isloggedin" style="display:none">
# <p class="dsc">ON/OFF 설정은<br>해당기기(브라우저)에 저장됩니다.</p>
# <div class="btn_area">
# <a href="https://help.naver.com/support/alias/search/word/word_16.naver" class="btn btn_view" data-clk="sug.cxlink" target="_blank">자세히</a>
# </div>
# </div>
# <!-- [AU] _plus_layer_isnotloggedin 클래스를 추가해주세요. -->
# <!-- [AU] style="display:none" 추가해주세요. -->
# <div class="_plus_layer_isnotloggedin" style="display:none">
# <p class="dsc"><em class="txt">동일한 시간대/연령/남녀별</em> 사용자 그룹의<br>관심사에 맞춰 자동완성을 제공합니다.</p>
# <div class="btn_area">
# <a href="https://nid.naver.com/nidlogin.login" class="btn btn_login" data-clk="sug.cxlogin">로그인</a>
# <a href="https://help.naver.com/support/alias/search/word/word_16.naver" class="btn btn_view" data-clk="sug.cxlink" target="_blank">자세히</a>
# </div>
# </div>
# <!-- [AU] _plus_layer_close 클래스를 추가해주세요. -->
# <a href="#" role="button" class="btn_close _plus_layer_close"><i class="imsc ico_close">컨텍스트 자동완성 레이어 닫기</i></a>
# </div>
# </div>
# </div>
# <div class="atcmp_footer">
# <span class="side_opt_area">
# <span class="opt_item"><a href="https://help.naver.com/alias/search/word/word_17.naver" data-clk="sug.help" target="_blank">도움말</a></span>
# <span class="opt_item"><a href="https://help.naver.com/support/contents/contents.help?serviceNo=605&categoryNo=18215" class="report" data-clk="sug.report" target="_blank">신고</a></span>
# </span>
# <span class="rside_opt_area">
# <span class="opt_item">
# <!-- [AU] _suggestOnOff 클래스를 추가해주세요. -->
# <a href="#" class="close _suggestOnOff">자동완성 끄기</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
#
# </div>
# </div>
#
# <!--EMPTY-->
# <div id="gnb" role="navigation">
# <div id="NM_FAVORITE" class="gnb_inner">
# <div class="group_nav">
# <ul class="list_nav type_fix">
# <li class="nav_item">
# <a href="https://mail.naver.com/" class="nav" data-clk="svc.mail"><i class="ico_mail"></i>메일</a>
# </li>
# <li class="nav_item"><a href="https://section.cafe.naver.com/" class="nav" data-clk="svc.cafe">카페</a></li>
# <li class="nav_item"><a href="https://section.blog.naver.com/" class="nav" data-clk="svc.blog">블로그</a></li>
# <li class="nav_item"><a href="https://kin.naver.com/" class="nav" data-clk="svc.kin">지식iN</a></li>
# <li class="nav_item"><a href="https://shopping.naver.com/" class="nav shop" data-clk="svc.shopping"><span class="blind">쇼핑</span></a></li>
# <li class="nav_item"><a href="https://shoppinglive.naver.com/home" class="nav shoplive"
# data-clk="svc.shoppinglive"><span class="blind">쇼핑LIVE</span></a></li>
# <li class="nav_item"><a href="https://order.pay.naver.com/home" class="nav" data-clk="svc.pay">Pay</a></li>
# <li class="nav_item">
# <a href="https://tv.naver.com/" class="nav" data-clk="svc.tvcast"><i class="ico_tv"></i>TV</a>
# </li>
# </ul>
# <ul
# class="list_nav NM_FAVORITE_LIST"
# >
# <li class="nav_item"><a href="https://dict.naver.com/" class="nav" data-clk="svc.dic">사전</a></li>
# <li class="nav_item"><a href="https://news.naver.com/" class="nav" data-clk="svc.news">뉴스</a></li>
# <li class="nav_item"><a href="https://finance.naver.com/" class="nav" data-clk="svc.stock">증권</a></li>
# <li class="nav_item"><a href="https://land.naver.com/" class="nav" data-clk="svc.land">부동산</a></li>
# <li class="nav_item"><a href="https://map.naver.com/" class="nav" data-clk="svc.map">지도</a></li>
# <li class="nav_item"><a href="https://vibe.naver.com/" class="nav" data-clk="svc.vibe">VIBE</a></li>
# <li class="nav_item"><a href="https://search.shopping.naver.com/book/home" class="nav" data-clk="svc.book">도서</a></li>
# <li class="nav_item"><a href="https://comic.naver.com/" class="nav" data-clk="svc.webtoon">웹툰</a></li>
#
# </ul>
# <ul class="list_nav type_empty" style="display: none;"></ul>
# <a href="#" role="button" class="btn_more" data-clk="svc.more">더보기</a>
# <div class="ly_btn_area">
# <a href="more.html" class="btn NM_FAVORITE_ALL" data-clk="map.svcmore">서비스 전체보기</a>
# <a href="#" role="button" class="btn btn_set" data-clk="map.edit">메뉴설정</a>
# <a href="#" role="button" class="btn btn_reset" data-clk="edt.reset">초기화</a>
# <a href="#" role="button" class="btn btn_save" data-clk="edt.save">저장</a>
# </div>
# </div>
# <div id="NM_WEATHER" class="group_weather">
# <div>
# <a data-clk="squ.weat" href="https://weather.naver.com/today/02190111?cpName=KMA" class="weather_area ico_w05">
# <div class="current_box">
# <strong class="current" aria-label="현재기온">12.1°</strong><strong class="state">구름많음</strong>
# </div>
# <div class="degree_box">
# <span class="min" aria-label="최저기온">6.0°</span><span class="max" aria-label="최고기온">13.0°</span>
# </div>
# <span class="location">심곡본동</span>
# </a>
# </div>
# <div>
# <a data-clk="squ.dust" href="https://weather.naver.com/today/02190111?cpName=KMA" class="air_area">
# <ul class="list_air">
# <li class="air_item">미세<strong class="state state_normal">보통</strong></li>
# <li class="air_item">초미세<strong class="state state_bad">나쁨</strong></li>
# </ul>
# <span class="location">심곡본동</span>
# </a>
# </div>
#
# </div>
# </div>
# <div class="ly_service">
# <div class="group_service NM_FAVORITE_ALL_LY"></div>
# <div class="group_service NM_FAVORITE_EDIT_LY" style="display: none;"></div>
# </div>
# </div>
# </div>
#  <div id="container" role="main"> <div style="position:relative;width:1130px;margin:0 auto;z-index:11"> <div id="da_top"></div> <div id="da_expwide"></div> </div> <div id="NM_INT_LEFT" class="column_left"> <div id="veta_top"> <div id="veta_top_inner" style="height:135px"> </div> <span class="veta_bd_t"></span> <span class="veta_bd_b"></span> <span class="veta_bd_l"></span> <span class="veta_bd_r"></span> </div> <div id="newsstand" class="sc_newscast"> <h2 class="blind">뉴스스탠드</h2> <div id="NM_NEWSSTAND_HEADER" class="group_issue" data-clk-prefix="ncy"> <div class="issue_area"> <a class="link_media" href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y" data-clk="newsflash">연합뉴스</a> <div id="NM_ONELINE_ROLLING" class="list_issue" data-nm-ui="rolling"> <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013578871" class="issue" data-clk="quickarticle">[1보] 트럼프, 2024년 대선출마 공식선언…세 번째 대권 도전</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013578780" class="issue" data-clk="quickarticle">[속보] 바이든 "폴란드 타격한 미사일, 러시아발 아닌듯"</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013578871" class="issue" data-clk="quickarticle">[1보] 트럼프, 2024년 대선출마 공식선언…세 번째 대권 도전</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013578854" class="issue" data-clk="quickarticle">'세월호 보고시간 조작' 김기춘 파기환송심서 무죄</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013578871" class="issue" data-clk="quickarticle">[1보] 트럼프, 2024년 대선출마 공식선언…세 번째 대권 도전</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013578864" class="issue" data-clk="quickarticle">스벅·투썸·맥도날드·롯데리아 임금체불 등 노동법 위반 적발</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013578871" class="issue" data-clk="quickarticle">[1보] 트럼프, 2024년 대선출마 공식선언…세 번째 대권 도전</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013578722" class="issue" data-clk="quickarticle">검찰, '서해 피격' 서주석 前 청와대 안보실 1차장 소환</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013578871" class="issue" data-clk="quickarticle">[1보] 트럼프, 2024년 대선출마 공식선언…세 번째 대권 도전</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013578749" class="issue" data-clk="quickarticle">[이태원 참사] 수능 후 경찰 770명 동원해 인파관리</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013578871" class="issue" data-clk="quickarticle">[1보] 트럼프, 2024년 대선출마 공식선언…세 번째 대권 도전</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013578765" class="issue" data-clk="quickarticle">금리 부담에 집 안 산다…주택 매매심리지수 역대 최저</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013578871" class="issue" data-clk="quickarticle">[1보] 트럼프, 2024년 대선출마 공식선언…세 번째 대권 도전</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013578213" class="issue" data-clk="quickarticle">尹대통령, 순방 마치고 귀국…이상민에 "고생 많았다" 악수</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013578871" class="issue" data-clk="quickarticle">[1보] 트럼프, 2024년 대선출마 공식선언…세 번째 대권 도전</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013578797" class="issue" data-clk="quickarticle">둔촌주공 일반분양 3.3㎡당 3천829만원…84㎡ 중도금대출 불가</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013578871" class="issue" data-clk="quickarticle">[1보] 트럼프, 2024년 대선출마 공식선언…세 번째 대권 도전</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013578553" class="issue" data-clk="quickarticle">190억원 미납 전자담배 업자…사망한 전두환 체납자 명단서 빠져</a></div> </div> </div> <div class="direct_area"> <a href="https://m.sports.naver.com/qatar2022/index" class="link_worldcup" data-clk="qatar2022"><span class="blind">QATAR 2022</span></a> <a href="http://news.naver.com/" class="link_news" data-clk="newshome">뉴스홈</a>
# <a href="http://entertain.naver.com/home" class="link_direct" data-clk="entertainment">연예</a>
# <a href="http://sports.news.naver.com/" class="link_direct" data-clk="sports">스포츠</a>
# <a href="http://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=101" class="link_direct" data-clk="economy">경제</a> </div> </div>        <div id="NM_NEWSSTAND_TITLE" class="group_title" data-clk-prefix="nsd"> <a href="http://newsstand.naver.com/" class="link_newsstand" data-clk="title" target="_blank">뉴스스탠드</a> <div id="NM_NEWSSTAND_data_buttons" class="sort_area" role="tablist">  <a href="#" role="tab" data-type="my" data-clk="my" class="btn_sort" aria-controls="NM_NEWSSTAND_MY_LIST" aria-selected="false">구독한 언론사</a> <a href="#" role="tab" data-type="all" data-clk="all" class="btn_sort" aria-controls="NM_NEWSSTAND_DEFAULT_THUMB" aria-selected="true">전체언론사</a>  </div> <div id="NM_NEWSSTAND_view_buttons" class="set_area" role="tablist">  <a href="#" role="tab" data-type="list" data-clk="articleview" class="btn_set" aria-controls="NM_NEWSSTAND_DEFAULT_LIST" aria-selected="false"> <i class="ico_list"><span class="blind">리스트형</span></i></a> <a href="#" role="tab" data-type="thumb" data-clk="pressview" class="btn_set" aria-controls="NM_NEWSSTAND_DEFAULT_THUMB" aria-selected="true"> <i class="ico_tile"><span class="blind">썸네일형</span></i></a>  <a href="http://newsstand.naver.com/config.html" class="btn_set" data-clk="set" target="_blank"> <i class="ico_set"><span class="blind">설정</span></i></a> </div> </div> <div id="NM_NEWSSTAND_VIEW_CONTAINER" style="position:relative"> <div id="NM_NEWSSTAND_DEFAULT_LIST" class="group_news" role="tabpanel" style="display:none" data-clk-prefix="nsd_all"> <a href="#" role="button" class="pm_btn_prev_l _NM_NEWSSTAND_LIST_prev_btn" data-clk-custom="prev"><i class="ico_btn"><span class="blind">이전</span></i></a> <a href="#" role="button" class="pm_btn_next_l _NM_NEWSSTAND_LIST_next_btn" data-clk-custom="next"><i class="ico_btn"><span class="blind">다음</span></i></a> <div class="list_view"> <div class="option_area"> <div class="list_option_wrap"> <ul class="list_option"> <li class="option_item" data-cateid="ct2"><a href="#" class="option" data-clk="daei">종합/경제</a></li> <li class="option_item" data-cateid="ct3"><a href="#" class="option" data-clk="dtvcom">방송/통신</a></li> <li class="option_item" data-cateid="ct4"><a href="#" class="option" data-clk="dit">IT</a></li> <li class="option_item" data-cateid="ct5"><a href="#" class="option" data-clk="deng">영자지</a></li> <li class="option_item" data-cateid="ct6"><a href="#" class="option" data-clk="dsporent">스포츠/연예</a></li> <li class="option_item" data-cateid="ct7"><a href="#" class="option" data-clk="dmagtec">매거진/전문지</a></li> <li class="option_item" data-cateid="ct8"><a href="#" class="option" data-clk="dloc">지역</a></li> </ul> </div> </div> <div class="_NM_NEWSSTAND_ARTICLE_CONTAINER" data-clk-sub="*a"></div> </div> <div class="ly_popup NM_NEWSSTAND_POPUP NM_NEWSSTAND_invalid" style="display:none" data-clk-sub="*a"> <a href="#" role="button" class="btn_close NM_NEWSSTAND_POPUP_CLOSE"><i class="ico_close"></i><span class="blind">닫기</span></a> <p class="popup_msg">해당 언론사 사정으로 접근이 제한됩니다.</p> <div class="popup_btn"> <a href="#" role="button" class="btn_confirm NM_NEWSSTAND_POPUP_CLOSE">확인</a> </div> </div> <div class="ly_popup NM_NEWSSTAND_POPUP NM_NEWSSTAND_undescribe_confirm" style="display:none" data-clk-sub="*a"> <a href="#" role="button" class="btn_close NM_NEWSSTAND_POPUP_CLOSE" data-clk="usclose"><i class="ico_close"></i><span class="blind">닫기</span></a> <p class="popup_msg"><strong class="NM_NEWSSTAND_POPUP_PNAME"></strong>을(를)<br>구독해지 하시겠습니까?</p> <div class="popup_btn"> <a href="#" role="button" class="btn_confirm NM_NEWSSTAND_POPUP_CONFIRM" data-clk="usdone">확인</a> <a href="#" role="button" class="btn_confirm NM_NEWSSTAND_POPUP_CLOSE" data-clk="uscancel">취소</a> </div> </div> <div class="ly_toast NM_NEWSSTAND_TOAST" style="display:none"> <p class="toast_msg">구독한 언론사에 추가되었습니다.</p> </div> </div>   <div id="NM_NEWSSTAND_DEFAULT_THUMB" class="group_news" role="tabpanel" style="display:block" data-clk-prefix="nsd_all"> <a href="#" role="button" class="pm_btn_prev ...
# <div class="tile_view">
# <div class="frame_area">
# <i class="line to_right1"></i>
# <i class="line to_right2"></i>
# <i class="line to_right3"></i>
# <i class="line to_bottom1"></i>
# <i class="line to_bottom2"></i>
# <i class="line to_bottom3"></i>
# <i class="line to_bottom4"></i>
# <i class="line to_bottom5"></i>
# </div>
# <div class="thumb_area">
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="930"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/930.png"
# height="20"
# alt="뉴스타파"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="930"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="930"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=930"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="930"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="014"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/014.png"
# height="20"
# alt="파이낸셜뉴스"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="014"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="014"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=014"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="014"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="016"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/016.png"
# height="20"
# alt="헤럴드경제"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="016"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="016"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=016"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="016"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="015"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/015.png"
# height="20"
# alt="한국경제"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="015"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="015"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=015"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="015"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="092"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/up/2022/0905/nsd131925414.png"
# height="20"
# alt="지디넷코리아"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="092"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="092"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=092"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="092"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="327"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/327.png"
# height="20"
# alt="뉴데일리"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="327"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="327"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=327"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="327"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="422"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/422.png"
# height="20"
# alt="연합뉴스TV"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="422"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="422"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=422"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="422"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="904"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/904.png"
# height="20"
# alt="JTBC"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="904"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="904"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=904"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="904"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="057"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/057.png"
# height="20"
# alt="MBN"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="057"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="057"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=057"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="057"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="032"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/032.png"
# height="20"
# alt="경향신문"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="032"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="032"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=032"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="032"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="330"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/330.png"
# height="20"
# alt="중앙데일리"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="330"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="330"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=330"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="330"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="025"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/up/2021/0824/nsd115034872.png"
# height="20"
# alt="중앙일보"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="025"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="025"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=025"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="025"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="109"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/up/2020/0610/nsd151458769.png"
# height="20"
# alt="OSEN"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="109"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="109"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=109"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="109"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="139"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/139.png"
# height="20"
# alt="스포탈코리아"
# class="news_logo"
# />
# ...
# 						<span class="thumb_bd"></span>
#
# 					</a>
# 					<a href="https://blog.naver.com/leedasom0817/222905488086" class="theme_info" data-clk="tcc_bty.list12cont2" target="_blank">
# 						<em class="theme_category"> 패션뷰티</em>
# 						<strong class="title elss">지방시 르 루즈 앵떼르디</strong>
#                         <p class="desc">찬바람 부는 가을, 겨울 바르기 좋은 F/W 세미 매트 립스틱 찾고있나요? 안녕하세요 여러분 다지입니다 저는 평소 매트립 너무 좋아하는데 건조한 요즘 날씨에도 각질부각이나 푸석함없이 매끈하게 발리는 세미 매트한 신상 립스틱을 가져왔답니다 :) 두근두근 이번 지방시 뷰티에서 새로운 #세미매트립스틱 이 출시되었는데요 이번 패키지는 정말 지방시를 대변하듯 시크함</p>
# 						<div class="source_box">
# 							<span class="date">3주일 전</span>
# 							<span class="source">
#
#                                 <span class="source_inner">다지</span>
#                             </span>
# 						</div>
# 					</a>
# 				</li>
#
# 				<li class="theme_item" data-gdid="e7fed347-fc39-4b94-b9b3-6837a040bcb7" data-da-position="true">
# 					<a href="https://blog.naver.com/skin87/222900489072" class="theme_thumb" data-clk="tcc_bty.list12cont3" target="_blank">
# 						<img  data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fs.pstatic.net%2Fshop.phinf%2F20221020_192%2F166625653561588z98_PNG%2FQRW.PNG%3Ftype%3Df342_264%22&amp;type&#x3D;nf340_228" alt="아이오페 PDRN 카페인샷" width="170" height="114" onerror="this.outerHTML='<span class=\'pm_noimg\'><span class=\'noimg_text\'>이미지 준비중</span></span>'">
# 						<span class="thumb_bd"></span>
#
# 					</a>
# 					<a href="https://blog.naver.com/skin87/222900489072" class="theme_info" data-clk="tcc_bty.list12cont3" target="_blank">
# 						<em class="theme_category"> 패션뷰티</em>
# 						<strong class="title elss">아이오페 PDRN 카페인샷</strong>
#                         <p class="desc">안녕하세요! 우리가 마스크를 착용한지 약 3년이 다 되어가고 있는데요! 그로인해 이런저런 피부변화들이 많이 일어났다고 생각합니다! 그래서 찾아보니 아무래도 여드름, 홍조. 하관 쪽 얼굴 탄력이 제일 이슈가 되었던 것 같아요! 요즘에는 마스크를 외부에선 많이들 off하고 다니실텐데 그래서그런지 리프팅 타이트닝에 상당히 관심들이 많으신 것 같더라구요! 물론 저</p>
# 						<div class="source_box">
# 							<span class="date">1개월 전</span>
# 							<span class="source">
#
#                                 <span class="source_inner">뷰스타뉴진</span>
#                             </span>
# 						</div>
# 					</a>
# 				</li>
#
# 				<li class="theme_item" data-gdid="3d18787a-daac-4b99-85c8-0509d1aff181" data-da-position="true">
# 					<a href="https://blog.naver.com/kjy911203/222868318375" class="theme_thumb" data-clk="tcc_bty.list12cont4" target="_blank">
# 						<img  data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fs.pstatic.net%2Fshop.phinf%2F20221020_250%2F1666256538599aY3yP_PNG%2FFE.PNG%3Ftype%3Df342_264%22&amp;type&#x3D;nf340_228" alt="40~60대 자음생크림 추천" width="170" height="114" onerror="this.outerHTML='<span class=\'pm_noimg\'><span class=\'noimg_text\'>이미지 준비중</span></span>'">
# 						<span class="thumb_bd"></span>
#
# 					</a>
# 					<a href="https://blog.naver.com/kjy911203/222868318375" class="theme_info" data-clk="tcc_bty.list12cont4" target="_blank">
# 						<em class="theme_category"> 패션뷰티</em>
# 						<strong class="title elss">40~60대 자음생크림 추천</strong>
#                         <p class="desc">안뇽하세요, 유니유니입니다. 날씨가 춥고 건조해진 요즘, 내 피부도 피부이지만 저는 며칠전 엄마 얼굴을 자세히 들여다봤는데 어느새 자글자글한 주름과 떨어진 탄력에 무너지는 얼굴라인을 보고 마음이 안좋더라구요. 그래서 50대 60대 화장품! 한국을 대표하는 럭셔리 뷰티 브랜드로 오랜시간 부동의 1위를 지켜오고 있는 설화수의 인기제품! 자음생크림을 선물했어요.</p>
# 						<div class="source_box">
# 							<span class="date">2개월 전</span>
# 							<span class="source">
#
#                                 <span class="source_inner">유니유니</span>
#                             </span>
# 						</div>
# 					</a>
# 				</li>
#
# 				<li class="theme_item" data-gdid="b66de778-13d1-4d01-baeb-7d703fa5fec0" data-da-position="true">
# 					<a href="https://blog.naver.com/30364/222903205949" class="theme_thumb" data-clk="tcc_bty.list12cont5" target="_blank">
# 						<img  data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fs.pstatic.net%2Fshop.phinf%2F20221019_175%2F1666148632026KXYkX_JPEG%2Freg.jpg%3Ftype%3Df342_264%22&amp;type&#x3D;nf340_228" alt="나스 파워매트 립스틱 발색" width="170" height="114" onerror="this.outerHTML='<span class=\'pm_noimg\'><span class=\'noimg_text\'>이미지 준비중</span></span>'">
# 						<span class="thumb_bd"></span>
#
# 					</a>
# 					<a href="https://blog.naver.com/30364/222903205949" class="theme_info" data-clk="tcc_bty.list12cont5" target="_blank">
# 						<em class="theme_category"> 패션뷰티</em>
# 						<strong class="title elss">나스 파워매트 립스틱 발색</strong>
#                         <p class="desc">매트립 맛집, 나스 파워매트 립스틱의 신상 컬러 9가지 쉐이드가 출시됐어요 ! 기존 6가지 컬러에 이어 새로운 나스 파워매트 립스틱 9컬러가 추가되며 총 15가지 컬러 라인업 완성 (짝짝) 기존 나스 파워매트 립스틱 6컬러 발색 리뷰는 다 보셨죠? 나스 파워매트 립스틱 가격 43,000원 대 / 용량 1.5g / 15 shades 이 매트 립스틱은 부드러운</p>
# 						<div class="source_box">
# 							<span class="date">4주일 전</span>
# 							<span class="source">
#
#                                 <span class="source_inner">스텔라</span>
#                             </span>
# 						</div>
# 					</a>
# 				</li>
#
# 		</ul>
# 	</div>
# </div>
# <div class="group_theme" data-block-id="" data-block-code="PC-THEME-BEAUTY-MOBILE-RANKING-VIDEO-11" data-block-type="MATERIALS" data-template-code="MOBILE-RANKING-VIDEO-LIST"
#
# 	 data-index=""
# 	 data-page="6"
# 	 style="display:none">
#
# 	<div class="media_view_wrap type_column">
# 		<div class="media_view">
#
# 				<a href="https://tv.naver.com/v/22489886" class="media_area" data-gdid="614458d6ed257d2befa1d24a" data-clk="tcc_bty.video12cont1" target="_blank">
# 					<div class="media_thumb">
# 						<img  data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fs.pstatic.net%2Fshop.phinf%2F20210917_14%2F16318689326717EsU3_JPEG%2F1631779148409.jpg%3Ftype%3Df342_264%22&amp;type&#x3D;nf464_260" alt="" width="232" height="130" onerror="this.outerHTML='<span class=\'pm_noimg\'><span class=\'noimg_text\'>이미지 준비중</span></span>'">
# 						<span class="thumb_dim"></span>
# 						<span class="thumb_bd"></span>
# 						<i class="pm_ico_play"><span class="blind">재생</span></i>
# 						<span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">09:07</em></span>
# 					</div>
# 					<div class="media_info">
# 						<div class="info_box">
# 							<strong class="title">F/W 트레이닝복 브랜드 모음</strong>
# 							<div class="source_wrap">
# 								<span class="date">1년 전</span>
# 								<span class="source">
#
#                                     <span class="source_inner">누엘</span>
#                                 </span>
# 							</div>
# 						</div>
# 					</div>
# 				</a>
#
# 				<a href="https://tv.naver.com/v/22449677" class="media_area" data-gdid="614069141aed886be13ddf25" data-clk="tcc_bty.video12cont2" target="_blank">
# 					<div class="media_thumb">
# 						<img  data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fs.pstatic.net%2Fshop.phinf%2F20210915_89%2F1631709951208DrtdH_JPEG%2F1631615122828.jpg%3Ftype%3Df342_264%22&amp;type&#x3D;nf464_260" alt="" width="232" height="130" onerror="this.outerHTML='<span class=\'pm_noimg\'><span class=\'noimg_text\'>이미지 준비중</span></span>'">
# 						<span class="thumb_dim"></span>
# 						<span class="thumb_bd"></span>
# 						<i class="pm_ico_play"><span class="blind">재생</span></i>
# 						<span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">08:10</em></span>
# 					</div>
# 					<div class="media_info">
# 						<div class="info_box">
# 							<strong class="title">쟁여놓고 써야하는 올영 잇템 8</strong>
# 							<div class="source_wrap">
# 								<span class="date">1년 전</span>
# 								<span class="source">
#
#                                     <span class="source_inner">블럼 메이크업</span>
#                                 </span>
# 							</div>
# 						</div>
# 					</div>
# 				</a>
#
# 				<a href="https://tv.naver.com/v/22420954" class="media_area" data-gdid="6141eacb06569de4c71631dc" data-clk="tcc_bty.video12cont3" target="_blank">
# 					<div class="media_thumb">
# 						<img  data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fs.pstatic.net%2Fshop.phinf%2F20210916_193%2F1631791861563odWcf_JPEG%2F1631526723559.jpg%3Ftype%3Df342_264%22&amp;type&#x3D;nf464_260" alt="" width="232" height="130" onerror="this.outerHTML='<span class=\'pm_noimg\'><span class=\'noimg_text\'>이미지 준비중</span></span>'">
# 						<span class="thumb_dim"></span>
# 						<span class="thumb_bd"></span>
# 						<i class="pm_ico_play"><span class="blind">재생</span></i>
# 						<span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">09:09</em></span>
# 					</div>
# 					<div class="media_info">
# 						<div class="info_box">
# 							<strong class="title">아무리 발라도 건조한 당신에게</strong>
# 							<div class="source_wrap">
# 								<span class="date">1년 전</span>
# 								<span class="source">
#
#                                     <span class="source_inner">채정안TV</span>
#                                 </span>
# 							</div>
# 						</div>
# 					</div>
# 				</a>
#
# 		</div>
# 	</div>
# </div>
#
#
#
#
#
# 	<div class="btn_more_wrap">
# 		<button type="button" class="btn_more" data-clk-custom="tcc_bty.more" data-next-page="2"><i class="ico_more"></i>새로운 글 더보기</button>
# 	</div>
#
#
# <div class="NM_THEME_META" style="display: none" data-panel-code="BEAUTY" data-parent-code=""></div>
#
# 	</div>
# </div>
#  </div> </div> <div id="NM_INT_RIGHT" class="column_right"> <div class="column_fix_wrap"> <div id="da_brand"></div>
#
#
#
#
#
# <div id="account" class="sc_login">
# <h2 class="blind">Sign in</h2>
# <p class="login_msg">Connect with people</p>
# <a href="https://nid.naver.com/nidlogin.login?mode=form&url=https%3A%2F%2Fwww.naver.com" class="link_login" data-clk="log_off.login"><i class="ico_naver"><span class="blind">NAVER</span></i>Sign in</a>
# <div class="sub_area">
# <div class="look_box">
# <a href="https://nid.naver.com/user/help.nhn?todo=idinquiry" class="link_look" data-clk="log_off.searchid">Forgot Username</a>
# <a href="https://nid.naver.com/nidreminder.form" class="link_look" data-clk="log_off.searchpass">Password</a>
# </div>
# <a href="https://nid.naver.com/nidregister.form?url=https%3A%2F%2Fwww.naver.com" class="link_join" data-clk="log_off.registration">Sign up</a>
# </div>
# </div>
#
#
#
#  <div id="timesquare" class="sc_timesquare"> <h2 class="blind">타임스퀘어</h2> <div class="card_wrap">
# <div class="card_nav">
# <a href="#" role="button" class="btn_nav btn_prev" data-clk="squ.pre"><span class="blind">이전</span></a>
# <a href="#" role="button" class="btn_nav btn_next" data-clk="squ.next"><span class="blind">다음</span></a>
# </div>
# <div id="NM_TS_ROLLING_WRAP" style="height: 100%;">
# <div>
# <a href="https://search.naver.com/search.naver?sm=top_hty&amp;fbm=0&amp;ie=utf8&amp;query=%EC%BD%94%EB%A1%9C%EB%82%9819" class="card_news" data-clk="squ.line3"><i class="news_badge">이슈</i><span class="news">코로나바이러스감염증-19 현황</span></a>
# </div>
# <div>
# <a href="https://finance.naver.com/sise/sise_index.nhn?code=KOSPI" class="card_stock " data-clk="squ.kospi">
# <strong class="stock_title">증시</strong>
# <div class="stock_box">
# <em class="name">코스피</em>
# <strong class="current">2,475.74</strong>
# <span class="rate rate_down"><span class="blind">하락</span>4.59 -0.19%</span>
# </div>
# </a>
# </div>
# <div>
# <a href="https://finance.naver.com/sise/sise_index.nhn?code=KOSDAQ" class="card_stock " data-clk="squ.kosdaq">
# <strong class="stock_title">증시</strong>
# <div class="stock_box">
# <em class="name">코스닥</em>
# <strong class="current">745.15</strong>
# <span class="rate rate_up"><span class="blind">상승</span>0.19 +0.03%</span>
# </div>
# </a>
# </div>
# <div>
# <a href="https://finance.naver.com/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW" class="card_stock type_exchange" data-clk="squ.usd">
# <strong class="stock_title">환율</strong>
# <div class="stock_box">
# <em class="name">USD</em>
# <strong class="current">1,322.60</strong>
# <span class="rate rate_up"><span class="blind">상승</span>6.60 +0.50%</span>
# </div>
# </a>
# </div>
# </div>
# </div> <!-- EMPTY --> </div> <div id="veta_branding"> <span class="blind"> <script id="veta_service_check"></script> </span> <div id="veta_branding_inner" style="width:350px;height:200px"> </div> <span class="veta_bd_t"></span> <span class="veta_bd_b"></span> <span class="veta_bd_l"></span> <span class="veta_bd_r"></span> </div> <div id="shopcast" class="sc_shopcast"> <iframe id="shopcast_iframe" data-iframe-src="/shoppingbox/shoppingboxnew/main.nhn?mode=plusdeal&domain=N" title="쇼핑캐스트" width="350" height="1809" marginheight="0" marginwidth="0" scrolling="no" frameborder="0"></iframe> </div> </div> </div> <a id="NM_scroll_top_btn" href="#wrap" class="content_top"><span class="blind">TOP</span></a> <button id="NM_darkmode_btn" type="button" role="button" class="btn_theme" aria-pressed="false"  > <span class="blind">라이트 모드로 보기</span> </button> </div> <div id="footer" role="contentinfo"> <div class="footer_inner"> <div id="NM-FOOTER-AD" class="banner_area"> <div class="da_box_wrap"> <div id="da_public_left"> </div> <div id="da_public_right"> </div> <div id="veta_time2"> </div> </div> </div> <div class="notice_area" data-clk-prefix="ntc"> <div class="notice_box"> <h3 class="title"><a href="https://www.naver.com/NOTICE">공지사항</a> </h3> <!-- EMPTY --> </div> <a href="more.html" class="link_all" data-clk="svcmap">서비스 전체보기</a> </div> <div class="aside_area"> <div class="partner_box_wrap"> <div class="partner_box" data-clk-prefix="crt"> <h3 class="title">Creators</h3> <a href="https://www.navercorp.com/service/creators" class="link_partner" data-clk="creator">크리에이터</a> <a href="https://www.navercorp.com/service/business" class="link_partner" data-clk="smbusiness">스몰비즈니스</a> </div> <div class="partner_box" data-clk-prefix="crt"> <h3 class="title">Partners</h3> <a href="https://campaign.naver.com/smefullcare/online/" class="link_partner" data-clk="sme">SME 풀케어 시스템</a> <a href="https://business.naver.com/service.html" class="link_partner" data-clk="service">비즈니스 · 광고</a> <a href="https://sell.storefarm.naver.com/#/home/about" class="link_partner" data-clk="store">스토어 개설</a> <a href="https://smartplace.naver.com" class="link_partner" data-clk="place">지역업체 등록</a> <a href="https://expert.naver.com/expert/introduction?tab=guide#join" class="link_partner" data-clk="expert">엑스퍼트 등록</a> </div> <div class="partner_box" data-clk-prefix="crt"> <h3 class="title">Developers</h3> <a href="https://developers.naver.com" class="link_partner" data-clk="center">네이버 개발자 센터</a> <a href="https://developers.naver.com/docs/common/openapiguide/#/apilist.md" class="link_partner" data-clk="openapi">오픈 API</a> <a href="https://naver.github.io" class="link_partner" data-clk="opensource">오픈소스</a> <a href="https://d2.naver.com" class="link_partner" data-clk="d2">네이버 D2</a> <a href="http://d2startup.com" class="link_partner" data-clk="naverD2SF">네이버 D2SF</a> <a href="https://www.naverlabs.com" class="link_partner" data-clk="labs">네이버 랩스</a> </div> </div> <div class="service_box_wrap"> <div class="service_box" data-clk-prefix="wbd"> <a href="http://whale.naver.com/" class="service_logo" data-clk="bt"> <img src="data:image/png;base64,..." alt="웨일" width="48" height="48"> </a> <div class="service_info"> <strong class="title">웨일 브라우저</strong> <a href="http://whale.naver.com/" class="dsc" data-clk="bt">다운받기</a> </div> </div> <div class="service_box" data-clk-prefix="prj"> <a href="https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EA%BD%83" class="service_logo" data-clk="link"> <img src="data:image/png;base64,..." alt="꽃" width="47" height="50"> </a> <div class="service_info"> <strong class="title">프로젝트 꽃</strong> <a href="https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EA%BD%83" class="dsc" data-clk="link">바로가기</a> </div> </div> </div> </div> <div class="corp_area" data-clk-prefix="plc"> <h3 class="blind">네이버 정책 및 약관</h3> <ul class=" ...

# %%
import urllib.request
res = urllib.request.urlopen("http://unico2013.dothome.co.kr/crawling/tagstyle.html")
print(res)
print("[ header 정보 ]----------")
res_header = res.getheaders()
for s in res_header :
    print(s)
print("[ body 내용 ]-----------")
print(res.read()) # 바이트 문자열, 바이트열 - b'..............'
#print(res.read().decode('utf-8'))
# Out:
# <http.client.HTTPResponse object at 0x7fe14904af40>
# [ header 정보 ]----------
# ('Date', 'Wed, 16 Nov 2022 02:26:38 GMT')
# ('Server', 'Apache/2.2.15 (CentOS)')
# ('Content-Length', '461')
# ('Connection', 'close')
# ('Content-Type', 'text/html')
# [ body 내용 ]-----------
# b'<!DOCTYPE html>\r\n<html>\r\n<head>\r\n<meta charset="UTF-8">\r\n<title>Insert title here</title>\r\n</head>\r\n<body>\r\n<h1>\xeb\xb8\x94\xeb\x9f\xad\xec\x8a\xa4\xed\x83\x80\xec\x9d\xbc \xed\x83\x9c\xea\xb7\xb8</h1>\r\n<div style="background-color:yellow">\xed\x85\x8c\xec\x8a\xa4\xed\x8a\xb8\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa41</div>\r\n<div>\xed\x85\x8c\xec\x8a\xa4\xed\x8a\xb8\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa42</div>\r\n<div>\xed\x85\x8c\xec\x8a\xa4\xed\x8a\xb8\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa43</div>\r\n<hr>\r\n<h1>\xec\x9d\xb8\xeb\x9d\xbc\xec\x9d\xb8\xec\x8a\xa4\xed\x83\x80\xec\x9d\xbc \xed\x83\x9c\xea\xb7\xb8</h1>\r\n<span style="background-color:yellow">\xed\x85\x8c\xec\x8a\xa4\xed\x8a\xb8\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa41</span>\r\n<span>\xed\x85\x8c\xec\x8a\xa4\xed\x8a\xb8\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa42</span>\r\n<span>\xed\x85\x8c\xec\x8a\xa4\xed\x8a\xb8\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa43</span>\r\n</body>\r\n</html>'

# %%
import urllib.request
print("===========================================================")
url = 'https://www.python.org/'
f = urllib.request.urlopen(url)
print(type(f))
print(type(f.info()))
encoding = f.info().get_content_charset()
encoding = 'utf-8' if encoding == None else encoding
print(url, ' 페이지의 인코딩 정보 :', encoding)
text = f.read(500).decode(encoding)
print(text)
print("===========================================================")

url = 'https://www.daum.net/'
f = urllib.request.urlopen(url)
encoding = f.info().get_content_charset() 
encoding = 'utf-8' if encoding == None else encoding
print(url, ' 페이지의 인코딩 정보 :', encoding)
text = f.read(500).decode(encoding)
print(text)
print("===========================================================")

url = 'http://www.yes24.com/Main/default.aspx'
f = urllib.request.urlopen(url)
encoding = f.info().get_content_charset()
encoding = 'utf-8' if encoding == None else encoding
print(url, ' 페이지의 인코딩 정보 :', encoding)

text = f.read(500).decode(encoding)
print(text)
print("===========================================================")
# Out:
# ===========================================================
# <class 'http.client.HTTPResponse'>
# <class 'http.client.HTTPMessage'>
# https://www.python.org/  페이지의 인코딩 정보 : utf-8
# <!doctype html>
# <!--[if lt IE 7]>   <html class="no-js ie6 lt-ie7 lt-ie8 lt-ie9">   <![endif]-->
# <!--[if IE 7]>      <html class="no-js ie7 lt-ie8 lt-ie9">          <![endif]-->
# <!--[if IE 8]>      <html class="no-js ie8 lt-ie9">                 <![endif]-->
# <!--[if gt IE 8]><!--><html class="no-js" lang="en" dir="ltr">  <!--<![endif]-->
#
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#     <link rel="prefetch" href="//ajax.googleapis.com/ajax/libs/jqu
# ===========================================================
# https://www.daum.net/  페이지의 인코딩 정보 : utf-8
# <!DOCTYPE html><html lang="ko"> <head> <meta charset="utf-8" /> <title>Daum</title> <meta http-equiv="x-ua-compatible" content="IE=edge" /> <meta property="og:url" content="//www.daum.net/" /> <meta property="og:type" content="website" /> <meta property="og:title" content="Daum" /> <meta http-equiv="Pragma" content="no-cache" /> <meta http-equiv="Expires" content="-1" /> <meta name="referrer" content="origin" /> <meta property="og:image" content="https://i1.daumcdn.net/svc/image/U03/common_icon/
# ===========================================================
# http://www.yes24.com/Main/default.aspx  페이지의 인코딩 정보 : ks_c_5601-1987
#
# 	<!DOCTYPE html>
# 	<html lang="ko">
#
# <head>
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# 	<meta http-equiv="Content-Type" content="text/html;charset=euc-kr" />
# 	<meta http-equiv="Accept-CH" content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" />
# 	<meta http-equiv="Accept-CH-Lifetime" content="86400" />
# 	<meta name="referrer" content="unsafe-url" />
# 	<meta name="viewport" content="width=1170" />
#
# 	<title>Y
# ===========================================================

# %% [markdown]
# ### urllib.parse.urlencode() 함수로 Query 문자열(요청 파라미터) 인코딩하기

# %%
import urllib
print("[ Query문자열 또는 요청 파라미터 인코딩 ]")
params1 = urllib.parse.urlencode({'number': 12524, 'type': 'issue', 'action': 'show'})
print(params1)
params2 = urllib.parse.urlencode({'addr': '서울시 강남구 역삼동'})
print(params2)
# Out:
# [ Query문자열 또는 요청 파라미터 인코딩 ]
# number=12524&type=issue&action=show
# addr=%EC%84%9C%EC%9A%B8%EC%8B%9C+%EA%B0%95%EB%82%A8%EA%B5%AC+%EC%97%AD%EC%82%BC%EB%8F%99

# %%
import urllib
print(urllib.parse.quote_plus('가나다 ABC123'))
query_str1 = "q="+urllib.parse.quote_plus('가나 다')
query_str2 = urllib.parse.urlencode({"q" : "가나 다"})
print("-------------------------------------------")
print(query_str1)
print(query_str2)
# Out:
# %EA%B0%80%EB%82%98%EB%8B%A4+ABC123
# -------------------------------------------
# q=%EA%B0%80%EB%82%98+%EB%8B%A4
# q=%EA%B0%80%EB%82%98+%EB%8B%A4

# %% [markdown]
# ### Query 문자열 전달하면서 GET 방식으로 요청하기

# %%
import urllib.request
import urllib.parse
params = urllib.parse.urlencode({'name': '유니코', 'age': 10})
print("URL 인코딩 규칙이 적용된 문자열 : %s" % params)
url = "http://unico2013.dothome.co.kr/crawling/get.php?%s" % params
print("URL 문자열 : %s" % url)
with urllib.request.urlopen(url) as f:
    print(f.read().decode('utf-8'))
# Out:
# URL 인코딩 규칙이 적용된 문자열 : name=%EC%9C%A0%EB%8B%88%EC%BD%94&age=10
# URL 문자열 : http://unico2013.dothome.co.kr/crawling/get.php?name=%EC%9C%A0%EB%8B%88%EC%BD%94&age=10
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름은 유니코이고 나이는 10이네요!!</h1>   </body>
# </html>

# %% [markdown]
# ### 요청 파라미터 전달하면서 POST 방식으로 요청하기(1)

# %%
import urllib.request
import urllib.parse
data = urllib.parse.urlencode({'name': '유니코', 'age': 10})
print("URL 인코딩 규칙이 적용된 문자열 : %s" % data)
postdata = data.encode('ascii')
print("변환된 바이트 문자열 : %s" % postdata)
url = "http://unico2013.dothome.co.kr/crawling/post.php"
with urllib.request.urlopen(url, postdata) as f:
    print(f.read().decode('utf-8'))
# Out:
# URL 인코딩 규칙이 적용된 문자열 : name=%EC%9C%A0%EB%8B%88%EC%BD%94&age=10
# 변환된 바이트 문자열 : b'name=%EC%9C%A0%EB%8B%88%EC%BD%94&age=10'
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>POST : 이름은 유니코이고 나이는 10이네요!!</h1>   </body>
# </html>

# %% [markdown]
# ### 요청 파라미터 전달하면서 POST 방식으로 요청하기(2)

# %%
import urllib.request
import urllib.parse
data = urllib.parse.urlencode({'name': '유니코', 'age': 10})
postdata = data.encode('ascii')
req = urllib.request.Request(url='http://unico2013.dothome.co.kr/crawling/post.php',
            data=postdata)
print(req)
with urllib.request.urlopen(req) as f:
    print(f.read().decode('utf-8'))
# Out:
# <urllib.request.Request object at 0x7fe168708490>
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>POST : 이름은 유니코이고 나이는 10이네요!!</h1>   </body>
# </html>

# %% [markdown]
# ### <span style='color:red'>requests.request()</span> 함수로 웹페이지 소스 크롤링하기

# %%
import requests

r = requests.request('get', 'http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8'
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
print('----------------------------------------------------------')
r = requests.request('head', 'http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8'
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
print('----------------------------------------------------------')
r = requests.request('post', 'http://unico2013.dothome.co.kr/crawling/post.php', data= {'name':'백도', 'age' : 12})
r.encoding = 'utf-8'
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
# Out:
# <class 'requests.models.Response'>
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title>테스트</title>
# </head>
# <body>
# <h1>웹 크롤링을 테스트 합니다.</h1>
# </body>
# </html>
# ----------------------------------------------------------
# <class 'requests.models.Response'>
# 응답된 콘텐츠가 없어요
# ----------------------------------------------------------
# <class 'requests.models.Response'>
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>POST : 이름은 백도이고 나이는 12이네요!!</h1>   </body>
# </html>

# %%
import requests

r = requests.get('http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8'
print(type(r))
print(r.headers)
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
# Out:
# <class 'requests.models.Response'>
# {'Date': 'Wed, 16 Nov 2022 04:21:00 GMT', 'Server': 'Apache/2.2.15 (CentOS)', 'Content-Length': '164', 'Connection': 'close', 'Content-Type': 'text/html'}
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title>테스트</title>
# </head>
# <body>
# <h1>웹 크롤링을 테스트 합니다.</h1>
# </body>
# </html>

# %%
import requests

dicdata = {'key1': 'value1', 'key2': 'value2'}
urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = requests.get(urlstr, params=dicdata)
print(r.url)
print('------------------------------------')
dicdata = {'key1': 'value1', 'key2': ['value2', 'value3']}
r = requests.request('GET', urlstr, params=dicdata)
print(r.url)
print('------------------------------------')
tupledata = [('key1', 'value1'), ('key1', 'value2')]
r = requests.get(urlstr, params=tupledata)
print(r.url)
# Out:
# http://unico2013.dothome.co.kr/crawling/get.php?key1=value1&key2=value2
# ------------------------------------
# http://unico2013.dothome.co.kr/crawling/get.php?key1=value1&key2=value2&key2=value3
# ------------------------------------
# http://unico2013.dothome.co.kr/crawling/get.php?key1=value1&key1=value2

# %%
import requests

urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = requests.get(urlstr)
print(r.text)
print('------------------------------------')
r.encoding = 'utf-8'
print(r.text)
print('------------------------------------')
print(r.content)
print('------------------------------------')
print(r.content.decode('utf-8'))
# Out:
# ï»¿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : ì´ë¦ê³¼ ëì´ë¥¼ ì ë¬í´ ì£¼ì¸ì!!</h1>   </body>
# </html>
# ------------------------------------
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름과 나이를 전달해 주세요!!</h1>   </body>
# </html>
# ------------------------------------
# b'\xef\xbb\xbf<!DOCTYPE html>\r\n<html>\r\n  <head>\r\n    <meta charset="utf-8">\r\n    <title>POST TEST</title>\r\n  </head>\r\n  <body>\r\n   <h1>GET : \xec\x9d\xb4\xeb\xa6\x84\xea\xb3\xbc \xeb\x82\x98\xec\x9d\xb4\xeb\xa5\xbc \xec\xa0\x84\xeb\x8b\xac\xed\x95\xb4 \xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94!!</h1>   </body>\r\n</html>'
# ------------------------------------
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름과 나이를 전달해 주세요!!</h1>   </body>
# </html>

# %% [markdown]
# ### 이미지 크롤링하여 파일로 저장하기

# %%
import requests
from PIL import Image
from io import BytesIO

r = requests.get('http://unico2013.dothome.co.kr/image/flower.jpg')
i = Image.open(BytesIO(r.content))
print(type(i))
i.save("/Users/juheekim/Desktop/coding/mycodesource/Multicampus/Python_Anaconda/test.jpg")
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %% [markdown]
# ### 크롤링한 웹페이지 내용을 BeautifulSoup으로 스크래핑하기

# %%
html_doc = """
<!DOCTYPE html>
<html>
    <head>
        <meta charset="utf-8">
        <title>Test BeautifulSoup</title>
    </head>
    <body>
        <h1>테스트</h1>
    </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(bs.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Test BeautifulSoup
#   </title>
#  </head>
#  <body>
#   <p align="center">
#    P태그의 컨텐트
#   </p>
#   <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300"/>
#  </body>
# </html>

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
          <ul>
               <li>테스트1<strong>강조</strong></li>
               <li>테스트2</li>
               <li>테스트3</li>
          </ul>
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs.title), ':', bs.title)
print(type(bs.title.name), ':', bs.title.name)
print(type(bs.title.string), ':', bs.title.string)
print('-------------------------')
print(type(bs.p['align']), ':', bs.p['align'])
print(type(bs.img['src']), ':', bs.img['src'])
print(type(bs.img.attrs), ':', bs.img.attrs)
# Out:
# <class 'bs4.element.Tag'> : <title>Test BeautifulSoup</title>
# <class 'str'> : title
# <class 'bs4.element.NavigableString'> : Test BeautifulSoup
# -------------------------
# <class 'str'> : center
# <class 'str'> : http://unico2013.dothome.co.kr/image/flower.jpg
# <class 'dict'> : {'src': 'http://unico2013.dothome.co.kr/image/flower.jpg', 'width': '300'}

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
          <ul>
               <li>테스트1<strong>강조</strong></li>
               <li>테스트2</li>
               <li>테스트3</li>
          </ul>
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print("[[[ string 속성 ]]]")
print(type(bs.p.string), ':', bs.p.string)
print(type(bs.ul.string), ':', bs.ul.string)
print(type(bs.ul.li.string), ':', bs.ul.li.string)
print(type(bs.ul.li.strong.string), ':', bs.ul.li.strong.string)
print("[[[ text 속성 ]]]")
print(type(bs.p.text), ':', bs.p.text)
print(type(bs.ul.text), ':', bs.ul.text)
print(type(bs.ul.li.text), ':', bs.ul.li.text)
print(type(bs.ul.li.strong.text), ':', bs.ul.li.strong.text)
print("[[[ contents 속성 ]]]")
print(type(bs.p.contents), ':', bs.p.contents)
print(type(bs.ul.contents), ':', bs.ul.contents)
print(type(bs.ul.li.contents), ':', bs.ul.li.contents)
print(type(bs.ul.li.strong.contents), ':', bs.ul.li.strong.contents)
print("[[[ find_all()의 text=True 매개변수 ]]]")
print(bs.find_all("li", text=True))  # 콘텐츠가 텍스트로만 구성된
# Out:
# [[[ string 속성 ]]]
# <class 'bs4.element.NavigableString'> : P태그의 컨텐트
# <class 'NoneType'> : None
# <class 'NoneType'> : None
# <class 'bs4.element.NavigableString'> : 강조
# [[[ text 속성 ]]]
# <class 'str'> : P태그의 컨텐트
# <class 'str'> :
# 테스트1강조
# 테스트2
# 테스트3
#
# <class 'str'> : 테스트1강조
# <class 'str'> : 강조
# [[[ contents 속성 ]]]
# <class 'list'> : ['P태그의 컨텐트']
# <class 'list'> : ['\n', <li>테스트1<strong>강조</strong></li>, '\n', <li>테스트2</li>, '\n', <li>테스트3</li>, '\n']
# <class 'list'> : ['테스트1', <strong>강조</strong>]
# <class 'list'> : ['강조']
# [[[ find_all()의 text=True 매개변수 ]]]
# [<li>테스트2</li>, <li>테스트3</li>]

# %%
html_doc="""
<!DOCTYPE html>
<html>
  <head>
     <meta charset='utf-8'>
     <title>Test BeautifulSoup</title>
  </head>
  <body>
     <p align="center"> text contents </p>
     <p align="right">  text contents 2 </p>
     <p align="left">   text contents 3 </p>
     <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500">
     <div>
       <p>text contents 4</p> 
     </div>
  </body>
</html> """

from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs.find('p')))
print(type(bs.find_all('p')))
print("---------------------------------")
print(bs.find('title'))
print(bs.find('p'))
print(bs.find('img'))
print("---------------------------------")
ptags = bs.find_all('p')
print(ptags)
print("----------------")
for tag in ptags :
    print(tag)
# Out:
# <class 'bs4.element.Tag'>
# <class 'bs4.element.ResultSet'>
# ---------------------------------
# <title>Test BeautifulSoup</title>
# <p align="center"> text contents </p>
# <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500"/>
# ---------------------------------
# [<p align="center"> text contents </p>, <p align="right">  text contents 2 </p>, <p align="left">   text contents 3 </p>, <p>text contents 4</p>]
# ----------------
# <p align="center"> text contents </p>
# <p align="right">  text contents 2 </p>
# <p align="left">   text contents 3 </p>
# <p>text contents 4</p>

# %%
html="""
<!DOCTYPE html>
<html>
  <head>
     <meta charset='utf-8'>
     <title>Test BeautifulSoup</title>
  </head>
  <body>
     <p align="center"> text contents </p>
     <p align="right" class="myp">  text contents 2 </p>
     <p align="left" a="b">   text contents 3 </p>
     <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500">
  </body>
</html> """

from bs4 import BeautifulSoup
bs = BeautifulSoup(html, 'html.parser')
print(bs.find('p', align="center"))
print(bs.find('p', class_="myp"))
print(bs.find('p', align="left"))
print("-------------------------------------")
print(bs.find('p', attrs={"align":"center"}))
print(bs.find('p', attrs={"align":"right", "class":"myp"}))
print(bs.find('p', attrs={"align":"left"}))

pdom = bs.find('p', align="left")
print("["+pdom.text+"]")
print("["+pdom.get_text(strip=True)+"]")
print("["+pdom.string.strip()+"]")
# Out:
# <p align="center"> text contents </p>
# <p align="right" class="myp">  text contents 2 </p>
# <p a="b" align="left">   text contents 3 </p>
# -------------------------------------
# <p align="center"> text contents </p>
# <p align="right" class="myp">  text contents 2 </p>
# <p a="b" align="left">   text contents 3 </p>
# [   text contents 3 ]
# [text contents 3]
# [text contents 3]

# %%
import requests
from bs4 import BeautifulSoup

req = requests.get('http://unico2013.dothome.co.kr/crawling/exercise_css.html')
html = req.content
print(type(html))
html = html.decode('utf-8')
print(html)
print("==============================")
bs = BeautifulSoup(html, 'html.parser')
title = bs.select('h1')
title1 = bs.select('#f_subtitle')
title2 = bs.select('.subtitle')
title3 = bs.select('aside > h2')
img = bs.select('[src]')
print(title)
print(type(title))
print(type(title[0]))
print("<h1>태그의 갯수 : %d " %len(title))
print("f_subtitle이라는 id 속성을 갖는 태그 갯수 : %d " %len(title1))
print("subtitle이라는 class 속성을 갖는 태그 갯수 : %d " %len(title2))
print("aside 태그의 <h2> 자식 태그 갯수 : %d " %len(title3))
print("src 속성을 갖는 태그 갯수 : %d " %len(img))

for content in title:
    print(content.string)
print("------------------------------")
for content in title1:
    print(content.text)
print("------------------------------")
for content in title2:
    print(content.text)
print("------------------------------")
for content in title3:
    print(content.text)
print("------------------------------")
for content in img:
   print(content["src"])
# Out:
# <class 'bytes'>
# ﻿<!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title>Insert title here</title>
# <style>
#   h1 {
#     background-image : linear-gradient(45deg, yellow, green);
#     height : 80px;
#     text-align : center;
#     font-size : 2em;
#     padding-top : 40px;
#     width : 50%;
#     margin : 0;
#     text-shadow : 5px 5px 5px white;
#   }
#   .subtitle {
#     color : #b30059;
#     background-color : pink;
#     text-align : center;
#   }
#   #f_subtitle {
#     color : #006600;
#     background-color : yellow;
#     text-align : center;
#   }
#   section, aside {
#     width : 50%;
#     border : 2px solid #8000ff;
#     border-radius : 20px;
#     margin-top : 10px;
#   }
#   nav {
#     margin-top : 10px;
#     text-align : center;
#     width : 50%;
#   }
#   a {
#     text-decoration : none;
#     font-weight : bold;
#   }
#   aside>ul {
#      color : #006622;
#      font-weight : bold;
#   }
#   div {
#      background-color :  #003399;
#      text-align : center;
#      color : white;
#      font-weight : bold;
#   }
# </style>
# </head>
# <body>
# <header>
# <h1>CSS 선택자 학습</h1>
# <nav>
# <a href="https://www.w3schools.com/">HTML, CSS, JavaScript 학습 사이트</a>
# <a href="https://www.python.org/">파이썬 학습 사이트</a>
# </nav>
# </header>
# <section>
# <h2 id="f_subtitle">교육과정 소개</h2>
# <div>
# 우리는 파이썬으로 데이터 수집과 전처리 그리고 분석을 학습합니다.
# <img src="https://www.python.org/static/img/python-logo.png">
# </div>
# <br>
# <article>
# <h2 class="subtitle">웹 클라이언트 기술</h2>
# <ul>
# <li id="btype">HTML5</li>
# <li class="atype">CSS3</li>
# <li>JavaScript</li>
# <li class="atype">Ajax</li>
# </ul>
# </article>
# </section>
# <aside>
# <h2 class="subtitle">학습 순서(수집)</h2>
# <ul>
# <li>웹 크롤링</li>
# <li>공공 DB</li>
# <li>SNS</li>
# </ul>
# </aside>
# </body>
# </html>
# ==============================
# [<h1>CSS 선택자 학습</h1>]
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.Tag'>
# <h1>태그의 갯수 : 1
# f_subtitle이라는 id 속성을 갖는 태그 갯수 : 1
# subtitle이라는 class 속성을 갖는 태그 갯수 : 2
# aside 태그의 <h2> 자식 태그 갯수 : 1
# src 속성을 갖는 태그 갯수 : 1
# CSS 선택자 학습
# ------------------------------
# 교육과정 소개
# ------------------------------
# 웹 클라이언트 기술
# 학습 순서(수집)
# ------------------------------
# 학습 순서(수집)
# ------------------------------
# https://www.python.org/static/img/python-logo.png

# %%
import requests
from bs4 import BeautifulSoup
import re
req = requests.get('http://movie.naver.com/movie/point/af/list.nhn?page=1')
html = req.text
soup = BeautifulSoup(html, 'html.parser')
titles = soup.select('.movie')
points = soup.select('td.title > div > em')
reviews = soup.select('td.title')
movie_title = []
movie_point = []
movie_review = [] 

for dom in titles:
    movie_title.append(dom.text)
for dom in points:
    movie_point.append(dom.text)
for dom in reviews:
    content = dom.contents[6] 
    content=re.sub("[\n\t]", '', content)    
    movie_review.append(content)
commentLength = len(movie_title)   
for i in range(commentLength):
    print("영화 제목 : " + movie_title[i])
    print("평점 : " + movie_point[i])
    print("리뷰글 : " + movie_review[i])
    print("-----------------------------------------")
# Out:
# 영화 제목 : 디지몬 어드벤처 라스트 에볼루션 : 인연
# 평점 : 10
# 리뷰글 : 진짜 눈물 주루륵 흘렸다..
# -----------------------------------------
# 영화 제목 : 동감
# 평점 : 10
# 리뷰글 : 간만에 푸릇푸릇한 첫사랑영화 극장에서보니까 좋았어요! 그리고 너무 이쁘고 잘생기고 음악은 좋고 영화에서 다하고.. 난리입니다..
# -----------------------------------------
# 영화 제목 : 데시벨
# 평점 : 1
# 리뷰글 : 감독이 도대체 뭘 만들고 싶었던건지 도무지 이해가 안가네
# -----------------------------------------
# 영화 제목 : 폴: 600미터
# 평점 : 7
# 리뷰글 : 이건 모두 댄이 잘못했다ㅋㅋㅋㅋ, 구조되는 장면이 너무 생략된 것 같아 아쉬웠음, 헌터 남은 신발 벗으라고 했을 때 신발 속에 먹을 거 숨겨두었나 의심했음ㅋㅋㅋ
# -----------------------------------------
# 영화 제목 : 블랙 팬서: 와칸다 포에버
# 평점 : 2
# 리뷰글 : 하품을 몇 번 한 것인지... 노잼임은 인정해야 한다~ 영화 왤케 못 만드는지! 그리고 배우들은 매력이 왜 그리도 없는지... 실망작
# -----------------------------------------
# 영화 제목 : 동감
# 평점 : 8
# 리뷰글 : 소소하게 재밌어요. 잘봤어요. 1999년에 동감 원작 대학생일때 봤는데그때의 감동은 없네요 ^^;;
# -----------------------------------------
# 영화 제목 : 자산어보
# 평점 : 4
# 리뷰글 : 흑백화면은 제작비 줄일려고 꼼수 쓴 건데.. 18세기 조선에 어설프게 들이대는 21세기적 정치비판.
# -----------------------------------------
# 영화 제목 : 늑대사냥
# 평점 : 6
# 리뷰글 : 필요이상으로 잔인함.스토리 구성이 치밀하지 않음그냥 다 죽음
# -----------------------------------------
# 영화 제목 : 리멤버
# 평점 : 8
# 리뷰글 : 재밌게 잘 봤습니다~~
# -----------------------------------------
# 영화 제목 : 블랙 팬서: 와칸다 포에버
# 평점 : 10
# 리뷰글 : 와칸다 포에버
# -----------------------------------------

# %%
import requests
from bs4 import BeautifulSoup
import re
for n in range(1,31):
    req = requests.get('http://movie.naver.com/movie/point/af/list.nhn?page='+str(n))
    html = req.text
    soup = BeautifulSoup(html, 'html.parser')
    titles = soup.select('.movie' )
    points = soup.select('td.title > div > em')
    reviews = soup.select('td.title')
    movie_title = []
    movie_point = []
    movie_review = [] 
    for dom in titles:
        movie_title.append(dom.text)
    for dom in points:
        movie_point.append(dom.text)
    for dom in reviews:
        content = dom.contents[6]
        content=re.sub("[\n\t]", '', content)
        movie_review.append(content)

    commentLength = len(movie_title)   
    for i in range(commentLength):
        print(movie_point[i] + ","+movie_title[i]+","+movie_review[i])
    print("-----------------------------------------------------")
# Out:
# 10,디지몬 어드벤처 라스트 에볼루션 : 인연,진짜 눈물 주루륵 흘렸다..
# 10,동감,간만에 푸릇푸릇한 첫사랑영화 극장에서보니까 좋았어요! 그리고 너무 이쁘고 잘생기고 음악은 좋고 영화에서 다하고.. 난리입니다..
# 1,데시벨,감독이 도대체 뭘 만들고 싶었던건지 도무지 이해가 안가네
# 7,폴: 600미터,이건 모두 댄이 잘못했다ㅋㅋㅋㅋ, 구조되는 장면이 너무 생략된 것 같아 아쉬웠음, 헌터 남은 신발 벗으라고 했을 때 신발 속에 먹을 거 숨겨두었나 의심했음ㅋㅋㅋ
# 2,블랙 팬서: 와칸다 포에버,하품을 몇 번 한 것인지... 노잼임은 인정해야 한다~ 영화 왤케 못 만드는지! 그리고 배우들은 매력이 왜 그리도 없는지... 실망작
# 8,동감,소소하게 재밌어요. 잘봤어요. 1999년에 동감 원작 대학생일때 봤는데그때의 감동은 없네요 ^^;;
# 4,자산어보,흑백화면은 제작비 줄일려고 꼼수 쓴 건데.. 18세기 조선에 어설프게 들이대는 21세기적 정치비판.
# 6,늑대사냥,필요이상으로 잔인함.스토리 구성이 치밀하지 않음그냥 다 죽음
# 8,리멤버,재밌게 잘 봤습니다~~
# 10,블랙 팬서: 와칸다 포에버,와칸다 포에버
# -----------------------------------------------------
# 10,데시벨,시원한 액션에 찐한 감동! 거기에 관객에게 계속 질문하는 고급짐까지! 감독, 배우들의 정성이 한땀한땀 느껴지는 영화.사운드테러액션ㅡ당연히 사운드 빵빵한 극장에서 보시길 추천!
# 7,블랙 팬서: 와칸다 포에버,나름 볼만 했다. 그장 두번 가서 보라면 못볼정도긴 한데. 후회는 안드는 작품이다. 채드윅 보스만 포에버..
# 10,블랙 팬서: 와칸다 포에버,새 블랙 팬서의 탄생...
# 10,데시벨,재미있네여재미있었어요
# 1,데시벨,
# 10,극장판 짱구는 못말려: 수수께끼! 꽃피는 천하떡잎학교,
# 10,데시벨,역시 김래원. 올해 본 영화 중 최고작. 자칫 이런 영화는 억지감동 신파극으로 가기 쉬운데 과하지않은 슬픔 감동으로 잘 이끌어갔다. 모든 배우들의 연기도 너무 좋았다. 정상훈의 감초 웃음 포인트도 큰 역할을 했다
# 10,데시벨,너무 재밌게 봤어요 스릴 긴장감 웃음 슬픔도 있고 이종석 김래원 연기 너무 잘해서 몰입하면서 봤어요. 둘다 상황과 행동이 이해도 가서 먹먹하고 배우분들 비주얼 미쳤고 마지막 쿠키영상 대박이에요 ㅠㅠ
# 10,동감,잘봤습니당스토리는 무난했지만 소재가 신선했어요
# 10,더 그레이,건장한 남성이 재난을 만나서 역경을 이겨내고 승리하는 그렇고 그런 헐리우드 영화가 아닙니다.마지막 장면에서 슬픔과 환희 전율을 느꼈어요. 손에 꼽는 인생영화입니다. 제목도  더 그레이라니! 재미도 있으면서 충분히 철학적인 영화입니다.
# -----------------------------------------------------
# 10,데시벨,오랜 기근에 반가운 비. 먹먹한 감동이 있는 영화 만났습니다. 한국영화로 새로운 이정표를 세웠다고 평가받을 독특한 위치의 영화. 모두 멋졌지만 배우 김래원씨의 연기와 액션 진정성의 감동. 영화관서 세번 봤는데 또 보고 싶다. OTT로 보면 늦음! 극장에서 보세요. 영화 속 부산 모습도 멋짐!
# 8,버즈 라이트이어,무난하게 볼 영화였어요. 기대보다는 아쉬웠지만 귀엽고 좋았습니다
# 10,디바이드,배우들의연기 감독의연출 스토리텔링 다 좋았다 10점이다... 왜6.9밖에 안되는지 의문...
# 10,클레멘타인,프로젝트는 아직도 진행중 ㅋ
# 1,데시벨,천안함 음모론 퍼트리려는 역겨운 의도가 들어가있는 쓰레기같은 영화.이딴걸 출연한 출연자들도 문제있다.나라지키다 젊은나이에 전사한 우리장병들을 두번 죽이는 OOO들임
# 10,동감,여진구...그의 연기에 빠져들었다..
# 10,외계+인 1부,호불호가 갈리는 영화라 생각없이 봤는데..ㅋ너~무 기대없이 봐서 그런가 재밌네요ㅎ배우님들의 짤막짤막한 코믹연기가 좋아요ㅎㅎ스토리는 뻔~하지만 CG는 배우연기2부가 기대되는건 뭘까요ㅋㅋㅋ
# 10,미시즈 해리스 파리에 가다,영화 정말 좋았어요 힐링용으로 추천해요
# 10,데시벨,지금 영화보고 나왔는데... 시간이 너무 짧게 늦겨졌다  너무 잘 봤요 좋은 영화가 또 나와서 행복해요한국 영화 화이팅♡^^♡ 역시 믿고 보는 김래원 배우외 한국 배우들 스텝들 한국영화 만드는 모든 분 감사해요 ^^
# 10,블랙 팬서: 와칸다 포에버,영화 괜찮았어요 추천합니다
# -----------------------------------------------------
# 10,한산 리덕스,한산 리덕스 한산 리덕스 한한
# 10,데시벨,짱입니다 진짜 ㅋㅋㅋㅋ개잼
# 2,동감,개연성과 스토리가 밋밋
# 7,윤시내가 사라졌다,짝퉁에 대한 진심과 열정...진정한 자아 찾기...나름 진지하게...유쾌하고 코믹하다...
# 10,동감,아~~ 조이현에게 빠진다
# 8,자백,약간 연기가 어색해고 개연성이 부족한듯요..
# 10,데시벨,기대한 이상으로 긴장감넘치고 감동도  줍니다.이종석배우 연기는  완전  최곱니다. 꼭 극장에서 보시기를 강추합니다.
# 10,동감,2000년 동감의 김하늘과 박용우를 너무 사랑했기에 2022년 동감을 볼 용기가 없었지만, 개봉일 기다렸다가 봤습니다. 2022년 동감도 너무 좋네요. 연출, 연기는 물론 OST도 마음을 아프게 하고... 주인공 여진구 연기 너무 좋았는데, 배인혁 배우가 눈에 들어오네요... 2000년 동감에서는 김하늘 친구가 너무 미웠는데, 2022년 여진구 친구는 왜 안 싫지... ㅠㅠ
# 1,데시벨,적당히 졸릴타이밍에 스타렉스 터르린거 진짜 신의한수임 앞자리 여자둘 팝콘쏟는게.제일웃겼음
# 10,데시벨,오오오 굿굿굿 재밌게봤습니다!!
# -----------------------------------------------------
# 8,데시벨,블랙팬서보다 볼만하네 그거면 된거
# 10,데시벨,슬퍼요...그래서 재밌어요
# 8,동감,살짝 부족하지만 진짜 오랜만에 몽글몽글한 영화여진구 연기 진짜 잘함
# 9,데시벨,배우들의 열연이 돋보이는 영화였어요 폭탄테러의 긴박감 속에 웃음코드도 있어서 밸런스가 좋았던 것 같아요 극장에서 보는걸 추천합니다!
# 1,데시벨,두개 다 보고 나왔는데 동감이 훨씬 재밌습니다 동감으로 가세요;;
# 2,블랙 팬서: 와칸다 포에버,추모, 그뿐. 내용은 유튜브 정리 영상으로 충분. 1관람 6졸음
# 6,폴링 포 크리스마스,90년대 영화인 줄 알았는데 나온 지 1주일도 안 됐다는 거 알고 개충격...
# 10,블랙 팬서: 와칸다 포에버,오래만에 영화재미있게 봤네요^^
# 10,데시벨,천안함 걍 개소리임 ㅋㅋ
# 10,데시벨,팝콘무비의 정석. 완벽한 시나리오는 아니지만 완벽한 얼굴로 커버가능함 재미있게 보기에 딱좋음
# -----------------------------------------------------
# 10,데시벨,시간가는줄 몰랐다 ㄹㅇ
# 10,데시벨,
# 10,동감,풋풋한 러브스토리 너무 좋다.. 간만에 연애세포 충전됨..
# 8,블랙 팬서: 와칸다 포에버,생각보다 괜찮음1편보다 좋았음
# 10,데시벨,차은우의 연기가 얼굴만큼 돋보이고 위화감이 없었다 김래원과 이종석의 연기합도 볼만
# 10,우리들의 일기,넷플 뒤지다가 그냥 함 봐보자 하고 봤는데 기대도 안했는데 너무 좋았음밑에 혹평들은 학생 패싸움으로만 집중해서 보니까 좋게 안 보이는거고 나랑 엄마는 수호랑 현수의 우정과 수호의 희생에 감동 받고 봤음수호 가수활동만 알았는데 연기 잘하네
# 8,자백,원작이 워낙 뛰어나 중간이상은 한다. 강추~
# 10,데시벨,
# 10,데시벨,배우들연기 비주얼만으로도  볼만합니다 이종석 연기가 인상적
# 1,에브리씽 에브리웨어 올 앳 원스,진짜 뭔 OO같은 영화냐.. 처음으로 욕나오는 영화보다가 나왔네 이해도 안되고 정신 나갈것같음 일반인은 이해하기 어려운듯재밌는거 보고싶으면 다른거보세요
# -----------------------------------------------------
# 7,데시벨,좀 생각보다는 많이 아쉽네여. 일단 주제가 무겁고 다큐같은 느낌도 들어여.. 테러범이라는 배우들 모아놓고 돈도 좀 쓴거 같은데... 생각보다 효율이 많이 떨어집니다. 액션도 그렇구여. 갬래원 혼자 하드캐리한 느낌.. 이런걸 보면 공조가 잘 만든영화라는 생각도 드네여.
# 10,동감,개꿀잼 2022년 최고의 영화아니? 21세기 최고영화
# 2,동감,다 유명한 배우들이 나와서 기대 많이 했는데 너무 기대한듯.. 내가 지금 뭘 보고온지 모르겠음.. 로맨스는 맞는거같은데 중요한 내용이 없음 그래서 어쩌다 둘이 만났는데 ???? 여진구가 갑자기 잠수타서 ????
# 8,킹덤2: 아득한 대지로,1편보다 대사의 오글거림이 덜하고 스케일이 커져 더 쟁있다.
# 10,데시벨,손에 땀을 쥐고 봤네요. 긴장감 대박!! 모든 것이 좋았던 영화~꼭 극장에서 보시길
# 10,데시벨,
# 2,블랙 팬서: 와칸다 포에버,슈리 별로…. 억지로 다봄
# 4,동감,여진구 안티계정을 만들 뻔 했어요
# 10,데시벨,연기 좋다...이종석♡
# 10,데시벨,배우들 연기가 최고였습니다특히 김래원 이종석 연기가 기대이상으로 좋았어요완성도는 조금 아쉽지만 배우들 연기때문에 n차 관람예정입니다
# -----------------------------------------------------
# 10,블랙 팬서: 와칸다 포에버,마블의 다른 영화..눈에 먼지가ㅜ.ㅜ
# 10,킹덤2: 아득한 대지로,처음부터 끝까지 액션 미쳐따 ㅠㅜ 가슴이 웅장해진다
# 10,동감,동감 재밌는거 동감? 노래도 너무 좋고 연기도 최고였음 또 볼까 고민하는 중
# 10,에브리씽 에브리웨어 올 앳 원스,모든 불행이 내 삶이라 하더라도. 함께
# 10,데시벨,배우들의 연기가 최고였다. 여운이 남은 영화몰입감최고 감성자극  오열 ㅠㅠ
# 10,데시벨,김래원 연기잘함 찡따오 중간중간 감칠맛줌 이정석 멋지고 연기 잘함 심장아픔 다들 보셔요
# 10,데시벨,올해 본영화중 최고 울고 웃고 정신없이 시간이 지나갔다 .. 김래원 역시 믿고본다 범죄도시보다 3배 재밌고 감동있다
# 10,첫번째 아이,
# 10,위플래쉬,숨좀 쉬자... 마지막에 죽을뻔...
# 10,폴: 600미터,아침 조조로 지금 보고왔어요의외로 많이들 안와서 저포함 다른 한 명 둘다 남자입니다두명이서 보다가 다른 분이 중간에 나가시더라고요그리고 안돌아왔습니다
# -----------------------------------------------------
# 8,동감,20 여년전 동감에 결말을 별수있어  좋았습니다
# 10,데시벨,운이 좋게 시사회에 가게 되어서 기분 좋게 보았고 마지막엔 울면서 영화관을 나왔습니다일단 영화에 나오는 배우들의 연기력이 너무 좋았습니다 영화의 긴장감이 몰입하게 좋을 정도로 있어서  상영내내 집중하여 보게 되었습니다. 내가 저 상황이라면 어떤 결정을 내렸을까 라는 감정이입도 하게 되었고 차은우님의 눈물연기도 인상깊었습니다 같이 울었네요 최근에 본 영화 중 인상 깊은 영화가 되었습니다 부모님과도 함께 보러 가려고 합니다
# 10,펭귄 하이웨이,어른이지만 재미있게 보았음
# 10,데시벨,김래원 이종석 연기대결 볼만함 영화 잼남 후반에 찡한거있음
# 10,동감,아날로그 감성이 묻어나는 잔잔한 영화 재미있게 봤습니다
# 8,인생은 아름다워,스토리와 영상미는 좋았습니다.하지만, 뮤지컬 영화에서 필수인 노래의 매력이 아쉽습니다. 맘마미아나 보헤미안랩소디, 레미제라블 처럼 한곡한곡 주옥같은 노래를 원하는 건 아니지만 적어도 몇곡정도는 여운이 남아 영화가 끝난 후에도 흥얼거리게 되는 곡이 있어야 하는데... 없습니다.그냥 아는 노래들을 오랜만에 들어 반가운 정도?뭔가 막힌듯한 음향과 배우의 가창력에 아쉬움이 남는 영화였습니다. 다음번엔 좀 더 발전된 영화를 기대해 봅니다.염정아님의 노래는 그나마 들을만 했습니다.
# 10,인생은 아름다워,처음으로 글을 남겨봅니다. 남편의 시선으로 구성된 마지막 부분은... 그 전의 남편의 춤과 극 적 전개의 그 모든 어색함을.. 모두 덮고도 남습니다.
# 1,늑대사냥,차라리 좀비물이지 그랬어 ....
# 10,위크엔드 어웨이,비행기에서 봤는데 진짜 재밌어서 시간가는줄 몰랐네요 레이튼 미스터 가십걸 이후로 오랜만에 봐서 반갑
# 1,데시벨,
# -----------------------------------------------------
# 2,블랙 팬서: 와칸다 포에버,그냥 pc범벅영화 아이언하트 나올때 순간 중국영화인줄 알았음 이제마블은 스파이더맨말고 거른다
# 10,블랙 아담,평점이 왜이래?  스토리 다 필요없고 화끈한 오락영화로 손색이 없다 DC 영화들 중에선 그래도 수준급
# 10,데시벨,많은 감정을 느끼게 되는 영화보면 후회는 안할듯
# 2,데시벨,와 진짜 최고급 식재료를 다 모아놓고 음식물쓰레기를 만들어놨네 ㅋㅋㅋ 배우들 연기력이 아깝다. 각본이랑 스토리 개연성 누가짰냐, 이종석 싸이코패스던지 동생 향한 복수인지도 모르겠고
# 1,데시벨,천안함 음모론자가 펼치는 상상의 나래
# 10,에브리씽 에브리웨어 올 앳 원스,가장 진부한 주제에 대한 가장 진부하지 않은 연출.
# 10,데시벨,연기 대박이고 몰입하느라 시간 가는 줄 몰랐음 그리고 안구정화되는 느낌…
# 1,블랙 팬서: 와칸다 포에버,실망 그자체 그립다 블랙팬서
# 10,에브리씽 에브리웨어 올 앳 원스,
# 10,동감,뭐야 진짜 재밌는데 왜 평점 다 낮게 주는지 진짜 모르겠다,,, 연기가 오글거렸다고 하는데 99년도를 배경으로 하는데 당연히 오글거릴 수 밖에 없잖아요,,,솔직히 여진구가 배인혁 갑자기 패는 장면이 좀 오바스럽다고 생각하긴 했지만 그래도 그 장면 빼고는 딱히 오글거린다는 느낌을 못받았어요. 이게 오글거리면 대체 다들 다른 로맨스영화,드라마는 어케 보시는지 궁금하네요!!!그 공중전화 연출도 좋았고 계단 내려가고 올라가는 연출도 좋았는데 왜 별로라고 하는지 진짜 이해가 안돼서 팝콘이 안넘어가네요!!요즘 세기말감성이 유행인데 트렌디하게 잘 리메이크 한것 같아요 진짜로 남들이 다 별로라 해도 제가 맘에 들면 된거죠 뭐 안보고 후회할 바엔 걍 보는게 훨씬 나을것 같아요 근데 진짜 재밌다니까요!!!
# -----------------------------------------------------
# 9,블랙 팬서: 와칸다 포에버,완벽한 추모. 그래도 와칸다포에버!
# 10,폴: 600미터,꼭 보세요. 두번 보세요
# 8,같은 속옷을 입는 두 여자,우리 사이엔 멀티버스가 필요해
# 10,선과 악의 학교,가장 강력한 악은 선으로 위장한다는데, 악이 눈을 뜨면 각성이라는데, 나는 선택이라 부른다.
# 10,폴: 600미터,땀쟁이들 땀폭발~~~
# 10,데시벨,배우들 연기가 끝짱!!!이종석은 올드보이의 유지태를 보는듯한 느낌.
# 10,데시벨,웃으며 봤는데 울었습니다
# 9,데시벨,지난 주말 영화를 봤는데 긴장감 대박이었습니다. 쫄깃한 스토리와 연기가 일품이었습니다. 추추추천~!!
# 10,레미제라블,안녕하세요 너 무 제미있돠
# 10,동감,찐 우정에서 나오는 바이브! 나도 은성이 같은 친구 있었으면
# -----------------------------------------------------
# 1,데시벨,왜 이런”데 ….시…벨..” !!!!
# 10,데시벨,재미없다는 평이 좀 있길래 긴장되는 마음으로 갔는데 누가 재미없대?  배우들 연기도 그렇고 감동,유쾌,스릴 다 느껴보고 왔습니다 강력추천
# 2,동감,기적이라고 얘기나올때 사커킥 마렵다
# 10,데시벨,재밌어요 이종석 슬픈 연기 먹먹..연기 대박
# 1,머니 몬스터,할리우드로 진출한 억지스토리
# 2,공조2: 인터내셔날,와 진짜 인생최악의 영화로 손꼽힐급으로 핵노잼이다 진짜 이런걸관객 700만이나 들었다니 대한민국 관개들 수준진짜 하...
# 10,블랙 팬서: 와칸다 포에버,존잼 대존잼 레전드존잼
# 10,데시벨,긴장감도 나쁘지 않고 코믹도 살짝 있음너무 재밌음 김래원 연기 무엇보다 배우들이 다 장난 아님 김래원,이종석,차은우,박병은 등등 미쳤음꼭 보셈
# 3,대무가,시작은 박성웅, 정경호 배우 보기 위해 봤다가 마지막은 양현민 배우에게 반해버림
# 10,데시벨,이종석 보러 갔는데 차은우 연기가 대박이네요
# -----------------------------------------------------
# 8,데시벨,방금 조조로 보고 왔는데 한마디로 김래원이 하드캐리하는 영화연기 잘하는 이종석이 나름 사연있는 악역을 맡았으나 그 사연 자체가 큰 울림이 없어 전반적인 스토리 자체의 개연성이 좀 부족함 그나마 연기력으로 커버치고 있지만 밝혀지는 순간이나 밝혀진 후의 서사도 엉성함차은우는 거슬리지 않을 정도의 연기와 비중이었는데 홍보를 위해 너무 언급하고 있고 오히려 이민기의 연기가 담백하고 좋았음정상훈을 코믹요소로 활용하고자 하는 의도가 엿보이지만 생각만큼 활약이 부족해 아쉬웠음박병은은 이렇게 쓰려고 등장시킨 것인지 사건해결의 키로 쓰이는줄 알고 봤다 대실망그래도 별점 4점을 준 것은 김래원의 연기가 훌륭했고 연기구멍이 없어 스토리가 좀 엉성해도 볼만은 했음다만 연기 잘하는 배우들 데려다가 나사 하나 빠진 스토리 안에서 엮으려다보니 허술한 면이 있음
# 1,동감,연기도 오글 스토리 구성도 엉성 7ㅐ억지스러움이게 왜 평점 8점대인지 의문이다조조할인으로 본것도 아깝90년대 갬성 살리지도 못함^^세기말 감성 따라하는 연기가 어색하고 스토리가 엉망이라 개어색~~~~특선영화로도 아깝고 러닝타임도 거의  두시간으로 쓸데없이 길다~~~~ 볼거면 다른거 추천~~~~ 진구야 미안하다 누나가 이거까진 쉴드 못쳐주겟다...
# 1,블랙 팬서: 와칸다 포에버,마블영화중 가장 실망한 영화..
# 10,군함도,
# 10,군함도,
# 10,동감,오랜만에 보는 로맨스 영화, 설렘이 가득한 영화 좋았습니다. OST가 넘 조아요!! 동감! 화이팅입니다. ^^
# 7,데시벨,걍 상업영화로 무난한듯
# 3,동감,이렇게 오글거린다는 생각이 드는 영화는 정말 오랜만이다!
# 10,조작된 도시,
# 10,동감,오랜만에 로맨스영화보니까 재밌네
# -----------------------------------------------------
# 9,데시벨,오랜만에 재미있게 본 한국영화입니다.
# 10,블랙 팬서: 와칸다 포에버,개인적으로 나쁘지 않았습니다. 평점이 낮아서 별로일줄 알았는데 생각보다 나쁘지 않게 봤습니다. 마지막에 슈리가 티찰라를 회상하는 장면은 눈물나더라고요.. 영화 분위기도 확실히 잘 살린거 같습니다. 채드윅 보스만님 삼가 고인의 명복을 빕니다..
# 10,블랙 아담,볼거리 많네 마법사는 진짜 마블이랑 비교 안되게 멋있네 액션도 훨씬 좋네
# 1,동감,썸남썸녀 극장가서 보고 욕하며 하나되고 싶다면 추천하는 영화유치한 대사와 연출,, 감 없는 감독님,, 연기를 못하는 배우들,,,김혜윤이 첫사랑 캐릭터와 잘 어울리는 지도 모르겠고 조이현은 왜 여진구때문에 가슴아파 하는지도 모르겠음,,,,
# 1,사잇소리,여주가 무슨 망상병 걸린 사람 같이 행동해서 숨겨진 반전을 기대하고 봤는데 스토리가 전개될수록 그 망상이 맞아들어감  ㅋㅋ뻔하고 예측가능한 스토리라인이고 스릴러 영화라고 하는데 스릴이 하나도 없음 별 반 개도 아까움
# 10,어톤먼트,너무 잘만들어서 화가난 작품
# 7,리멤버,재밌게 잘 봤습니다.
# 1,동감,형만한 아우 없다 ㅡㅡ 연출 연기배우들이 설레이지가 않음 지루하고 별로였어요 ㅠㅠ
# 8,블랙 아담,마블이 흔들릴 때 블랙아담의 강함 펀치 한방!
# 10,데시벨,유난히도 뜻하지 않은 사고가 많았던 올해. 데OO을 통해 억눌린 울분과 슬픔을 위로 받는 시간이 될 수 있었고, 마지막의 여운이 오래 갈 듯 합니다.
# -----------------------------------------------------
# 1,블랙 팬서: 와칸다 포에버,연출연기스토리또한 모두 엉성그자체보다가 중간에나온 영화는 처음입니다 공주를 구출하고 전쟁준비도안하고 태평하게 대화나하고있고고작 10명한테 지구최강이라는 와칸다가뚫리는데  대체 적군들은  동맹이 왜 필요하고 공격하러가서 함선한대만 들고가서 고작 물고기 쩌리들한테 개털리는모습 잘봤습니다다 봐줘서 초보블랙팬서니 백번양보했다쳐도 대사에 무게감 연출력은 한없이 가볍고 B급영화 그자체의 최악의영화인것같습니다.앞으로 다음편에도 맥아리없는 블랙팬서가나온다면 안볼예정
# 10,데시벨,초중반 쫄깃쫄깃 긴장감 넘치고 마지막에는 감동과 여운이 느껴지는 영화!
# 1,동감,정말 시간이 많으신 사람만 보세요배우들이 다 연기가.. 걍 대사가 너무 유치한듯참고로 장르가 코미디입니닼ㅋㅋ
# 10,데시벨,이건 꼭 극장에서 봐야하네요 스케일 액션 펑펑 터지고 스토리까지..  김래원 이종석 연기 진짜 잘하고 차은우 존잘
# 10,폴: 600미터,반전 너무 좋은데? 재밌게 봄!!
# 9,동감,김용의 설레고 안타까운 첫사랑 이야기를 아날로그 감성이 더해진 과거와 현재를 넘나들며 아름답게 잘 그렸네요. 보는 내내 추억 돋아 흐뭇하게 봤습니다.
# 2,동감,보고 잠듬 그냥 공짜로 풀리면 볼 걸
# 10,동감,하진짜 너무 슬프다. 나 정말 감성 없는 사람인데울었음. 주인공 용이 몬마니? 잃고 힘들게 찾고 있는데 김은성이랑 한솔이가 연인같이 거북이 몬마니를 쓰담고 있는 장면.. 용이 가만히 무슨 생각 하고있을지 너무 이해감 지금 자기가 저 관계를 망치면 무늬는 없을테고 그치만 한솔이랑 그러고 싶고... 무늬한텐 솔직하게 가라면서 용은 솔직하게 않음..ㅜㅠ 용은 솔직해도 못 이뤘는데. 왜 무늬는 이뤄진 걸까 용이 서투르게 행동하고 안좋은 모습을 보여줬긴 했지만 마음은 진짜 였는데....용이 작가라는 소리 듣고 펜싸인 들어갈때 너무 나까지 심장 두근거림..그리고 또 첨에 나인우?가 무늬한테 우산 갔다준게.. 용이 준거라니.. 과거의 용은 왜 안나왔냐며 화났지만 현재의 용은 무늬를 알고 그래줬구나.. 진짜 과거 현재 관한 스토리 너무 좋아하는데..진짜 너무 좋았다. 원하는 스토리는 아니지만 못 잊을듯 영화에 나온 책 사고싶다.
# 10,공조2: 인터내셔날,
# 9,데시벨,예상 밖의 스토리로 긴장감 속에서 재미있게 봤습니다.
# -----------------------------------------------------
# 10,데시벨,이종석 연기 미쳤다  찡했음
# 10,데시벨,생각 없이 보기 좋아요 킬링타임용 액션 영화
# 6,자백,기승전은 괜찮았다. 초반 반전 요소나 배우들 연기력, 인물의 심리묘사 등 초중반 부분에 영화의 집중도가 좋았지만 갑작스런 결말 전개나 권선징악을 보여주려고 후반 어거지로 끼어맞춘게 아쉬웠다 요약하자면 용두사미 같은 작품
# 10,데시벨,
# 10,클레멘타인,아주 감동적인 영화. 죽여주네요
# 10,데시벨,일단 배우 캐스팅만으로도 큰 스크린에서 볼 가치가 충분하다고 생각. 사운드나 액션까지 받쳐주니 무조건 극장에서 보길 잘한 작품!!
# 10,데시벨,감정의 여운이 남는 영화네요. 개연성 부족이 약간 아쉬우나 배우들의 연기와 몰입도에 있어서는 최고입니다. ^^
# 10,데시벨,배우 라인업 좋고 내용 더 좋고 ㅎㅎ 2시간 순삭이요
# 4,데시벨,개연성도 부족하고 기억 남는 장면도 하나 없고 캐릭터들도 전혀 이해가 되질 않는다. 아니 저 상황에서 개그? 실화? 영화의 제목도 왜 데OO인지 의문인 작품. 오랜만에 영화 보고 나서 할 말을 잃어버렸다.
# 2,블랙 팬서: 와칸다 포에버,스토리라인이 너무 개연성이 없고 캐릭터매력도도 넘 떨어지네요. 액션도 허접하고....좀 어설푼 전개가 실소를 유발합니다...  어린 19세 천재과학자가 사이코패스인가요??   사람 죽여놓고 좋아라 하고.. 이건 뭐~~  말도안되는 전개
# -----------------------------------------------------
# 10,데시벨,진짜개슬퍼요질질짰지만인생영화등극
# 1,동감,그냥 명절에 tv로 보는게 딱 맞을 영화 지루하고 오글거리는 굳이 왜 리메이크 했지 ㅡㅡ
# 6,블랙 팬서: 와칸다 포에버,재미는 있는데 너무 김 쓸데없는 장면도 많고..딱 킬링 타임용
# 8,연애의 목적,연애의 목적은 서로를 치유하는 것이라는 것을 아주 사실적이고 스릴있게 설명해주는 것 같다
# 10,데시벨,전체적으로 재미있다 긴장감 스릴 유머 그리고 슬픔까지 배우들이 연기를 너무 잘해서 더 좋았던것 같다 그리고 잠수함 부분이 너무 좋았다 이종석 ㅠㅠ
# 1,블랙 팬서: 와칸다 포에버,개판이구만..근데 웃긴건 요즘 마블영화 디씨 영화 다 이 정도도 못만드는 수준..pc사상이랑 일단 결별 좀 하고 만들자
# 8,외계+인 1부,티빙 통해서 봤는데 혹평이 억울했겠는데! 극장 관람료 생각한다면 관람객들 평점이 조금은 이해가 가기도 하고. SF같은 뜬구름 잡는 이야기 좋아하는 사람들한테는 괜찮은 영화. 초반부가 흡입력도 대사도 연기도 좀 아쉬웠지만 중반부 들어가면서 본격적으로 스토리가 시작되면서 몰입도도 높아지고 배우들 연기도 안정되더라. 특히 고려시대 액션이 볼만했다. 끝나고 나선 2부 언제 개봉하는지 찾아봤음. 나는 2부는 극장가서 볼 것 같음.
# 4,블랙 팬서: 와칸다 포에버,닥스랑 토르보단 나은 거 같긴 한데 아닌 거 같기도 하고...
# 8,같은 속옷을 입는 두 여자,같음으로 시작해 다름으로 끝나는 영화
# 10,폴: 600미터,와나 미친거아님... 손에 계속 땀 나서 핸드크림이 필요가 없다
# -----------------------------------------------------
# 2,늑대사냥,24년인생 가장 노잼영화
# 1,블랙 팬서: 와칸다 포에버,공짜여서봤음시간아까웠다
# 10,데시벨,배우들 라인업이 좋아서 기대하고 봤는데 실망을 져버리지않네요! 몰입감 대박이고 폭탄 터질때마다 깜짝깜짝 놀랏네요ㅋㅋㅋ극장에서 보기 좋은 영화!
# 10,폴: 600미터,이런 영화 넘 오랜만ㅜㅜㅜ 극장에서 티익스프레스 타는 느낌 .. 극장에서 보니까 진짜 ㅈ림
# 10,데시벨,오랜만에 영화 보고 울었습니다.
# 10,인생은 아름다워,아 너무 재밌어서 인생영화 될꺼같음
# 10,에브리씽 에브리웨어 올 앳 원스,MCU가 담으려는 메타버스식 메세지를 양자경 가족이 한편에 담네.. ㅋㅋㅋ
# 10,폴: 600미터,정말 영화 시작해서 끝날 때까지 손에 땀이 나네 ㅋㅋ 반전 두방 있음~!! 많이 쌤
# 8,에브리씽 에브리웨어 올 앳 원스,평범함의 소중함, 그 소중함으로 감사하는 삶을 살게 된다
# 6,데시벨,엄청 울었습니다... 긴장감 넘치고 재밌었어요
# -----------------------------------------------------
# 10,데시벨,너무잘봤어요 연기들이 끝내줍니다..우리나라를 위해 전사하신분들..다시한번 깊은 애도를 표합니다
# 8,블랙 팬서: 와칸다 포에버,액션장면은 별로없어요 하지만 배우들때문에 계속 집중보게되서 볼만했어요
# 6,아이 씨 유,흔한 반전에서 한발더 갔기 때문에 그나마 다행.
# 10,데시벨,스토리도  연기도 전부 굿
# 1,블랙 팬서: 와칸다 포에버,PC주의에 뇌가 절여져 나 이만큼 올바른 사람이야!! 하고 어필하는 정치 선전물.. 마블은 거른다 ㅅㄱ
# 10,동감,오랜만에 로맨스 장르 영화 보러 왔는데 재밌게 몰입해서 봤습니다!
# 5,자백,인비저블게스트 리메이크 영화인줄 모르고 그냥 봤는데 초반부터 기시감이 확 들더니 역시 원작이 있는 영화였네요. 리메이크면 리메이크작만의 매력이 있어야 되는데(아님 배경이 바뀌었으니 최소한 한국 배경의 특징이라도) 근데 분위기도 연출도 다 원작과 똑같기만 해서 좀 실망스러웠습니다. 알고보니까 당연히 반전도 뻔했고요. 소지섭이나 김윤진 연기도 솔직히 쏘쏘고 오히려 나나 연기가 인상깊었네요. 리메이크인지 모르고 본 제탓이지만 알고 봤어도 실망했을거 같네요.
# 2,블랙 팬서: 와칸다 포에버,한 배우가 끌고가는 힘이 얼마나 중요한지 알게됨  후...오랜만에 영화관에서 졸았네요스토리연계하려는거 알겠는데 너무 지루하고 전투씬도 잠깐 나오는데 쩝...  그 잠깐잠깐 전투씬도 딱히 임팩트없고 채드윅보스만  회상씬이 보고싶으신분들만보세요 아니시면 다음에 리뷰같은걸로 스토리 대충듣고 3보는거 추천드립니다
# 4,블랙 팬서: 와칸다 포에버,솔직히 그냥 별로였음ㅠㅠㅠㅠ
# 2,블랙 팬서: 와칸다 포에버,최고로 발달한 과학국가라면서 왜 우가우가 하면서 싸우나요??
# -----------------------------------------------------
# 10,데시벨,긴장의 연속이었습니다. 스릴있었어요!
# 6,블랙 팬서: 와칸다 포에버,믿고보던 마블이 이제는 다 별로인 ㅠ
# 7,블랙 팬서: 와칸다 포에버,
# 9,블랙 팬서: 와칸다 포에버,뛰어난 주인공의 영웅물이 아닌 한 인물의 성장 서사가 담긴 블록버스터
# 10,폴: 600미터,핵재밌고 소름 무서움 추움 보는내내 이입되서추웟다
# 10,데시벨,올해 본 영화중 제일 재밌었어요 김래원 이종석 연기 최고 울면서 나왔어요ㅠㅠ 시간순삭
# 10,데시벨,김래원, 이종석 신선한 조합이었습니다. 눈호강 제대로 했어요 ㅎㅎ
# 10,데시벨,데OO 액션이 진짜 장난 아님ㅎㄷㄷ 영화관에서 보길 진심 잘했다!! 김래원, 이종석 역시 믿고 보는 배우 인정함ㅋㅋ
# 9,데시벨,중반부 까지 정말 몰입 넘치게 잘봤습니다..후반부의전개가 아쉬웠지만 그래도 재밌게봤어요
# 10,데시벨,캐스팅도 대박인데 스토리까지 개쩔어요...진짜 극장에서 안보면 완전 후회할뻔 ㅠㅠ
# -----------------------------------------------------
# 2,동감,연기, 연출, 시나리오 3박자가 엉망. 조조로 보고 왔는데 만원 날렸다. 집에서 봤으면 15분 보고 삭제함
# 10,블랙 팬서: 와칸다 포에버,여성 캐릭터 활용도가 높았고 기술자도 여성들이어서 좋았음. 전반적으로 채드윅을 떠나보낸 여성들의 슬픔과 모계계승의 시나리오가 좋았음. 블랙팬서로서의 슈리도 기대됨. 모든 부분이 완벽했고 앞으로도 마블에서 여성 캐릭터들이 잘 활용됐음 좋겠음.
# 6,폴: 600미터,하 너무 무서웠어요 ㅠㅠ  12세 절대 아님 반전도 있고 영화보는 내내 긴장감을 놓칠 수 없음 , 몇번이나 소름돋았네요 심약주의자는 주의하셔야됩니다근데 영화가 반전도 있고 긴장감 넘치지만 보고나서 찝찝하고 감독이 뭘 얘기하고 싶은건지 사실 남는게 없네요 감동스토리 없음
# 4,블랙 팬서: 와칸다 포에버,갑자기 여동생이 슈퍼히어로??? 어쩔수 없다는건 알지만 무리수 ㅠㅠ
# 8,킹덤2: 아득한 대지로,영화 잘봤습니다 영화 잘봤습니다
# 8,블랙 팬서: 와칸다 포에버,채드윅에 대한 절절한 추모, 다음 블랙팬서의 기대감을 높였으나 러닝타임 3시간은 너무하지않았나.엔딩으로 깔리던 리한나의 ost가 기억에 남는다.여전한 ost 맛집.
# 10,폴: 600미터,위에 어떤 몰상식한 사람이 예전 식스센스 보고 나옴서 반전을 외쳣던 그 사람인가? 영화의 묘미를 한풀 꺽는 이런짓은 하지 말기를 바란다
# 8,한산 리덕스,영화 잘봤습니다 영화 잘봤습니다
# 10,데시벨,액션에 끌려서 관람했는데 감동까지 ㅠㅠ  이 영화 대체 뭐야… 적극 추천!! 그리고 배우님들 열연 진짜 인상적임…. 다시 볼 예정
# 8,동감,영화 잘봤습니다 영화 잘봤습니다
# -----------------------------------------------------
# 8,데시벨,영화 잘봤습니다 영화 잘봤습니다
# 10,데시벨,데OO 대박 너무 재밌어요 ^^ 연기최고 긴장 ,슬픔, 웃음 모두 있는 시간순삭 올해 본 영화중 최고!! 여운이 남는 영화 ㅠㅠ
# 8,고백,다소 과한 슬로우모션 장면들과 bgm들이 오히려 영화의 서늘함 및 잔혹함과 잘 어우러진 느낌. 갠적으로 원작을 오래전에 읽었지만 아이들이 우유 마시는 장면에서부터 내용이 다 떠올라서 슬펐음ㅜ (이런 내용은 영화부터 보는게 나음)
# 9,블라인드 사이드,연출, 연기 걍 다 좋았다
# 10,리멤버,평상시에 남주혁배우를 좋아하고있었고 물론 이성민배우역시 좋아한 상태로 영화를 봤긴하지만 너무 좋았던 이유중 하나는 이 스토리가 지루하지않고 후반부까지 끌고 갈수 있던 것 중에 하나는 바로 배우들의 연기력과 미친 호흡이라고 생각함 !중간중간 웃음포인트와 무거운 주제를 너무나 막 무겁지않게 그렇다고 가볍지 않게 나타내었고,영화의 상징하는 소재들이 ㄴㅏ오는데 예를 들면 총 , 피 , 손에 이름을 새긴다던가 등등에서의 그런 소재들로 인해 더욱 더 몰입감을 주었음 ! 사람들이 많이 봤으면 !!!! 보면 후횐안함 ~~~~
# 10,에브리씽 에브리웨어 올 앳 원스,
# 10,데시벨,배우들 연기에 시간 가는줄 모르고 몰입해서 봄!
# 6,블랙 팬서: 와칸다 포에버,채드윅이 없는 블랙팬서는.. 더이상 블랙팬서가 아니다... 아쉬움만 한가득인 영화 ㅠㅠ
# 10,화차,이 영화를 극장에서 못보다니,,,
# 6,데시벨,에휴~ 스토리가 너무 공감할수 없는 부분이 많다. 테러의 명분도 너무 공감 안가고, 결과도 웃기고, 그나마, 대배우들을 한번에 볼 수 있었다는거말고는...연기력도 그다지.... 감상포인트가 없는데, 어디를 하란말이야
# -----------------------------------------------------
# 10,데시벨,시간순삭 진짜 잼나게 봤음배우들 비주얼과 연기들이 눈을 뗄수없게 만들고 스릴과 감동을 동시에 주는 영화였음
# 5,블랙 팬서: 와칸다 포에버,너무 길어요... 지루하고
# 10,동감,넘 감동적이었어요... 얼굴 합도 미쳤음 ... ㅠㅠㅠㅠ
# 6,블랙 팬서: 와칸다 포에버,솔찍히 재미없다는 댓글 보고 안 믿고 봤는데1. 날개달린 발2. 후레쉬맨 같은 인물 등장3. 안 어울리는 여주인공3가지가 나올 때 속으로 헉 뭐지?라는 생각이 본능적으로 그냥 들었습니다.
# 10,인생은 아름다워,진짜 감동과 재미가..있었어요 ㅠㅠ
# 10,데시벨,재밌어용 개봉전 무대인사로 봤어욜
# 10,데시벨,긴장감 있고  감동도 있는 영화. 시간 가는 줄 모르고 몰입해서 봄.
# 9,같은 속옷을 입는 두 여자,"가장 큰 상처는 가족에게서 받는다"는 말에 동의한다.  긴 상영시간 내내 몰입해서 볼만큼 여배우들의 연기가 좋다. 딸이 엄마를 벗어나 멋진 인생을 살아갈 수 있기를 영화를 보면서 간절히 바라게 되었다.
# 10,데시벨,초반 스릴과 쫄림을 맛보고 후반 연기파티를 보는 영화  몰입도 최고이종석의 미친놈연기는 언제나 최고인것같고 김래원의 고생이 고스란히 느껴지는 영화임  배우들누구하나 아쉬움없이 잘 어울리고 중간중간 숨쉴수있는 캐리과 그저그런 오락영화인줄 알았는데 뭔가 메시지를 더져주는 영화여서 좋았음 중후반에 울컥했다가 엔딩후 쿠키장면에선 오열했음ㅠㅠ  배우들 보는 눈이 즐거운 영화임
# 10,데시벨,소리가 주는 긴장감이 가득한 영화! 보는내내 몰입감 최고!
# -----------------------------------------------------
# 10,20세기 소녀,눈물없이는 볼 수 없는 영화...ㅠ
# 10,멀홀랜드 드라이브,완벽하게 이해하진 못했지만, 상당히 잘 짜인 '악몽같은 사랑이야기'인건 분명하다
# 1,데시벨,518,반일감정 이런거 그려러니 해도 천안함은 건들지 말자 유족 두번죽이는짓을 왜 계속하냐 니들도 사람이면 적당히좀해라 제발
# 10,동감,연인끼리 보기좋은 영화
# 10,블랙 팬서: 와칸다 포에버,영화시간도 긴데지루하지않게 재밌게 봤습니다 :)
# 2,블랙 팬서: 와칸다 포에버,돈이 아까울 정도...
# 10,데시벨,아주 쫄깃합합니다. 이종석 테러범인데 늠 멋짐 ㅠ
# 4,데시벨,별로에옹 너무 뻔함....
# 10,데시벨,영화보면서 눈정화 하기는 처음ㅋㅋㅋ배우들 조합이 아주 그냥 미쳤음
# 9,수프와 이데올로기,뒤늦게 어머니의 삶을 이해하고 눈물 흘리는 감독의 마음이 와 닿았다. 아픈 역사를 외면하지 않고 마주 바라보는 일은 쉽지 않다. 그래도 그런 작업이 필요하다.
# -----------------------------------------------------
# 10,데시벨,사운드로 사로잡은 긴장감
# 10,데시벨,너무 재밌게 봤습니다. 차은우 배우님 연기에 한번 더 놀랐습니다.
# 10,한산: 용의 출현,완벽할수 없지만 개인적으로는 감동적으로 봤습니다! 노량 기대됩니다!
# 6,블랙 팬서: 와칸다 포에버,초중반 어느 시점까지 좋다가 뒤는 전부 굳이 ...
# 9,데시벨,간장감 있고 재밌다. 이건 찐 관람평. 펑펑 울었어요~~
# 10,데시벨,전개는 평타 , 마지막 클라이막스가 좋았음 특히 차은우의 눈물연기가 일품.사실 더 울리고 싶었다...
# 1,20세기 소녀,김유정때문에 봤지만 진부하고 볼품없는 스토리라인과 처참한 수준의 연출 결말이 궁금하지 않아  40분 남기고 종료했고 이런걸 보는데 쓴 한시간이 너무 아깝다
# 10,폴: 600미터,헌터가 결국 가방 못잡고 죽었고 환영으로 보인다는 반전은 정말 생각도 못했다;;;;
# 10,동감,진짜 로멘스영화 코믹스러우면서도 재밌었다.. 연인들이 보기 좋은영화
# 10,킹덤2: 아득한 대지로,와... 전쟁씬이 장난 아니게 멋짐.킹덤 만화책부터 좋아했지만.. 정말 실사화으로 잘만들었던거 같아여~!!! 완전 추천!
# -----------------------------------------------------
# 10,킹덤2: 아득한 대지로,스토리는 약하지만, 스케일이 큰 극장용 영화. 3편은 언제 나오려나..
# 10,한산 리덕스,한산 용의출현에 이어 한산 리덕스 N차 관람할 결심
# 10,시네마 천국,내 인생 최고의 영화... OST만 들어도 눈물이 난다..ㅠㅠ 영화를 좋아하는 사람이라면 누구나 감명 깊게 봤을 영화...
# 8,폴: 600미터,추모팬서보다 600배는 재밌음
# 10,한산 리덕스,배를 돌려라! 격군들을 보강시켜 학익진 대형을 펼쳐라~ ! 전군 발포하라! 모조리 분멸하라~~
# 3,데시벨,너무 기대를 했나.. 올해 비상선언보다 못하는 영화가 등장할줄이야... 배우들이 아까운 영화다... OTT로 봐도 아까울 영화..
# 10,동감,재미있게 봤어요 간단하게 보기 좋네요.
# 10,지상의 별처럼,너무 감동적인 영화였음…..
# 10,지상의 별처럼,너무 감동적인 영화였음…..
# 10,데시벨,손에 땀을 쥐며 시간 가는 줄 모르고 봤습니다. 같이 간 친구는 펑펑 울었어요. 연기도, 연출도, 액션도 아주 좋았습니다. 오랜만에 본 긴장감 넘치는 액션 영화!
# -----------------------------------------------------
# 7,데시벨,현실판 11번째 스트라이커
# 10,다크 나이트,내인생 최고의 영화. 살면서 처음 3번 이상 본 영화.
# 7,자백,배우들의 연기는 좋았지만 어딘가 아쉬움..
# 10,데시벨,액션은 두말할것 없고 스토리와 감정선이 더 좋았음ㅠㅠ 차은우 연기 정말 잘함
# 10,데시벨,보는 내내 긴장감 넘치고 스릴 넘쳤습니다
# 4,데시벨,꼭 이렇게 만들어야만.. 속이 후련했냐!!!!
# 10,동감,풋풋한 감성으로 무장한 영화네요. 오글거림도 옅은미소로 커버가 되는 순수함이 있습니다
# 10,데시벨,끝까지 흥미진진했어요~ 쫄깃한 긴장감에 2시간이 순삭! 배우들의 명연기에 뭉클한 감동까지. 여운이 많이 남는 액션은 간만이네요~
# 10,킹덤2: 아득한 대지로,액션이랑 비주얼 좋음. 진짜 일본에서 이렇게 오글거리지 않은? 퀄좋은 액션 영화가 있었나 싶을정도.. 굿굿
# 6,알카라스의 여름,표면 위 부유로 감각 되어지지 않는 심연
# -----------------------------------------------------
# 10,한산 리덕스,1빠라서 평점10점
# 8,미안해요, 리키,우리가 이 시점에 윗세대에 본받을 것은 기술이 아니라, 이웃에게 한 마디 건넬 수 있는 따뜻한 마음일지도.
# 10,인 어 베러 월드,10여년전 이 영화를 봤을때도, 그리고 이번에 다시 봤을 때도 여전히 용서에 대해 많은 생각을 하게 한, 갠적으로 내게 큰 울림을 줬던 영화.
# 10,에브리씽 에브리웨어 올 앳 원스,마지막 장면의 수 많은 세계의 자신들을 돌아보다가 현실의 국세청으로 돌아와 미소짓는 장면에 소름이 쫙 돋았다. 모성애에 대해 깊게 생각해볼 수 있는 계기가 되었다.
# 10,킹덤2: 아득한 대지로,1빠라서 평점10점
# 10,데시벨,신선한 소재의 테러 액션인데 심지어 배우들 연기가 훌륭하니까 과몰입해서 봤음 ㅠㅠ
# 9,동감,지루하지 않고 감동적이에요
# 2,블랙 팬서: 와칸다 포에버,무한~~~도전!!!!
# 4,데시벨,데OO이 아니라 더OO
# 8,블랙 팬서: 와칸다 포에버,볼만했어요 ㅎㅎ
# -----------------------------------------------------
# 5,용과 주근깨 공주,영상과 노래는 정말 역대급으로 좋은데, 스토리가 다 망쳐버렸네요. 아쉬운 작품. 일본의 기형적인 이지매와 일본 사회의 음침함이 고쳐지지 않는 한 작품 만드는 사람들도 미래는 없을 듯 하네요.
# 3,체리마호: 30살까지 동정이면 마법사가 될 수 있대,그냥 봤는데 뭔가했는데 드라마 뒷이야기라네..드라마내용을 몰라서 그런가 지루함
# 8,2012 글로벌다큐멘터리 공룡의 땅,내용도 볼만하고 재미있네
# 7,블랙 팬서: 와칸다 포에버,진짜 추모 영화 세대 교체가 맞는지는 진짜 의문 임 액션 수치 낮음 그래도 그냥 마블영화라 봄 킬링타임용
# 8,에브리씽 에브리웨어 올 앳 원스,
# 3,블랙 팬서: 와칸다 포에버,히어로영화에 간지가 안나는게 말이되냐....
# 9,북극의 눈물,이런 좋은 다큐는 많은 사람들이 보아야 할듯
# 8,휴먼다큐멘터리 사랑,많은 것을 느끼게 해주네요
# 10,동감,지금 만나러 갑니다 이후 최고의 리메이크 작 인정!
# 10,데시벨,
# -----------------------------------------------------
# 10,데시벨,진돗개와 빅마우스의 대결..재미있습니다.
# 10,블랙 팬서: 와칸다 포에버,채드윅 보스만을 위한, 그를 추모하는 영화에 히어로물을 얹은 느낌이다. 한 방 크게 치고 들어오는 그런 묵직함이 없어 자극적인 것을 원하는 관객에겐 불호일수 있겠으나 채드윅의 빈자리를 어떻게 극복해냈는지, 새로운 블랙팬서가 어떻게 만들어졌는지에 대한 서사는 확실했다고 생각한다.기회만 된다면 재관람하고싶은 영화
# 10,사잇소리,감독의 연출이나 의도가 잘 숨겨져 있어 찾아내는 재미가 쏠쏠했습니다. 보는 내내 시간가는 줄 몰랐어요!
# 10,동감,몽글몽글하고 풋풋하고 귀엽고 무겁지 않은데 재밌어요~ 영화 끝에 츄 가수님 고백 노래도 넘 좋아요 기분좋은 여운있는 영화
# 7,카우보이 비밥,세련된 내용에 결말이 아련...
# 2,모범시민,결말이 너무너무 아쉽네...ㅅㅂ 검사...가족들 몰살 당하구 죽어야 되었는데...
# 8,폴: 600미터,짜릿 그자체!! 이건 꼭 극장에서 봐야합니다
# 10,데시벨,올만에 한국영화 중에 범죄되시 이후로 생각 없이 잼나게 걍 2시간 볼 수 있는 영화인듯 굳
# 10,폴: 600미터,영화보는 내내..긴장감 대박!! 역대급 짜릿~ 큰 스크린에서 꼭 봐야해요!
# 9,사잇소리,기대했던 것보다 훨씬 재밌네요 완전 강추!!
# -----------------------------------------------------

# %%
print(reviews[0].contents)
# Out:
# ['\n', <a class="movie color_b" href="?st=mcode&amp;sword=205027&amp;target=after">데시벨</a>, '\n', <div class="list_netizen_score">
# <span class="st_off"><span class="st_on" style="width:100%">별점 - 총 10점 중</span></span><em>10</em>
# </div>, '\n', <br/>, '진돗개와 빅마우스의 대결..재미있습니다. \n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t', <a class="report" href="#" onclick="report('shit****', 'vC5HZwT67IVlqsWHtPuEfjWTIi0cCF/NjDJdtX2apqc=', '진돗개와 빅마우스의 대결..재미있습니다.', '18541467', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>, '\n']

# %%
import requests
from bs4 import BeautifulSoup
title = []
link = []
urlstr = 'http://www.yes24.com/SearchCorner/Search?domain=BOOK&query=python'
r = requests.get(urlstr)
#r.encoding = "utf-8"
bs = BeautifulSoup(r.text, 'html.parser')
bookList = bs.select('a.gd_name')

for bookDom in bookList:
    title.append(bookDom.string)
    link.append(bookDom["href"])

print("-- 도서 제목 --")
print(title)
print("-- 도서 링크 URL --")
print(link)
with open('/Users/juheekim/Desktop/coding/mycodesource/Multicampus/Rexam/output/booklink.csv', "wt", encoding="utf-8") as f:
    f.write('booktitle,booklink\n')  
    for i in range(len(title)):
        f.write(title[i]+","+link[i]+'\n')
# Out:
# -- 도서 제목 --
# ['혼자 공부하는 파이썬', '혼자 공부하는 머신러닝+딥러닝', 'Do it! 점프 투 파이썬', '만들면서 배우는 파이썬과 40개의 작품들', '데이터에듀 빅데이터 분석기사 실기 with Python', '1일 1로그 100일 완성 IT 지식', '파이썬 머신러닝 완벽 가이드', '이것이 취업을 위한 코딩 테스트다 with 파이썬 ', '2023 이기적 빅데이터분석기사 실기 기본서', '밑바닥부터 시작하는 딥러닝 ', 'Pandas를 이용한 데이터 분석 실습 2/e', '핸즈온 머신러닝', 'Do it! 쉽게 배우는 파이썬 데이터 분석', 'Do it! 자료구조와 함께 배우는 알고리즘 입문 : 파이썬 편', '케라스 창시자에게 배우는 딥러닝 개정 2판', 'Do it! 알고리즘 코딩 테스트 - 파이썬 편', '일잘러의 비밀, 엑셀 대신 파이썬으로 업무 자동화하기', '밑바닥부터 시작하는 딥러닝 2', '파이썬 알고리즘 인터뷰', '파이썬 클린 코드 2nd Edition', '모두의 데이터 분석 with 파이썬', '모두의 인공지능 기초 수학', 'Do it! 파이썬 생활 프로그래밍', 'Python을 이용한 개인화 추천 시스템']
# -- 도서 링크 URL --
# ['/Product/Goods/109625396', '/Product/Goods/96024871', '/Product/Goods/74419916', '/Product/Goods/107490270', '/Product/Goods/114655897', '/Product/Goods/105803863', '/Product/Goods/108824557', '/Product/Goods/91433923', '/Product/Goods/114873812', '/Product/Goods/34970929', '/Product/Goods/115330064', '/Product/Goods/89959711', '/Product/Goods/108947478', '/Product/Goods/91219874', '/Product/Goods/112012471', '/Product/Goods/111686187', '/Product/Goods/109003861', '/Product/Goods/72173703', '/Product/Goods/91084402', '/Product/Goods/114667254', '/Product/Goods/72227684', '/Product/Goods/91358533', '/Product/Goods/91437485', '/Product/Goods/110328538']

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd


titles = list()
summaries = list()
ratings = list()

for page_num in range(1,21):
    url = f"https://comic.naver.com/genre/bestChallenge.nhn?&page={page_num}" 
    req = requests.get(url)
    
    html = req.content.decode("utf-8")
    bs= BeautifulSoup(html, "html.parser")
    
    for info in bs.find_all(class_="challengeInfo"):
        titles.append(info.find(class_="challengeTitle").a.text.strip())
        summaries.append(info.find(class_="summary").text.strip())
        ratings.append(info.find(class_="rating_type").strong.text.strip())
    print(f"{len(titles)}개 추출")
    
naver_comic_dict = { 'title':titles, 'summary' : summaries, 'rating' : ratings }    

df = pd.DataFrame(naver_comic_dict)
display(df)
# Out:
# 24개 추출
# 48개 추출
# 72개 추출
# 96개 추출
# 120개 추출
# 144개 추출
# 168개 추출
# 192개 추출
# 216개 추출
# 240개 추출
# 264개 추출
# 288개 추출
# 312개 추출
# 336개 추출
# 360개 추출
# 384개 추출
# 408개 추출
# 432개 추출
# 456개 추출
# 480개 추출
#                   title     summary rating
# 0                  푸들가족    독립한 반려동물   9.58
# 1                   고고고  집사가 되어라!!!   9.90
# 2    21세기 밴드 (21C BAND)  음악과 사랑 이야기   7.24
# 3           호수마을에서 기억나?  캠퍼스 성장 로맨스   9.62
# 4                아빠는 N살  아빠 4컷 그림일기   9.90
# ..                  ...         ...    ...
# 475            유산은 처음이라     또 유산입니다   9.41
# 476               호텔불란서    갑자기 호텔리어   9.74
# 477                  마귀      스릴러 액션   9.64
# 478              좀비다이어리    격리구역 탈출기   9.89
# 479           이 결혼을 막아라  이 결혼을 막아라!   9.90
#
# [480 rows x 3 columns]

# %% [markdown]
# ### API 별 응답내용 한글처리 방법

# %%
import requests
from bs4 import BeautifulSoup
urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = requests.get(urlstr)
r.encoding = 'utf-8'
html = r.text
print(html)
print("===================================")
bs = BeautifulSoup(html, 'html.parser')
print(bs.prettify())
# Out:
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름과 나이를 전달해 주세요!!</h1>   </body>
# </html>
# ===================================
# ﻿
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    POST TEST
#   </title>
#  </head>
#  <body>
#   <h1>
#    GET : 이름과 나이를 전달해 주세요!!
#   </h1>
#  </body>
# </html>

# %%
import requests
from bs4 import BeautifulSoup
urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = requests.get(urlstr)
html = r.content
html = r.content.decode('utf-8')
print(html)
print("===================================")
bs = BeautifulSoup(html, 'html.parser')
print(bs.prettify())
# Out:
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름과 나이를 전달해 주세요!!</h1>   </body>
# </html>
# ===================================
# ﻿
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    POST TEST
#   </title>
#  </head>
#  <body>
#   <h1>
#    GET : 이름과 나이를 전달해 주세요!!
#   </h1>
#  </body>
# </html>

# %%
import urllib.request
from bs4 import BeautifulSoup
urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = urllib.request.urlopen(urlstr)
html = r.read()
html = html.decode('utf-8')
print(html)
print("===================================")
bs = BeautifulSoup(html, 'html.parser')
print(bs.prettify())
# Out:
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름과 나이를 전달해 주세요!!</h1>   </body>
# </html>
# ===================================
# ﻿
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    POST TEST
#   </title>
#  </head>
#  <body>
#   <h1>
#    GET : 이름과 나이를 전달해 주세요!!
#   </h1>
#  </body>
# </html>
