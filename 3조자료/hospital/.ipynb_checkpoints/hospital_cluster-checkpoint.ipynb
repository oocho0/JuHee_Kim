# %%
import pandas as pd

df=pd.read_csv('hs_rate_t_result.csv')
cluster=pd.read_csv('../project/cluster.csv')
df.set_index('sigungu',inplace=True)
df
# Out:
#           sum  상급종합병원  종합병원  병원  요양병원  한의원       pop 인구감소지수 분류  sido  \
# sigungu
# 강원도 고성군    23       0     0   0     0    4   26791.5    인구감소지역   강원도
# 강원도 삼척시    55       0     1   1     1   10   65623.0    인구감소지역   강원도
# 강원도 양구군    20       0     0   3     0    4   22379.0    인구감소지역   강원도
# 강원도 양양군    20       0     0   0     0    3   27627.5    인구감소지역   강원도
# 강원도 영월군    32       0     1   1     1    6   38345.0    인구감소지역   강원도
# ...       ...     ...   ...  ..   ...  ...       ...       ...   ...
# 충청북도 단양군   36       0     0   0     1    5   29143.0    인구감소지역  충청북도
# 충청북도 보은군   52       0     0   1     3    8   32402.5    인구감소지역  충청북도
# 충청북도 영동군   73       0     0   1     3   15   47736.5    인구감소지역  충청북도
# 충청북도 옥천군   73       0     1   0     3   15   50381.0    인구감소지역  충청북도
# 충청북도 제천시  152       0     2   1     6   36  132882.5    인구감소지역  충청북도
#
#                  전체   삼차        이차        일차        요양        한의  sig_cd
# sigungu
# 강원도 고성군    8.584812  0.0  0.000000  0.000000  0.000000  1.493011   42820
# 강원도 삼척시    8.381208  0.0  0.152386  0.152386  0.152386  1.523856   42230
# 강원도 양구군    8.936950  0.0  0.000000  1.340542  0.000000  1.787390   42800
# 강원도 양양군    7.239164  0.0  0.000000  0.000000  0.000000  1.085875   42830
# 강원도 영월군    8.345286  0.0  0.260790  0.260790  0.260790  1.564741   42750
# ...             ...  ...       ...       ...       ...       ...     ...
# 충청북도 단양군  12.352881  0.0  0.000000  0.000000  0.343136  1.715678   43800
# 충청북도 보은군  16.048144  0.0  0.000000  0.308618  0.925854  2.468945   43720
# 충청북도 영동군  15.292282  0.0  0.000000  0.209483  0.628450  3.142250   43740
# 충청북도 옥천군  14.489589  0.0  0.198488  0.000000  0.595463  2.977313   43730
# 충청북도 제천시  11.438677  0.0  0.150509  0.075254  0.451527  2.709160   43150
#
# [89 rows x 16 columns]

# %%
cluster.set_index('sigungu',inplace=True)
cluster
# Out:
#           cluster
# sigungu
# 강원도 고성군         0
# 강원도 철원군         0
# 강원도 화천군         0
# 경기도 연천군         0
# 경상남도 거창군        0
# ...           ...
# 전라북도 장수군        2
# 전라북도 진안군        2
# 충청남도 청양군        2
# 충청북도 괴산군        2
# 충청북도 옥천군        2
#
# [89 rows x 1 columns]

# %%
df['cluster']=cluster['cluster']
df.reset_index(inplace=True)

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

sns.scatterplot(x='pop', y='전체', hue='cluster',style='cluster',s=60,data=df)
for i in range(len(df)): # 행 개수만큼 순회
    row = df.iloc[i] # 한 행씩 꺼내기
    name = row['sigungu'] # 이름이 저장된 열
    x = row['pop'] # x좌표가 저장된 열
    y = row['전체'] # y좌표가 저장된 열
#    plt.text(x, y, name, fontsize=6)

plt.title('인구감소지역 전체 병원/인구수 비율, 1 만명 당')
plt.xlabel('인구수')
plt.ylabel('전체 병원/인구수 비율')
plt.legend(fontsize=6)
plt.savefig('output/aging_rate_cluster.png', bbox_inches='tight')
plt.show()
