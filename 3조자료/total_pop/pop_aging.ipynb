# %%
import pandas as pd

age_pop=pd.read_csv('age_pop.csv')
age_pop.set_index('시점',inplace=True)
age_pop=age_pop.T
age_pop
# Out:
# 시점          2000y     2001y     2002y     2003y     2004y     2005y     2006y  \
# 0세       598035.0  570380.0  501475.5  469760.5  460244.5  432538.5  419297.5
# 1세       628671.5  628188.0  597764.0  524843.5  491437.0  480935.5  452105.0
# 2세       656500.5  629879.5  628937.0  598326.0  525609.0  492441.0  481863.5
# 3세       680329.0  657152.5  630230.0  629113.0  598517.5  526186.5  493123.5
# 4세       698846.0  680592.5  657304.0  630466.0  629544.0  599063.0  526681.5
# ...           ...       ...       ...       ...       ...       ...       ...
# 96세        1786.0    1925.0    2087.0    2357.5    2670.0    2874.0    3109.0
# 97세        1280.0    1293.0    1409.5    1520.5    1756.0    2005.0    2134.5
# 98세        1009.5     937.5     944.0     998.5    1072.5    1248.0    1438.0
# 99세         832.5     753.5     678.5     667.0     697.5     761.5     905.5
# 100세 이상    2219.0    2224.5    2164.0    2026.0    1933.5    1924.0    1963.0
#
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

age_pop.plot(y='2000y')
plt.savefig('output/2000y.png', bbox_inches='tight')
plt.show()

# %%
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

age_pop.plot(y='2001y')
plt.savefig('output/2001y.png', bbox_inches='tight')
plt.show()

# %%
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

age_pop.plot(y='2002y')
plt.savefig('output/2002y.png', bbox_inches='tight')
plt.show()

# %%
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

age_pop.plot(y='2003y')
plt.savefig('output/2003y.png', bbox_inches='tight')
plt.show()

# %%
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

age_pop.plot(y='2004y')
plt.savefig('output/2004y.png', bbox_inches='tight')
plt.show()

# %%
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

age_pop.plot(y='2005y')
plt.savefig('output/2005y.png', bbox_inches='tight')
plt.show()

# %%
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

age_pop.plot(y='2006y')
plt.savefig('output/2006y.png', bbox_inches='tight')
plt.show()

# %%
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

age_pop.plot(y='2007y')
plt.savefig('output/2007y.png', bbox_inches='tight')
plt.show()

# %%
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

age_pop.plot(y='2008y')
plt.savefig('output/2008y.png', bbox_inches='tight')
plt.show()

# %%
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

age_pop.plot(y='2009y')
plt.savefig('output/2009y.png', bbox_inches='tight')
plt.show()

# %%
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

age_pop.plot(y='2010y')
plt.savefig('output/2010y.png', bbox_inches='tight')
plt.show()

# %%
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

age_pop.plot(y='2011y')
plt.savefig('output/2011y.png', bbox_inches='tight')
plt.show()

# %%
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

age_pop.plot(y='2012y')
plt.savefig('output/2012y.png', bbox_inches='tight')
plt.show()

# %%
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

age_pop.plot(y='2013y')
plt.savefig('output/2013y.png', bbox_inches='tight')
plt.show()

# %%
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

age_pop.plot(y='2014y')
plt.savefig('output/2014y.png', bbox_inches='tight')
plt.show()

# %%
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

age_pop.plot(y='2015y')
plt.savefig('output/2015y.png', bbox_inches='tight')
plt.show()

# %%
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

age_pop.plot(y='2016y')
plt.savefig('output/2016y.png', bbox_inches='tight')
plt.show()

# %%
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

age_pop.plot(y='2017y')
plt.savefig('output/2017y.png', bbox_inches='tight')
plt.show()

# %%
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

age_pop.plot(y='2018y')
plt.savefig('output/2018y.png', bbox_inches='tight')
plt.show()

# %%
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

age_pop.plot(y='2019y')
plt.savefig('output/2019y.png', bbox_inches='tight')
plt.show()

# %%
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

age_pop.plot(y='2020y')
plt.savefig('output/2020y.png', bbox_inches='tight')
plt.show()

# %%
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

age_pop.plot(y='2021y')
plt.savefig('output/2021y.png', bbox_inches='tight')
plt.show()
