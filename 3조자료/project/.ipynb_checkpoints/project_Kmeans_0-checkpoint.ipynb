# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #서브 패키지 pyplot 사용
# %matplotlib inline
from sklearn.cluster import KMeans

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
else:
    print('Unknown system...  sorry~~~')

# %%
import seaborn as sns #seaborn 패키지 임포트

# %%
data=pd.read_csv('cluster_0s.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 32 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   시군구          30 non-null     object
#  1   SIG_CD       30 non-null     int64
#  2   SIG_KOR_NM   30 non-null     object
#  3   인구수          30 non-null     float64
#  4   사망률          30 non-null     float64
#  5   고령화비율        30 non-null     float64
#  6   전체 가구수       30 non-null     int64
#  7   산림면적(ha)     30 non-null     int64
#  8   고용률          30 non-null     float64
#  9   경제활동인구       30 non-null     float64
#  10  유소년비율        30 non-null     float64
#  11  조출생률         30 non-null     float64
#  12  1인 가구비율      30 non-null     float64
#  13  터널수          30 non-null     int64
#  14  만명당 매장 수     30 non-null     float64
#  15  만명 당 의료기관 수  30 non-null     float64
#  16  만명당 3차병원수    30 non-null     float64
#  17  만명당 2차병원 수   30 non-null     float64
#  18  만명당 1차병원 수   30 non-null     float64
#  19  만명당 요양병원 수   30 non-null     float64
#  20  만먕당 한의원 수    30 non-null     float64
#  21  1차산업비율       30 non-null     float64
#  22  2차산업비율       30 non-null     float64
#  23  3차산업비율       30 non-null     float64
#  24  ktx거리        30 non-null     float64
#  25  빈집비율         30 non-null     float64
#  26  산지면적/도시면적    30 non-null     float64
#  27  재정자립도        30 non-null     float64
#  28  연평균인구증감률     30 non-null     float64
#  29  시도           30 non-null     object
#  30  총가구수         30 non-null     int64
#  31  cluster      30 non-null     int64
# dtypes: float64(23), int64(6), object(3)
# memory usage: 7.6+ KB

# %%
pj_data = data.drop(['SIG_CD','SIG_KOR_NM','시도'], axis=1)
pj_data.set_index('시군구', inplace=True)
pj_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 강원도 삼척시 to 충청북도 영동군
# Data columns (total 28 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   인구수          30 non-null     float64
#  1   사망률          30 non-null     float64
#  2   고령화비율        30 non-null     float64
#  3   전체 가구수       30 non-null     int64
#  4   산림면적(ha)     30 non-null     int64
#  5   고용률          30 non-null     float64
#  6   경제활동인구       30 non-null     float64
#  7   유소년비율        30 non-null     float64
#  8   조출생률         30 non-null     float64
#  9   1인 가구비율      30 non-null     float64
#  10  터널수          30 non-null     int64
#  11  만명당 매장 수     30 non-null     float64
#  12  만명 당 의료기관 수  30 non-null     float64
#  13  만명당 3차병원수    30 non-null     float64
#  14  만명당 2차병원 수   30 non-null     float64
#  15  만명당 1차병원 수   30 non-null     float64
#  16  만명당 요양병원 수   30 non-null     float64
#  17  만먕당 한의원 수    30 non-null     float64
#  18  1차산업비율       30 non-null     float64
#  19  2차산업비율       30 non-null     float64
#  20  3차산업비율       30 non-null     float64
#  21  ktx거리        30 non-null     float64
#  22  빈집비율         30 non-null     float64
#  23  산지면적/도시면적    30 non-null     float64
#  24  재정자립도        30 non-null     float64
#  25  연평균인구증감률     30 non-null     float64
#  26  총가구수         30 non-null     int64
#  27  cluster      30 non-null     int64
# dtypes: float64(23), int64(5)
# memory usage: 6.8+ KB

# %%
#X=pj_data
#from sklearn import preprocessing
#X=preprocessing.StandardScaler().fit(X).transform(X)

# %%
kmeans=KMeans(n_clusters=3, init='k-means++', random_state=10)
kmeans.fit(pj_data)
# Out:
# KMeans(n_clusters=3, random_state=10)

# %%
kmeans.labels_
# Out:
# array([0, 2, 2, 0, 2, 2, 0, 0, 0, 0, 2, 2, 0, 2, 1, 1, 2, 0, 1, 1, 1, 2,
#        2, 2, 2, 1, 2, 1, 2, 0], dtype=int32)

# %%
cluster = kmeans.predict(pj_data)
cluster
# Out:
# array([0, 2, 2, 0, 2, 2, 0, 0, 0, 0, 2, 2, 0, 2, 1, 1, 2, 0, 1, 1, 1, 2,
#        2, 2, 2, 1, 2, 1, 2, 0], dtype=int32)

# %%
pj_data['cluster']=kmeans.labels_

# %%
pj_data.head(3)
# Out:
#              인구수     사망률      고령화비율  전체 가구수  산림면적(ha)   고용률  경제활동인구  \
# 시군구
# 강원도 삼척시  65623.0   964.6  24.495985   31016    104323  61.0    70.0
# 강원도 양구군  22379.0   862.4  20.362840    8606     52993  71.2    23.4
# 강원도 양양군  27627.5  1104.0  29.253461   12445     52485  71.5    33.9
#
#              유소년비율      조출생률   1인 가구비율  ...  1차산업비율  2차산업비율  3차산업비율    ktx거리  \
# 시군구                                     ...
# 강원도 삼척시   9.679533  5.455404  0.403534  ...    9.12   16.64   74.38   6.5740
# 강원도 양구군  11.836990  7.104875  0.294097  ...   28.26    7.83   63.48  69.6764
# 강원도 양양군   7.984798  3.221428  0.361109  ...   25.15   12.57   62.28  42.4503
#
#          빈집비율   산지면적/도시면적  재정자립도  연평균인구증감률   총가구수  cluster
# 시군구
# 강원도 삼척시  17.2   13.059622   13.5   -1.6028  31016        0
# 강원도 양구군   7.8  142.838275    8.1   -1.8544   8606        2
# 강원도 양양군  23.7   44.811864   14.1    0.6621  12445        2
#
# [3 rows x 28 columns]

# %%
from sklearn.decomposition import PCA

pca=PCA(n_components=2)

# %%
pca_transformed=pca.fit_transform(pj_data)

# %%
pca_transformed
# Out:
# array([[  4714.31937291,  52252.15279602],
#        [-43994.23737229,  -3638.51543366],
#        [-36642.83808991,  -3487.89025658],
#        [-30971.5623089 ,  48958.93401846],
#        [-19251.39229522,   5449.15898272],
#        [-17321.46496076, -27496.11300268],
#        [-26365.86922579,  64796.58402191],
#        [  1936.2801726 ,  99595.18359737],
#        [   798.18195329,  16459.96047066],
#        [  1411.07961895,   7700.06084002],
#        [ -7414.19948207, -19740.52520194],
#        [-35512.37865546, -22965.07312785],
#        [-18413.60513639,  16396.99888946],
#        [-40853.29822126, -10225.91639254],
#        [ 43884.40339931,  34259.86691343],
#        [113201.92569356,  64594.65097313],
#        [-54197.43461314, -52245.63033983],
#        [-10124.74889237,  28626.24463988],
#        [135833.81614834, -40591.76906685],
#        [ 38934.01624722, -49157.74955653],
#        [ 60534.69535614, -46820.71927603],
#        [-20596.56775574, -13422.23122011],
#        [-21667.33393902, -22545.6593716 ],
#        [ -8224.76307289, -27827.98281024],
#        [ -3026.65098961, -26969.026407  ],
#        [ 30281.48699974, -38648.04407998],
#        [-40939.6619903 ,  -5391.29879601],
#        [ 49059.46414546, -15699.45735433],
#        [-30846.89522034, -24041.63927249],
#        [-14224.76688607,  11825.44482321]])

# %%
pj_data['pca_x']=pca_transformed[:,0]
pj_data['pca_y']=pca_transformed[:,1]
pj_data.head()
# Out:
#              인구수     사망률      고령화비율  전체 가구수  산림면적(ha)   고용률  경제활동인구  \
# 시군구
# 강원도 삼척시  65623.0   964.6  24.495985   31016    104323  61.0    70.0
# 강원도 양구군  22379.0   862.4  20.362840    8606     52993  71.2    23.4
# 강원도 양양군  27627.5  1104.0  29.253461   12445     52485  71.5    33.9
# 강원도 정선군  36313.0  1027.2  26.847135   16375    104220  70.0    43.1
# 강원도 철원군  44767.5   965.0  22.049478   17244     59849  65.7    43.6
#
#              유소년비율      조출생률   1인 가구비율  ...  3차산업비율    ktx거리  빈집비율  \
# 시군구                                     ...
# 강원도 삼척시   9.679533  5.455404  0.403534  ...   74.38   6.5740  17.2
# 강원도 양구군  11.836990  7.104875  0.294097  ...   63.48  69.6764   7.8
# 강원도 양양군   7.984798  3.221428  0.361109  ...   62.28  42.4503  23.7
# 강원도 정선군   8.385427  3.662600  0.377771  ...   70.02  28.7242  14.3
# 강원도 철원군  11.640141  7.639471  0.278300  ...   57.51  64.3458   7.7
#
#           산지면적/도시면적  재정자립도  연평균인구증감률   총가구수  cluster         pca_x  \
# 시군구
# 강원도 삼척시   13.059622   13.5   -1.6028  31016        0   4714.319373
# 강원도 양구군  142.838275    8.1   -1.8544   8606        2 -43994.237372
# 강원도 양양군   44.811864   14.1    0.6621  12445        2 -36642.838090
# 강원도 정선군   24.497452   21.5   -1.2152  16375        0 -30971.562309
# 강원도 철원군   22.621491    8.5   -1.7721  17244        2 -19251.392295
#
#                 pca_y
# 시군구
# 강원도 삼척시  52252.152796
# 강원도 양구군  -3638.515434
# 강원도 양양군  -3487.890257
# 강원도 정선군  48958.934018
# 강원도 철원군   5449.158983
#
# [5 rows x 30 columns]

# %%
plt.scatter(x=pj_data.loc[:,'pca_x'],y=pj_data.loc[:,'pca_y'],
           c=pj_data['cluster'])

pj_data.reset_index(inplace=True)

for i in range(len(pj_data)):
    row=pj_data.iloc[i]
    name=row['시군구']
    x = row['pca_x']
    y = row['pca_y']
    if name in ['경상북도 울릉군']:
        plt.text(x-0.5, y-0.5, name, fontsize=8)

pj_data.set_index('시군구', inplace=True)

# %%
pj_data.reset_index(inplace=True)
clusterDF = pd.DataFrame(data=pca_transformed, columns=['ftr1','ftr2'])
clusterDF['cluster'] = pj_data['cluster']
clusterDF
# Out:
#              ftr1          ftr2  cluster
# 0     4714.319373  52252.152796        0
# 1   -43994.237372  -3638.515434        2
# 2   -36642.838090  -3487.890257        2
# 3   -30971.562309  48958.934018        0
# 4   -19251.392295   5449.158983        2
# 5   -17321.464961 -27496.113003        2
# 6   -26365.869226  64796.584022        0
# 7     1936.280173  99595.183597        0
# 8      798.181953  16459.960471        0
# 9     1411.079619   7700.060840        0
# 10   -7414.199482 -19740.525202        2
# 11  -35512.378655 -22965.073128        2
# 12  -18413.605136  16396.998889        0
# 13  -40853.298221 -10225.916393        2
# 14   43884.403399  34259.866913        1
# 15  113201.925694  64594.650973        1
# 16  -54197.434613 -52245.630340        2
# 17  -10124.748892  28626.244640        0
# 18  135833.816148 -40591.769067        1
# 19   38934.016247 -49157.749557        1
# 20   60534.695356 -46820.719276        1
# 21  -20596.567756 -13422.231220        2
# 22  -21667.333939 -22545.659372        2
# 23   -8224.763073 -27827.982810        2
# 24   -3026.650990 -26969.026407        2
# 25   30281.487000 -38648.044080        1
# 26  -40939.661990  -5391.298796        2
# 27   49059.464145 -15699.457354        1
# 28  -30846.895220 -24041.639272        2
# 29  -14224.766886  11825.444823        0

# %%
centers=kmeans.cluster_centers_
centers
# Out:
# array([[ 5.31970000e+04,  1.24421111e+03,  2.97093098e+01,
#          2.37211111e+04,  9.19631111e+04,  6.73333333e+01,
#          6.10444444e+01,  8.39347687e+00,  3.94822165e+00,
#          3.67468865e-01,  2.90000000e+01,  7.02650459e-01,
#          1.21296143e+01,  0.00000000e+00,  3.31164196e-02,
#          3.64049104e-01,  4.94561578e-01,  2.12915673e+00,
#          3.13377778e+01,  1.25088889e+01,  5.62155556e+01,
#          3.12234889e+01,  1.65000000e+01,  2.91455905e+01,
#          1.23666667e+01, -1.06902222e+00,  2.37211111e+04,
#          0.00000000e+00],
#        [ 1.14686214e+05,  1.04825714e+03,  2.61434661e+01,
#          5.10510000e+04,  3.36111429e+04,  5.86714286e+01,
#          1.19614286e+02,  8.93315981e+00,  3.65827312e+00,
#          3.56684246e-01,  1.54285714e+01,  8.89906444e-01,
#          1.25872690e+01,  2.69674072e-02,  1.55105764e-01,
#          2.92737408e-01,  4.51392785e-01,  3.20280302e+00,
#          1.79328571e+01,  1.88528571e+01,  6.32142857e+01,
#          1.49143571e+01,  1.16285714e+01,  6.30405613e+00,
#          1.20000000e+01, -1.46480000e+00,  5.10510000e+04,
#          0.00000000e+00],
#        [ 3.48159286e+04,  1.23932143e+03,  3.10449767e+01,
#          1.51510714e+04,  3.70090000e+04,  7.15500000e+01,
#          4.02000000e+01,  8.46408922e+00,  3.96432545e+00,
#          3.56645124e-01,  1.37142857e+01,  6.01993204e-01,
#          1.21991422e+01,  2.60208521e-18,  2.99782882e-02,
#          2.82047448e-01,  3.92980536e-01,  1.96777465e+00,
#          3.85871429e+01,  1.10828571e+01,  5.03414286e+01,
#          4.74289214e+01,  1.34142857e+01,  3.81311660e+01,
#          9.24285714e+00, -1.59347857e+00,  1.51510714e+04,
#          0.00000000e+00]])

# %%
unique_labels=np.unique(cluster)
unique_labels
# Out:
# array([0, 1, 2], dtype=int32)

# %%
markers=['o','s','^','P','D','H','x']

for target in unique_labels :
    target_cluster = clusterDF[clusterDF['cluster']==target]
    plt.scatter(x=target_cluster['ftr1'], y=target_cluster['ftr2'],
               edgecolor='k', marker=markers[target])
plt.show()

# %%
for label in unique_labels:
    
    label_cluster=clusterDF[clusterDF['cluster']==label]
    center_x_y=centers[label]
    plt.scatter(x=label_cluster['ftr1'], y=label_cluster['ftr2'],
                edgecolor='k', marker=markers[label])
    
    center_x_y=centers[label]
    
    plt.scatter(x=center_x_y[0], y=center_x_y[1], s=220, color='white',
               alpha=0.9, edgecolor='k',  marker=markers[label])
    
    plt.scatter(x=center_x_y[0], y=center_x_y[1], s=80, color='k',
                edgecolor='k', marker='$%d$' % label)
    
    
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
# %matplotlib inline

# %%
pj_data.set_index('시군구',inplace=True)
pj_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 강원도 삼척시 to 충청북도 영동군
# Data columns (total 30 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   인구수          30 non-null     float64
#  1   사망률          30 non-null     float64
#  2   고령화비율        30 non-null     float64
#  3   전체 가구수       30 non-null     int64
#  4   산림면적(ha)     30 non-null     int64
#  5   고용률          30 non-null     float64
#  6   경제활동인구       30 non-null     float64
#  7   유소년비율        30 non-null     float64
#  8   조출생률         30 non-null     float64
#  9   1인 가구비율      30 non-null     float64
#  10  터널수          30 non-null     int64
#  11  만명당 매장 수     30 non-null     float64
#  12  만명 당 의료기관 수  30 non-null     float64
#  13  만명당 3차병원수    30 non-null     float64
#  14  만명당 2차병원 수   30 non-null     float64
#  15  만명당 1차병원 수   30 non-null     float64
#  16  만명당 요양병원 수   30 non-null     float64
#  17  만먕당 한의원 수    30 non-null     float64
#  18  1차산업비율       30 non-null     float64
#  19  2차산업비율       30 non-null     float64
#  20  3차산업비율       30 non-null     float64
#  21  ktx거리        30 non-null     float64
#  22  빈집비율         30 non-null     float64
#  23  산지면적/도시면적    30 non-null     float64
#  24  재정자립도        30 non-null     float64
#  25  연평균인구증감률     30 non-null     float64
#  26  총가구수         30 non-null     int64
#  27  cluster      30 non-null     int32
#  28  pca_x        30 non-null     float64
#  29  pca_y        30 non-null     float64
# dtypes: float64(25), int32(1), int64(4)
# memory usage: 7.1+ KB

# %%
pj_data.to_csv('project_result.csv')

# %%
inertia=[]
for k in range(2,7):
    km=KMeans(n_clusters=k)
    km.fit(pj_data)
    inertia.append(km.inertia_)
plt.plot(range(2,7), inertia)
plt.xlabel('k')
plt.ylabel('inertia')
plt.savefig('approprate_k.png')
plt.show()

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

print(__doc__)

# Generating the sample data from make_blobs
# This particular setting has one distinct cluster and 3 clusters placed close
# together.
# Out:
# Automatically created module for IPython interactive environment

# %%
X= pca_transformed

# %%
y= kmeans.labels_

# %%
data.columns
# Out:
# Index(['시군구', 'SIG_CD', 'SIG_KOR_NM', '인구수', '사망률', '고령화비율', '전체 가구수',
#        '산림면적(ha)', '고용률', '경제활동인구', '유소년비율', '조출생률', '1인 가구비율', '터널수',
#        '만명당 매장 수', '만명 당 의료기관 수', '만명당 3차병원수', '만명당 2차병원 수', '만명당 1차병원 수',
#        '만명당 요양병원 수', '만먕당 한의원 수', '1차산업비율', '2차산업비율', '3차산업비율', 'ktx거리',
#        '빈집비율', '산지면적/도시면적', '재정자립도', '연평균인구증감률', '시도', '총가구수', 'cluster'],
#       dtype='object')

# %%
df=data.drop(['시도','SIG_CD','SIG_KOR_NM'], axis=1)
df
# Out:
#          시군구       인구수     사망률      고령화비율  전체 가구수  산림면적(ha)   고용률  경제활동인구  \
# 0    강원도 삼척시   65623.0   964.6  24.495985   31016    104323  61.0    70.0
# 1    강원도 양구군   22379.0   862.4  20.362840    8606     52993  71.2    23.4
# 2    강원도 양양군   27627.5  1104.0  29.253461   12445     52485  71.5    33.9
# 3    강원도 정선군   36313.0  1027.2  26.847135   16375    104220  70.0    43.1
# 4    강원도 철원군   44767.5   965.0  22.049478   17244     59849  65.7    43.6
# 5    강원도 태백시   42288.0   848.9  23.725407   18688     26855  61.6    45.0
# 6    강원도 평창군   41489.0   993.0  27.457880   18519    119586  72.4    50.6
# 7    강원도 홍천군   68652.0  1091.0  25.489425   29533    151734  71.1    81.7
